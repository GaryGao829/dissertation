# %%
# pytorch optimizer 让动量参与计算，以及手动修改lr

from __future__ import absolute_import
from __future__ import division
from __future__ import print_function

import argparse
import numpy as np

import ray
import resnet.models as models
import random,time
from time import sleep
import copy 
import datetime
import argparse
import sys


import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torchvision import datasets, transforms
from torch.autograd import Variable
import numpy as np
import os
import shutil
from torch.utils.tensorboard import SummaryWriter
from filelock import FileLock
# Out:
# /userhome/34/gyu/anaconda3/envs/pytorch_env/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:541: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /userhome/34/gyu/anaconda3/envs/pytorch_env/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:542: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /userhome/34/gyu/anaconda3/envs/pytorch_env/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:543: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /userhome/34/gyu/anaconda3/envs/pytorch_env/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:544: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /userhome/34/gyu/anaconda3/envs/pytorch_env/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:545: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /userhome/34/gyu/anaconda3/envs/pytorch_env/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:550: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])

# %%
def generate_train_loader(batch_size,kwargs):
    train_loader = torch.utils.data.DataLoader(
        datasets.CIFAR10('./data.cifar10', train=True, download=True,
        transform=transforms.Compose([
            transforms.Pad(4),
            transforms.RandomCrop(32),
            transforms.RandomHorizontalFlip(),
            transforms.ToTensor(),
            transforms.Normalize((0.4914, 0.4822, 0.4465), (0.2023, 0.1994, 0.2010))
        ])),
    batch_size=batch_size, shuffle=True, **kwargs)
    return train_loader

def generate_test_loader(test_batch_size):
    test_loader = torch.utils.data.DataLoader(
        datasets.CIFAR10('./data.cifar10', train=False, transform=transforms.Compose([
            transforms.ToTensor(),
            transforms.Normalize((0.4914, 0.4822, 0.4465), (0.2023, 0.1994, 0.2010))
        ])),batch_size=test_batch_size, shuffle=True)
    return test_loader

def _get_params(model):
    bns = {}
    non_bns = {}
    param_count = 0.
    bn_param_count = 0.
    for name,param in model.named_parameters():
        param_count += len(param)
        if 'bn' in name:
            bns[name] = param
            bn_param_count += len(param)
        else:
            non_bns[name] = param
#     print("bn params occupies: ",bn_param_count/param_count)
    return bns,non_bns

@ray.remote
class ParameterServer():
    def __init__(self,args,test_loader):
        self.model = models.__dict__["resnet"](dataset="cifar10",depth=args.depth)
        self.stalness_table = [0] * args.num_workers
        self.stalness_limit = args.stalness_limit 
        self.global_step = 0
        self.lr = args.lr
        self.args = args
        self.eva_model = models.__dict__["resnet"](dataset="cifar10",depth=args.depth)
        self.optimizer = optim.SGD(self.model.parameters(),
                          lr=args.lr,
                          momentum=args.momentum,
                          weight_decay=args.weight_decay)
        self.test_loader = test_loader
        self.model.cpu()
        self.eva_model.cpu()
        self.ps_writer = SummaryWriter(os.path.join(os.getcwd(),(args.tb_path+'/ps')))
        self.save_path = args.save
        self.num_workers = (int)(args.num_workers)
        
        # get point to all non_bns parameters
        self.non_bns = [param.data for name,param in self.model.named_parameters() if 'bn' not in name]
        self.bns = [param.data for name,param in self.model.named_parameters() if 'bn' in name]
        self.bns_sync = [None] * args.num_workers
        
        if args.resume:
            if os.path.isfile(args.resume):
                print("=> loading checkpoint '{}'".format(args.resume))
                checkpoint = torch.load(args.resume)
                self.global_step = checkpoint['global_step']
                self.model.load_state_dict(checkpoint['state_dict'])
                self.optimizer.load_state_dict(checkpoint['optimizer'])
                self.stalness_table = [self.global_step/args.num_workers] * args.num_workers
                print("=> loaded checkpoint '{}' (global step: {})".format(args.resume, checkpoint['global_step']))                
                if 'epoch' in checkpoint: print("epoch: {}".format(checkpoint['epoch']))
            else:
                print("=> no checkpoint found at '{}'".format(args.resume))                    
                
    def apply_gradients(self, iter_diff, wk_idx, epoch):
        if args.debug: print("applying gradients from the ",wk_idx, " worker")
        
        # updata all params
        for idx, p in enumerate(self.model.parameters()):
            p.data -= iter_diff[idx]

#         if wk_idx == 0:
#             # updata all params
#             for idx, p in enumerate(self.model.parameters()):
#                 p.data -= iter_diff[idx]
#         else:
#             # only update non_bns params
#             for idx, tensor in enumerate(self.non_bns):
#                 tensor -= iter_diff[idx]
        
#         # only update non_bns params
#         for idx, tensor in enumerate(self.non_bns):
#             tensor -= iter_diff[idx]
        
        self.stalness_table[wk_idx] += 1
        self.global_step += 1
        if args.debug: print("finished applying gradients from the ",wk_idx, " worker")
        if self.global_step % 1000 == 0:
#             print("global_step: ",self.global_step," and prepare evaluate")
#             self.evaluate()
            self.save_ckpt({
                'epoch':epoch,
                'global_step':self.global_step,
                'state_dict':self.model.state_dict(),
                'optimizer':self.optimizer.state_dict()
            },filepath=os.path.join(os.getcwd(),self.save_path))
    
    
    def apply_gradients_non_bns(self,iter_diff,wk_idx,epoch):
        for i in range(len(self.non_bns)):
            self.non_bns[i] -= iter_diff[i]
#         print(wk_idx,"finished updating non bns on ps")

        
    def apply_gradients_bns(self,iter_diff,wk_idx,epoch):
        for idx, tensor in enumerate(self.bns):
#             if idx == len(iter_diff) / 2:
#                 print(wk_idx,"is in the middle of updating bns on ps")
            tensor -= iter_diff[idx]
#         print(wk_idx,"finished updating non bns on ps")
#         self.stalness_table[wk_idx] += 1
#         self.global_step += 1

    def apply_gradients_partical_bns(self, iter_diff, wk_idx, epoch):
        if wk_idx == 0 :
            for i in range(0,(int)(len(self.bns)/self.num_workers)):
                self.bns[i] -= iter_diff[i]
        elif wk_idx == self.num_workers:
            for i in range((int)(len(self.bns) * wk_idx / self.num_workers + 1) , len(self.bns)):
                self.bns[i] -= iter_diff[i]
        else:
            for i in range((int)(len(self.bns) * wk_idx / self.num_workers + 1) , (int)(len(self.bns) * (wk_idx + 1) / self.num_workers)):
                self.bns[i] -= iter_diff[i]
        self.stalness_table[wk_idx] += 1
        self.global_step += 1
        if self.global_step % 1000 == 0:
            self.save_ckpt({
                'epoch':epoch,
                'global_step':self.global_step,
                'state_dict':self.model.state_dict(),
                'optimizer':self.optimizer.state_dict()
            },filepath=os.path.join(os.getcwd(),self.save_path))

        
    def pull_weights(self):
        return self.model.state_dict()
    
    def pull_non_bn_weights(self):
        self.non_bns = [param.data for name,param in self.model.named_parameters() if 'bn' not in name]
        return copy.deepcopy(self.non_bns)
    
    def pull_bn_weights(self):
        self.bns = [param.data for name,param in self.model.named_parameters() if 'bn' in name]
        return copy.deepcopy(self.bns)
    
    def get_optim(self):
        return self.optimizer
    
    def pull_optimizer_state(self):
        return self.optimizer.state_dict()

    def check_stalness(self,wk_idx):
        min_iter = min(self.stalness_table)
        return self.stalness_table[wk_idx] - min_iter < self.stalness_limit
        
    def get_stalness(self):
        return min(self.stalness_table)
    
    def get_stalness_table(self):
        return self.stalness_table
    
    def get_global_step(self):
        return self.global_step
    
    def get_model(self):
        return self.model
    
    def save_ckpt(self,state,filepath):
        torch.save(state,os.path.join(filepath,'checkpoint.pth.tar'))
    
    def get_bns_ready(self):
        return any(self.bns_sync) == False
        
    def aggregate_bns(self,wk_bns,worker_index):
        self.bns_sync[worker_index] = wk_bns
        if all(self.bns_sync):
            for i in range(len(self.bns)):
                tmp = copy.deepcopy(self.bns_sync[0][i])
                for j in range(1, self.num_workers):
                    tmp += self.bns_sync[j][i]
                self.bns[i] = tmp / self.num_workers    
            self.bns_sync = [None] * self.num_workers
        return self.bns_sync
    
    def evaluate(self):
        print("going to evaluate")
        test_loss = 0.
        correct = 0.
        print("pulled weights")
        self.eva_model.load_state_dict(copy.deepcopy(self.model.state_dict()))
        print("loaded weights")
        print("length of the test_loader dataset is : ",len(self.test_loader.dataset))
        self.eva_model.eval()
        count = 0
        for data,target in self.test_loader:
            count += 1
            if count % 20 == 0: print("in eval, the batch is: ",count)
            data, target = Variable(data,volatile=True),Variable(target)
            output = self.eva_model(data)
            batch_loss = F.cross_entropy(output, target, size_average=False).data
            test_loss += batch_loss
            pred = output.data.max(1, keepdim=True)[1]
            correct += pred.eq(target.data.view_as(pred)).cpu().sum()
        len_testset = len(self.test_loader.dataset)
        test_loss /= len_testset 
        accuracy = correct / len_testset
        # log 
        print('\nTest set: Average loss: {:.4f}, Accuracy: {}/{} ({:.1f}%)\n'.format(
        test_loss, correct, len_testset,accuracy))

        self.ps_writer.add_scalar('Accuracy/eval', accuracy, self.global_step)
        self.ps_writer.add_scalar('Loss/eval',test_loss , self.global_step)

# %%
@ray.remote(num_gpus=1)
def worker_task(args,ps,worker_index, train_loader):
    # Initialize the model.
#     if args.debug: print(worker_index, " worker is going to sleep ",worker_index*5000)
#     time.sleep(worker_index * 5000)
    
    model = models.__dict__["resnet"](dataset="cifar10",depth=args.depth)
    local_step = 0
    optimizer = optim.SGD(model.parameters(),
                          lr=args.lr,
                          momentum=args.momentum,
                          weight_decay=args.weight_decay)
    wk_non_bns = [param.data for name,param in model.named_parameters() if 'bn' not in name]
    wk_bns = [param.data for name,param in model.named_parameters() if 'bn' in name]
    
    if args.cuda:
        starttime = datetime.datetime.now()
        model.cuda()
        endtime = datetime.datetime.now()
        time_cost = (endtime - starttime).seconds
        if args.debug: print("move model to gpu takes: ", time_cost, "seconds")
    if args.resume:
        checkpoint = torch.load(args.resume)
        local_step = checkpoint['global_step'] / args.num_workers
        optimizer.load_state_dict(checkpoint['optimizer'])
        if 'epoch' in checkpoint:
            args.start_epoch = checkpoint['epoch']

    wk_writer = SummaryWriter(os.path.join(os.getcwd(),args.tb_path,('wk_'+str(worker_index))))
    print("worker #",worker_index," is online")
    
    # all workers owns the same init values
    init_wei = ray.get(ps.pull_weights.remote())
    model.load_state_dict(init_wei)
    sync_bns_flag = False
    
    
    for epoch in range(args.start_epoch,args.epochs):
        avg_loss = 0.
        train_correct = 0.
        for batch_idx,(data,target) in enumerate(train_loader):
            if args.cuda:
                starttime = datetime.datetime.now()
                data,target = data.cuda(),target.cuda()
                mid = datetime.datetime.now()
                if args.debug: print("move data to gpu takes: ", (mid - starttime).seconds, "seconds")
                model.cuda()
                endtime = datetime.datetime.now()
                time_cost = (endtime - starttime).seconds
                if args.debug: print("move model to gpu takes: ", time_cost, "seconds")
                
            while(local_step - ray.get(ps.get_stalness.remote()) > args.stalness_limit):
                sleep(1)
            

            # Get all weights from the parameter server.
            if args.debug: print("the ",worker_index," pulls wei from ps.")
            init_wei = ray.get(ps.pull_weights.remote())
            model.load_state_dict(init_wei)
            if args.debug: print("the ",worker_index," loaded the latest wei from ps.")
            model.cpu()    
            wk_non_bns = [param.data for name,param in model.named_parameters() if 'bn' not in name]
            wk_bns = [param.data for name,param in model.named_parameters() if 'bn' in name]
            model.cuda()
            old_tensors_non_bns = copy.deepcopy(wk_non_bns)
            old_tensors_bns = copy.deepcopy(wk_bns)
                
#             # Get only non-bn weights from the parameter server.
#             ps_non_bns = ray.get(ps.pull_non_bn_weights.remote())
#             print(worker_index,"pulled non bns from ps")
#             assert len(ps_non_bns) == len(wk_non_bns)
#             for i in range(len(ps_non_bns)):
#                 if i == len(ps_non_bns) / 2:
#                     print(worker_index,"is in the middle of updating non bns")
#                 wk_non_bns[i] = ps_non_bns[i]
#             print(worker_index,"updated non bns from ps and is going to pull bns ")
            
#             # Get only bn weights from the parameter server.
#             ps_bns = ray.get(ps.pull_bn_weights.remote())
#             print(worker_index,"pulled bns from ps")
#             assert len(ps_bns) == len(wk_bns)
#             for i in range(len(ps_bns)):
#                 if i == len(ps_bns) / 2 :
#                     print(worker_index, "is in the middle of updating bns")
#                 wk_bns[i] = ps_bns[i]
#             print(worker_index,"updated bns from ps")

                
            # Compute an update and push it to the parameter server.        
            data, target = Variable(data), Variable(target)
            optimizer.zero_grad()
            if args.debug: print(worker_index,' is generating output')
            output = model(data)
            if args.debug: print(worker_index,' generated output done and going to calculate loss')
            loss = F.cross_entropy(output,target)
            avg_loss += loss
            pred = output.data.max(1,keepdim=True)[1]
            batch_correct = pred.eq(target.data.view_as(pred)).cpu().sum()
            train_correct += batch_correct
            if args.debug: print(worker_index,' calculated loss and going to bp')
            loss.backward()
            if args.debug: print(worker_index,' bp done')
                
#             if worker_index == 0:
#                 # calculate difference for this iteration
#                 old_tensors = copy.deepcopy([p.data for p in model.parameters()])    
#                 optimizer.step()
#                 new_tensors = [p.data for p in model.parameters()]
#                 iter_diff = [(old_tensor - new_tensor)/args.num_workers for (old_tensor, new_tensor) in zip(old_tensors,new_tensors)]
#                 # print("passing sizes: ",sys.getsizeof(iter_diff))
#                 ps.apply_gradients.remote(iter_diff,worker_index,epoch)
            
#             else:
#                 old_tensors_non_bns = copy.deepcopy([param.data for name,param in model.named_parameters() if 'bn' not in name])
#                 optimizer.step()
#                 wk_non_bns = [param.data for name,param in model.named_parameters() if 'bn' not in name]
#                 iter_diff_non_bns = [(old_tensor_non_bns - new_tensor_non_bns)/args.num_workers for (old_tensor_non_bns, new_tensor_non_bns) in zip(old_tensors_non_bns,wk_non_bns)]
#                 ps.apply_gradients_non_bns.remote(iter_diff_non_bns,worker_index,epoch)
        

                
            
#             if worker_index == 0:
# #                 print(worker_index, "passing all params")
#                 # calculate difference for this iteration
#                 old_tensors = copy.deepcopy([p.data for p in model.parameters()])    
#                 optimizer.step()
#                 new_tensors = [p.data for p in model.parameters()]
#                 iter_diff = [(old_tensor - new_tensor)/args.num_workers for (old_tensor, new_tensor) in zip(old_tensors,new_tensors)]
#                 # print("passing sizes: ",sys.getsizeof(iter_diff))
#                 ps.apply_gradients.remote(iter_diff,worker_index,epoch)
#             else:
# #                 print(worker_index, "passing non bn params")
#                 #calculate only non-bn parameters difference 
#                 old_tensors = copy.deepcopy([param.data for name,param in model.named_parameters() if 'bn' not in name])
#                 optimizer.step()
#                 new_tensors = [param.data for name,param in model.named_parameters() if 'bn' not in name]
#                 iter_diff = [(old_tensor - new_tensor)/args.num_workers for (old_tensor, new_tensor) in zip(old_tensors,new_tensors)]
#                 # print("passing sizes: ",sys.getsizeof(iter_diff))
#                 ps.apply_gradients.remote(iter_diff,worker_index,epoch)

            # calculate bns and non_bns parameters difference 
           
            optimizer.step()
            model.cpu()
            new_tensors_non_bns = [param.data for name,param in model.named_parameters() if 'bn' not in name]
            new_tensors_bns = [param.data for name,param in model.named_parameters() if 'bn' in name]
            model.cuda()
            iter_diff_non_bns = [(old_tensor_non_bns - new_tensor_non_bns)/args.num_workers for (old_tensor_non_bns, new_tensor_non_bns) in zip(old_tensors_non_bns,new_tensors_non_bns)]
            iter_diff_bns = [(old_tensor_bns - new_tensor_bns)/args.num_workers for (old_tensor_bns, new_tensor_bns) in zip(old_tensors_bns,new_tensors_bns)]
            # print("passing sizes: ",sys.getsizeof(iter_diff))
            ps.apply_gradients_non_bns.remote(iter_diff_non_bns,worker_index,epoch)
#             print(worker_index, "pushed non bns to ps and is going to push bns to ps")
            ps.apply_gradients_partical_bns.remote(iter_diff_bns,worker_index,epoch)
#             print(worker_index, "pushed bns to ps")
            
            
#             # aggregate and sync bn parameters    
#             if sync_bns_flag:
#                 print("SYNC BNS: worker #",worker_index," is checking to pull bns from ps ")
#                 if ray.get(ps.get_bns_ready.remote()):
#                     print("SYNC BNS: worker #",worker_index," is pulling bns from ps ")
#                     ps_wei = ray.get(ps.pull_weights.remote())
#                     model.load_state_dict(ps_wei)
#                     sync_bns_flag = False
#             if local_step % args.sync_bns == 0:
#                 sync_bns_flag = True
#                 model.cpu()
#                 if args.debug: print("SYNC BNS: goint to aggregate bns")
#                 wk_bns = [param.data for name,param in model.named_parameters() if 'bn' in name]
#                 bns_sync = ray.get(ps.aggregate_bns.remote(wk_bns,worker_index))
#                 print("SYNC BNS: bns of worker #",worker_index," have been pushed")
                
#                 if any(bns_sync) == False: # when all workers have pushed their own bns parameters to ps
#                     print("SYNC BNS: worker #",worker_index," is last worker pushed its bns")
#                     ps_wei = ray.get(ps.pull_weights.remote())
#                     model.load_state_dict(ps_wei)
#                     sync_bns_flag = False
#                 if args.cuda: model.cuda()
            
                    
                
                
                
            local_step += 1
            if batch_idx % args.log_interval == 0:
                print('The {} worker, Train Epoch: {} [{}/{} ({:.1f}%)]\tLoss: {:.6f}'.format(
                worker_index, epoch, batch_idx * len(data), len(train_loader.dataset),
                100. * batch_idx / len(train_loader), loss.data))
                
                for name,param in model.named_parameters():
                    wk_writer.add_histogram(name, param, local_step)

                wk_writer.add_scalar("Loss/worker_train",loss,local_step)
                wk_writer.add_scalar("Accuracy/worker_train",batch_correct.float()/len(data),local_step)
                
        print("The {} worker finished its {} epoch with loss: {} and accuracy: {}".format(
            worker_index,
            epoch,
            avg_loss / float(len(train_loader.dataset)),
            train_correct.float() / float(len(train_loader.dataset))
        ))

# %%
parser = argparse.ArgumentParser(description='Distributed SSP CIFAR-10 Restnet train with network slimming')
parser.add_argument('--ray-master',type=str,default='127.0.0.1')
parser.add_argument('--redis-port',type=str,default='6379')
parser.add_argument('--batch-size',type=int,default=64)
parser.add_argument('--test-batch-size', type=int, default=64)
parser.add_argument('--epochs', type=int, default=160)
parser.add_argument('--start-epoch', default=0, type=int)
parser.add_argument('--lr', type=float, default=0.1)
parser.add_argument('--momentum', type=float, default=0.9)
parser.add_argument('--weight-decay', '--wd', default=1e-4, type=float)
parser.add_argument('--resume', default=None, type=str) 
parser.add_argument('--no-cuda', action='store_true', default=False)
parser.add_argument('--save', default='./logs', type=str)
parser.add_argument('--depth', default=20, type=int)
parser.add_argument('--tb-path', default='./logs', type=str)
parser.add_argument('--log-interval', type=int, default=100)
parser.add_argument('--num-workers',type=int,default=1)
parser.add_argument('--stalness-limit',type=int,default=5)
parser.add_argument('--debug',action='store_true',default=False)
parser.add_argument('--sync-bns',type=int, default=194)

args = parser.parse_args(args=['--num-workers=3','--tb-path=logs_part_bns_20','--save=logs_part_bns_20','--resume=/userhome/34/gyu/logs_part_bns_20/checkpoint.pth.tar'])
# '--resume=/userhome/34/gyu/logs/checkpoint.pth.tar'
# '--tb-path=logs_no_bns','--save=logs_no_bns'

args.cuda = not args.no_cuda and torch.cuda.is_available()

# %%
if ray.is_initialized():
    ray.shutdown()

# %%
ray.init(address=args.ray_master+':'+args.redis_port)
# Out:
# {'node_ip_address': '10.21.5.172',
#  'redis_address': '10.21.5.172:6379',
#  'object_store_address': '/tmp/ray/session_2019-12-06_14-17-14_956560_1309/sockets/plasma_store',
#  'raylet_socket_name': '/tmp/ray/session_2019-12-06_14-17-14_956560_1309/sockets/raylet',
#  'webui_url': 'http://10.21.5.172:8080/?token=0a0f5577181eb8b4c7f82b663dce64a4c8a28d43b0a3d220',
#  'session_dir': '/tmp/ray/session_2019-12-06_14-17-14_956560_1309'}

# %%
kwargs = {'num_workers': 1, 'pin_memory': True} if args.cuda else {}

test_loader = generate_test_loader(args.test_batch_size)
train_loaders = [generate_train_loader(args.batch_size,kwargs) for _ in range(args.num_workers)]

resume_from_ckpt = args.resume if (args.resume and os.path.isfile(args.resume)) else None

ps = ParameterServer.remote(args,test_loader)
# Out:
# Files already downloaded and verified
# Files already downloaded and verified
# Files already downloaded and verified
# (pid=15162, ip=10.21.5.174) /userhome/34/gyu/anaconda3/envs/pytorch_env/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:541: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=15162, ip=10.21.5.174)   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# (pid=15162, ip=10.21.5.174) /userhome/34/gyu/anaconda3/envs/pytorch_env/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:542: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=15162, ip=10.21.5.174)   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# (pid=15162, ip=10.21.5.174) /userhome/34/gyu/anaconda3/envs/pytorch_env/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:543: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=15162, ip=10.21.5.174)   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# (pid=15162, ip=10.21.5.174) /userhome/34/gyu/anaconda3/envs/pytorch_env/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:544: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=15162, ip=10.21.5.174)   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# (pid=15162, ip=10.21.5.174) /userhome/34/gyu/anaconda3/envs/pytorch_env/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:545: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=15162, ip=10.21.5.174)   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# (pid=15162, ip=10.21.5.174) /userhome/34/gyu/anaconda3/envs/pytorch_env/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:550: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=15162, ip=10.21.5.174)   np_resource = np.dtype([("resource", np.ubyte, 1)])
# (pid=15162, ip=10.21.5.174) => loading checkpoint '/userhome/34/gyu/logs_part_bns_20/checkpoint.pth.tar'
# (pid=15162, ip=10.21.5.174) => loaded checkpoint '/userhome/34/gyu/logs_part_bns_20/checkpoint.pth.tar' (global step: 9000)
# (pid=15162, ip=10.21.5.174) epoch: 3

# %%
worker_tasks = [worker_task.remote(args,ps,idx,train_loaders[idx]) for idx in range(args.num_workers)]
# Out:
# (pid=15158, ip=10.21.5.174) /userhome/34/gyu/anaconda3/envs/pytorch_env/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:541: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=15158, ip=10.21.5.174)   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# (pid=15158, ip=10.21.5.174) /userhome/34/gyu/anaconda3/envs/pytorch_env/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:542: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=15158, ip=10.21.5.174)   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# (pid=15158, ip=10.21.5.174) /userhome/34/gyu/anaconda3/envs/pytorch_env/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:543: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=15158, ip=10.21.5.174)   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# (pid=15158, ip=10.21.5.174) /userhome/34/gyu/anaconda3/envs/pytorch_env/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:544: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=15158, ip=10.21.5.174)   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# (pid=15158, ip=10.21.5.174) /userhome/34/gyu/anaconda3/envs/pytorch_env/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:545: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=15158, ip=10.21.5.174)   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# (pid=15158, ip=10.21.5.174) /userhome/34/gyu/anaconda3/envs/pytorch_env/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:550: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=15158, ip=10.21.5.174)   np_resource = np.dtype([("resource", np.ubyte, 1)])
# (pid=15161, ip=10.21.5.174) /userhome/34/gyu/anaconda3/envs/pytorch_env/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:541: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=15161, ip=10.21.5.174)   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# (pid=15161, ip=10.21.5.174) /userhome/34/gyu/anaconda3/envs/pytorch_env/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:542: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=15161, ip=10.21.5.174)   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# (pid=15161, ip=10.21.5.174) /userhome/34/gyu/anaconda3/envs/pytorch_env/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:543: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=15161, ip=10.21.5.174)   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# (pid=15161, ip=10.21.5.174) /userhome/34/gyu/anaconda3/envs/pytorch_env/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:544: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=15161, ip=10.21.5.174)   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# (pid=15161, ip=10.21.5.174) /userhome/34/gyu/anaconda3/envs/pytorch_env/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:545: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=15161, ip=10.21.5.174)   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# (pid=15161, ip=10.21.5.174) /userhome/34/gyu/anaconda3/envs/pytorch_env/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:550: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=15161, ip=10.21.5.174)   np_resource = np.dtype([("resource", np.ubyte, 1)])
# (pid=15160, ip=10.21.5.174) /userhome/34/gyu/anaconda3/envs/pytorch_env/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:541: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=15160, ip=10.21.5.174)   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# (pid=15160, ip=10.21.5.174) /userhome/34/gyu/anaconda3/envs/pytorch_env/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:542: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=15160, ip=10.21.5.174)   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# (pid=15160, ip=10.21.5.174) /userhome/34/gyu/anaconda3/envs/pytorch_env/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:543: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=15160, ip=10.21.5.174)   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# (pid=15160, ip=10.21.5.174) /userhome/34/gyu/anaconda3/envs/pytorch_env/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:544: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=15160, ip=10.21.5.174)   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# (pid=15160, ip=10.21.5.174) /userhome/34/gyu/anaconda3/envs/pytorch_env/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:545: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=15160, ip=10.21.5.174)   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# (pid=15160, ip=10.21.5.174) /userhome/34/gyu/anaconda3/envs/pytorch_env/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:550: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=15160, ip=10.21.5.174)   np_resource = np.dtype([("resource", np.ubyte, 1)])
# (pid=15157, ip=10.21.5.174) /userhome/34/gyu/anaconda3/envs/pytorch_env/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:541: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=15157, ip=10.21.5.174)   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# (pid=15157, ip=10.21.5.174) /userhome/34/gyu/anaconda3/envs/pytorch_env/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:542: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=15157, ip=10.21.5.174)   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# (pid=15157, ip=10.21.5.174) /userhome/34/gyu/anaconda3/envs/pytorch_env/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:543: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=15157, ip=10.21.5.174)   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# (pid=15157, ip=10.21.5.174) /userhome/34/gyu/anaconda3/envs/pytorch_env/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:544: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=15157, ip=10.21.5.174)   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# (pid=15157, ip=10.21.5.174) /userhome/34/gyu/anaconda3/envs/pytorch_env/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:545: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=15157, ip=10.21.5.174)   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# (pid=15157, ip=10.21.5.174) /userhome/34/gyu/anaconda3/envs/pytorch_env/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:550: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=15157, ip=10.21.5.174)   np_resource = np.dtype([("resource", np.ubyte, 1)])
# (pid=15159, ip=10.21.5.174) /userhome/34/gyu/anaconda3/envs/pytorch_env/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:541: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=15159, ip=10.21.5.174)   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# (pid=15159, ip=10.21.5.174) /userhome/34/gyu/anaconda3/envs/pytorch_env/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:542: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=15159, ip=10.21.5.174)   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# (pid=15159, ip=10.21.5.174) /userhome/34/gyu/anaconda3/envs/pytorch_env/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:543: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=15159, ip=10.21.5.174)   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# (pid=15159, ip=10.21.5.174) /userhome/34/gyu/anaconda3/envs/pytorch_env/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:544: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=15159, ip=10.21.5.174)   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# (pid=15159, ip=10.21.5.174) /userhome/34/gyu/anaconda3/envs/pytorch_env/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:545: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=15159, ip=10.21.5.174)   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# (pid=15159, ip=10.21.5.174) /userhome/34/gyu/anaconda3/envs/pytorch_env/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:550: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=15159, ip=10.21.5.174)   np_resource = np.dtype([("resource", np.ubyte, 1)])
# (pid=15163, ip=10.21.5.174) /userhome/34/gyu/anaconda3/envs/pytorch_env/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:541: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=15163, ip=10.21.5.174)   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# (pid=15163, ip=10.21.5.174) /userhome/34/gyu/anaconda3/envs/pytorch_env/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:542: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=15163, ip=10.21.5.174)   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# (pid=15163, ip=10.21.5.174) /userhome/34/gyu/anaconda3/envs/pytorch_env/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:543: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=15163, ip=10.21.5.174)   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# (pid=15163, ip=10.21.5.174) /userhome/34/gyu/anaconda3/envs/pytorch_env/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:544: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=15163, ip=10.21.5.174)   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# (pid=15163, ip=10.21.5.174) /userhome/34/gyu/anaconda3/envs/pytorch_env/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:545: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=15163, ip=10.21.5.174)   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# (pid=15163, ip=10.21.5.174) /userhome/34/gyu/anaconda3/envs/pytorch_env/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:550: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=15163, ip=10.21.5.174)   np_resource = np.dtype([("resource", np.ubyte, 1)])
# (pid=15156, ip=10.21.5.174) /userhome/34/gyu/anaconda3/envs/pytorch_env/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:541: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=15156, ip=10.21.5.174)   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# (pid=15156, ip=10.21.5.174) /userhome/34/gyu/anaconda3/envs/pytorch_env/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:542: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=15156, ip=10.21.5.174)   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# (pid=15156, ip=10.21.5.174) /userhome/34/gyu/anaconda3/envs/pytorch_env/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:543: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=15156, ip=10.21.5.174)   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# (pid=15156, ip=10.21.5.174) /userhome/34/gyu/anaconda3/envs/pytorch_env/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:544: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=15156, ip=10.21.5.174)   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# (pid=15156, ip=10.21.5.174) /userhome/34/gyu/anaconda3/envs/pytorch_env/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:545: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=15156, ip=10.21.5.174)   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# (pid=15156, ip=10.21.5.174) /userhome/34/gyu/anaconda3/envs/pytorch_env/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:550: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=15156, ip=10.21.5.174)   np_resource = np.dtype([("resource", np.ubyte, 1)])
# (pid=16069, ip=10.21.5.173) /userhome/34/gyu/anaconda3/envs/pytorch_env/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:541: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=16069, ip=10.21.5.173)   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# (pid=16069, ip=10.21.5.173) /userhome/34/gyu/anaconda3/envs/pytorch_env/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:542: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=16069, ip=10.21.5.173)   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# (pid=16069, ip=10.21.5.173) /userhome/34/gyu/anaconda3/envs/pytorch_env/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:543: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=16069, ip=10.21.5.173)   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# (pid=16069, ip=10.21.5.173) /userhome/34/gyu/anaconda3/envs/pytorch_env/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:544: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=16069, ip=10.21.5.173)   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# (pid=16069, ip=10.21.5.173) /userhome/34/gyu/anaconda3/envs/pytorch_env/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:545: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=16069, ip=10.21.5.173)   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# (pid=16069, ip=10.21.5.173) /userhome/34/gyu/anaconda3/envs/pytorch_env/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:550: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=16069, ip=10.21.5.173)   np_resource = np.dtype([("resource", np.ubyte, 1)])
# (pid=16072, ip=10.21.5.173) /userhome/34/gyu/anaconda3/envs/pytorch_env/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:541: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=16072, ip=10.21.5.173)   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# (pid=16072, ip=10.21.5.173) /userhome/34/gyu/anaconda3/envs/pytorch_env/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:542: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=16072, ip=10.21.5.173)   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# (pid=16072, ip=10.21.5.173) /userhome/34/gyu/anaconda3/envs/pytorch_env/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:543: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=16072, ip=10.21.5.173)   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# (pid=16072, ip=10.21.5.173) /userhome/34/gyu/anaconda3/envs/pytorch_env/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:544: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=16072, ip=10.21.5.173)   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# (pid=16072, ip=10.21.5.173) /userhome/34/gyu/anaconda3/envs/pytorch_env/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:545: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=16072, ip=10.21.5.173)   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# (pid=16072, ip=10.21.5.173) /userhome/34/gyu/anaconda3/envs/pytorch_env/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:550: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=16072, ip=10.21.5.173)   np_resource = np.dtype([("resource", np.ubyte, 1)])
# (pid=16070, ip=10.21.5.173) /userhome/34/gyu/anaconda3/envs/pytorch_env/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:541: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=16070, ip=10.21.5.173)   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# (pid=16070, ip=10.21.5.173) /userhome/34/gyu/anaconda3/envs/pytorch_env/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:542: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=16070, ip=10.21.5.173)   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# (pid=16070, ip=10.21.5.173) /userhome/34/gyu/anaconda3/envs/pytorch_env/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:543: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=16070, ip=10.21.5.173)   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# (pid=16070, ip=10.21.5.173) /userhome/34/gyu/anaconda3/envs/pytorch_env/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:544: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=16070, ip=10.21.5.173)   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# (pid=16070, ip=10.21.5.173) /userhome/34/gyu/anaconda3/envs/pytorch_env/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:545: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=16070, ip=10.21.5.173)   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# (pid=16070, ip=10.21.5.173) /userhome/34/gyu/anaconda3/envs/pytorch_env/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:550: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=16070, ip=10.21.5.173)   np_resource = np.dtype([("resource", np.ubyte, 1)])
# (pid=16074, ip=10.21.5.173) /userhome/34/gyu/anaconda3/envs/pytorch_env/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:541: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=16074, ip=10.21.5.173)   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# (pid=16074, ip=10.21.5.173) /userhome/34/gyu/anaconda3/envs/pytorch_env/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:542: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=16074, ip=10.21.5.173)   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# (pid=16074, ip=10.21.5.173) /userhome/34/gyu/anaconda3/envs/pytorch_env/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:543: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=16074, ip=10.21.5.173)   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# (pid=16074, ip=10.21.5.173) /userhome/34/gyu/anaconda3/envs/pytorch_env/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:544: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=16074, ip=10.21.5.173)   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# (pid=16074, ip=10.21.5.173) /userhome/34/gyu/anaconda3/envs/pytorch_env/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:545: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=16074, ip=10.21.5.173)   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# (pid=16074, ip=10.21.5.173) /userhome/34/gyu/anaconda3/envs/pytorch_env/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:550: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=16074, ip=10.21.5.173)   np_resource = np.dtype([("resource", np.ubyte, 1)])
# (pid=16076, ip=10.21.5.173) /userhome/34/gyu/anaconda3/envs/pytorch_env/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:541: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=16076, ip=10.21.5.173)   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# (pid=16076, ip=10.21.5.173) /userhome/34/gyu/anaconda3/envs/pytorch_env/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:542: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=16076, ip=10.21.5.173)   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# (pid=16076, ip=10.21.5.173) /userhome/34/gyu/anaconda3/envs/pytorch_env/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:543: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=16076, ip=10.21.5.173)   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# (pid=16076, ip=10.21.5.173) /userhome/34/gyu/anaconda3/envs/pytorch_env/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:544: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=16076, ip=10.21.5.173)   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# (pid=16076, ip=10.21.5.173) /userhome/34/gyu/anaconda3/envs/pytorch_env/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:545: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=16076, ip=10.21.5.173)   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# (pid=16076, ip=10.21.5.173) /userhome/34/gyu/anaconda3/envs/pytorch_env/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:550: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=16076, ip=10.21.5.173)   np_resource = np.dtype([("resource", np.ubyte, 1)])
# (pid=16073, ip=10.21.5.173) /userhome/34/gyu/anaconda3/envs/pytorch_env/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:541: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=16073, ip=10.21.5.173)   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# (pid=16073, ip=10.21.5.173) /userhome/34/gyu/anaconda3/envs/pytorch_env/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:542: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=16073, ip=10.21.5.173)   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# (pid=16073, ip=10.21.5.173) /userhome/34/gyu/anaconda3/envs/pytorch_env/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:543: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=16073, ip=10.21.5.173)   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# (pid=16073, ip=10.21.5.173) /userhome/34/gyu/anaconda3/envs/pytorch_env/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:544: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=16073, ip=10.21.5.173)   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# (pid=16073, ip=10.21.5.173) /userhome/34/gyu/anaconda3/envs/pytorch_env/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:545: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=16073, ip=10.21.5.173)   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# (pid=16073, ip=10.21.5.173) /userhome/34/gyu/anaconda3/envs/pytorch_env/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:550: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=16073, ip=10.21.5.173)   np_resource = np.dtype([("resource", np.ubyte, 1)])
# (pid=16071, ip=10.21.5.173) /userhome/34/gyu/anaconda3/envs/pytorch_env/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:541: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=16071, ip=10.21.5.173)   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# (pid=16071, ip=10.21.5.173) /userhome/34/gyu/anaconda3/envs/pytorch_env/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:542: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=16071, ip=10.21.5.173)   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# (pid=16071, ip=10.21.5.173) /userhome/34/gyu/anaconda3/envs/pytorch_env/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:543: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=16071, ip=10.21.5.173)   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# (pid=16071, ip=10.21.5.173) /userhome/34/gyu/anaconda3/envs/pytorch_env/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:544: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=16071, ip=10.21.5.173)   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# (pid=16071, ip=10.21.5.173) /userhome/34/gyu/anaconda3/envs/pytorch_env/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:545: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=16071, ip=10.21.5.173)   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# (pid=16071, ip=10.21.5.173) /userhome/34/gyu/anaconda3/envs/pytorch_env/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:550: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=16071, ip=10.21.5.173)   np_resource = np.dtype([("resource", np.ubyte, 1)])
# (pid=16075, ip=10.21.5.173) /userhome/34/gyu/anaconda3/envs/pytorch_env/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:541: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=16075, ip=10.21.5.173)   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# (pid=16075, ip=10.21.5.173) /userhome/34/gyu/anaconda3/envs/pytorch_env/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:542: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=16075, ip=10.21.5.173)   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# (pid=16075, ip=10.21.5.173) /userhome/34/gyu/anaconda3/envs/pytorch_env/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:543: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=16075, ip=10.21.5.173)   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# (pid=16075, ip=10.21.5.173) /userhome/34/gyu/anaconda3/envs/pytorch_env/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:544: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=16075, ip=10.21.5.173)   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# (pid=16075, ip=10.21.5.173) /userhome/34/gyu/anaconda3/envs/pytorch_env/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:545: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=16075, ip=10.21.5.173)   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# (pid=16075, ip=10.21.5.173) /userhome/34/gyu/anaconda3/envs/pytorch_env/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:550: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=16075, ip=10.21.5.173)   np_resource = np.dtype([("resource", np.ubyte, 1)])
# (pid=1344) /userhome/34/gyu/anaconda3/envs/pytorch_env/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:541: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=1344)   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# (pid=1344) /userhome/34/gyu/anaconda3/envs/pytorch_env/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:542: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=1344)   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# (pid=1344) /userhome/34/gyu/anaconda3/envs/pytorch_env/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:543: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=1344)   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# (pid=1344) /userhome/34/gyu/anaconda3/envs/pytorch_env/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:544: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=1344)   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# (pid=1344) /userhome/34/gyu/anaconda3/envs/pytorch_env/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:545: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=1344)   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# (pid=1344) /userhome/34/gyu/anaconda3/envs/pytorch_env/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:550: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=1344)   np_resource = np.dtype([("resource", np.ubyte, 1)])
# (pid=1343) /userhome/34/gyu/anaconda3/envs/pytorch_env/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:541: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=1343)   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# (pid=1343) /userhome/34/gyu/anaconda3/envs/pytorch_env/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:542: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=1343)   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# (pid=1343) /userhome/34/gyu/anaconda3/envs/pytorch_env/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:543: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=1343)   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# (pid=1343) /userhome/34/gyu/anaconda3/envs/pytorch_env/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:544: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=1343)   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# (pid=1343) /userhome/34/gyu/anaconda3/envs/pytorch_env/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:545: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=1343)   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# (pid=1343) /userhome/34/gyu/anaconda3/envs/pytorch_env/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:550: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=1343)   np_resource = np.dtype([("resource", np.ubyte, 1)])
# (pid=1341) /userhome/34/gyu/anaconda3/envs/pytorch_env/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:541: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=1341)   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# (pid=1341) /userhome/34/gyu/anaconda3/envs/pytorch_env/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:542: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=1341)   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# (pid=1341) /userhome/34/gyu/anaconda3/envs/pytorch_env/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:543: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=1341)   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# (pid=1341) /userhome/34/gyu/anaconda3/envs/pytorch_env/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:544: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=1341)   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# (pid=1341) /userhome/34/gyu/anaconda3/envs/pytorch_env/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:545: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=1341)   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# (pid=1341) /userhome/34/gyu/anaconda3/envs/pytorch_env/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:550: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=1341)   np_resource = np.dtype([("resource", np.ubyte, 1)])
# (pid=1338) /userhome/34/gyu/anaconda3/envs/pytorch_env/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:541: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=1338)   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# (pid=1338) /userhome/34/gyu/anaconda3/envs/pytorch_env/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:542: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=1338)   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# (pid=1338) /userhome/34/gyu/anaconda3/envs/pytorch_env/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:543: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=1338)   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# (pid=1338) /userhome/34/gyu/anaconda3/envs/pytorch_env/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:544: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=1338)   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# (pid=1338) /userhome/34/gyu/anaconda3/envs/pytorch_env/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:545: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=1338)   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# (pid=1338) /userhome/34/gyu/anaconda3/envs/pytorch_env/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:550: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=1338)   np_resource = np.dtype([("resource", np.ubyte, 1)])
# (pid=1342) /userhome/34/gyu/anaconda3/envs/pytorch_env/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:541: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=1342)   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# (pid=1342) /userhome/34/gyu/anaconda3/envs/pytorch_env/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:542: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=1342)   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# (pid=1342) /userhome/34/gyu/anaconda3/envs/pytorch_env/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:543: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=1342)   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# (pid=1342) /userhome/34/gyu/anaconda3/envs/pytorch_env/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:544: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=1342)   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# (pid=1342) /userhome/34/gyu/anaconda3/envs/pytorch_env/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:545: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=1342)   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# (pid=1342) /userhome/34/gyu/anaconda3/envs/pytorch_env/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:550: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=1342)   np_resource = np.dtype([("resource", np.ubyte, 1)])
# (pid=1340) /userhome/34/gyu/anaconda3/envs/pytorch_env/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:541: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=1340)   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# (pid=1340) /userhome/34/gyu/anaconda3/envs/pytorch_env/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:542: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=1340)   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# (pid=1340) /userhome/34/gyu/anaconda3/envs/pytorch_env/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:543: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=1340)   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# (pid=1340) /userhome/34/gyu/anaconda3/envs/pytorch_env/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:544: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=1340)   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# (pid=1340) /userhome/34/gyu/anaconda3/envs/pytorch_env/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:545: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=1340)   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# (pid=1340) /userhome/34/gyu/anaconda3/envs/pytorch_env/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:550: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=1340)   np_resource = np.dtype([("resource", np.ubyte, 1)])
# (pid=1339) /userhome/34/gyu/anaconda3/envs/pytorch_env/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:541: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=1339)   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# (pid=1339) /userhome/34/gyu/anaconda3/envs/pytorch_env/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:542: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=1339)   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# (pid=1339) /userhome/34/gyu/anaconda3/envs/pytorch_env/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:543: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=1339)   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# (pid=1339) /userhome/34/gyu/anaconda3/envs/pytorch_env/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:544: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=1339)   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# (pid=1339) /userhome/34/gyu/anaconda3/envs/pytorch_env/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:545: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=1339)   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# (pid=1339) /userhome/34/gyu/anaconda3/envs/pytorch_env/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:550: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=1339)   np_resource = np.dtype([("resource", np.ubyte, 1)])
# (pid=1337) /userhome/34/gyu/anaconda3/envs/pytorch_env/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:541: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=1337)   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# (pid=1337) /userhome/34/gyu/anaconda3/envs/pytorch_env/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:542: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=1337)   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# (pid=1337) /userhome/34/gyu/anaconda3/envs/pytorch_env/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:543: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=1337)   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# (pid=1337) /userhome/34/gyu/anaconda3/envs/pytorch_env/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:544: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=1337)   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# (pid=1337) /userhome/34/gyu/anaconda3/envs/pytorch_env/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:545: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=1337)   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# (pid=1337) /userhome/34/gyu/anaconda3/envs/pytorch_env/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:550: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=1337)   np_resource = np.dtype([("resource", np.ubyte, 1)])
# (pid=1340) worker # 0  is online
# (pid=1340) The 0 worker, Train Epoch: 3 [0/50000 (0.0%)]	Loss: 0.368551

# %%
print(1)
# Out:
# 1
# (pid=15161, ip=10.21.5.174) worker # 1  is online
# (pid=15161, ip=10.21.5.174) The 1 worker, Train Epoch: 3 [0/50000 (0.0%)]	Loss: 0.420468
# (pid=16075, ip=10.21.5.173) worker # 2  is online
# (pid=16075, ip=10.21.5.173) The 2 worker, Train Epoch: 3 [0/50000 (0.0%)]	Loss: 0.524599
# (pid=15161, ip=10.21.5.174) The 1 worker, Train Epoch: 3 [6400/50000 (12.8%)]	Loss: 0.380609
# (pid=1340) The 0 worker, Train Epoch: 3 [6400/50000 (12.8%)]	Loss: 0.422478
# (pid=16075, ip=10.21.5.173) The 2 worker, Train Epoch: 3 [6400/50000 (12.8%)]	Loss: 0.317502
# (pid=1340) The 0 worker, Train Epoch: 3 [12800/50000 (25.6%)]	Loss: 0.605353
# (pid=16075, ip=10.21.5.173) The 2 worker, Train Epoch: 3 [12800/50000 (25.6%)]	Loss: 0.352667
# (pid=15161, ip=10.21.5.174) The 1 worker, Train Epoch: 3 [12800/50000 (25.6%)]	Loss: 0.542702
# (pid=1340) The 0 worker, Train Epoch: 3 [19200/50000 (38.4%)]	Loss: 0.314719
# (pid=16075, ip=10.21.5.173) The 2 worker, Train Epoch: 3 [19200/50000 (38.4%)]	Loss: 0.489712
# (pid=15161, ip=10.21.5.174) The 1 worker, Train Epoch: 3 [19200/50000 (38.4%)]	Loss: 0.528145
# (pid=16075, ip=10.21.5.173) The 2 worker, Train Epoch: 3 [25600/50000 (51.2%)]	Loss: 0.488341
# (pid=1340) The 0 worker, Train Epoch: 3 [25600/50000 (51.2%)]	Loss: 0.436847
# (pid=15161, ip=10.21.5.174) The 1 worker, Train Epoch: 3 [25600/50000 (51.2%)]	Loss: 0.345269
# (pid=16075, ip=10.21.5.173) The 2 worker, Train Epoch: 3 [32000/50000 (63.9%)]	Loss: 0.422411
# (pid=1340) The 0 worker, Train Epoch: 3 [32000/50000 (63.9%)]	Loss: 0.573815
# (pid=15161, ip=10.21.5.174) The 1 worker, Train Epoch: 3 [32000/50000 (63.9%)]	Loss: 0.384040
# (pid=1340) The 0 worker, Train Epoch: 3 [38400/50000 (76.7%)]	Loss: 0.617925
# (pid=16075, ip=10.21.5.173) The 2 worker, Train Epoch: 3 [38400/50000 (76.7%)]	Loss: 0.402654
# (pid=15161, ip=10.21.5.174) The 1 worker, Train Epoch: 3 [38400/50000 (76.7%)]	Loss: 0.361125
# (pid=16075, ip=10.21.5.173) The 2 worker, Train Epoch: 3 [44800/50000 (89.5%)]	Loss: 0.432056
# (pid=1340) The 0 worker, Train Epoch: 3 [44800/50000 (89.5%)]	Loss: 0.604439
# (pid=15161, ip=10.21.5.174) The 1 worker, Train Epoch: 3 [44800/50000 (89.5%)]	Loss: 0.400832
# (pid=1340) The 0 worker finished its 3 epoch with loss: 0.007567496970295906 and accuracy: 0.8320199847221375
# (pid=16075, ip=10.21.5.173) The 2 worker finished its 3 epoch with loss: 0.007447124924510717 and accuracy: 0.8354799747467041
# (pid=1340) The 0 worker, Train Epoch: 4 [0/50000 (0.0%)]	Loss: 0.261788
# (pid=16075, ip=10.21.5.173) The 2 worker, Train Epoch: 4 [0/50000 (0.0%)]	Loss: 0.271689
# (pid=15161, ip=10.21.5.174) The 1 worker finished its 3 epoch with loss: 0.007489181123673916 and accuracy: 0.8330199718475342
# (pid=15161, ip=10.21.5.174) The 1 worker, Train Epoch: 4 [0/50000 (0.0%)]	Loss: 0.723675
# (pid=16075, ip=10.21.5.173) The 2 worker, Train Epoch: 4 [6400/50000 (12.8%)]	Loss: 0.520324
# (pid=15161, ip=10.21.5.174) The 1 worker, Train Epoch: 4 [6400/50000 (12.8%)]	Loss: 0.494454
# (pid=1340) The 0 worker, Train Epoch: 4 [6400/50000 (12.8%)]	Loss: 0.404497
# (pid=16075, ip=10.21.5.173) The 2 worker, Train Epoch: 4 [12800/50000 (25.6%)]	Loss: 0.493273
# (pid=1340) The 0 worker, Train Epoch: 4 [12800/50000 (25.6%)]	Loss: 0.387352
# (pid=15161, ip=10.21.5.174) The 1 worker, Train Epoch: 4 [12800/50000 (25.6%)]	Loss: 0.314408
# (pid=1340) The 0 worker, Train Epoch: 4 [19200/50000 (38.4%)]	Loss: 0.433889
# (pid=16075, ip=10.21.5.173) The 2 worker, Train Epoch: 4 [19200/50000 (38.4%)]	Loss: 0.398903
# (pid=15161, ip=10.21.5.174) The 1 worker, Train Epoch: 4 [19200/50000 (38.4%)]	Loss: 0.318818
# (pid=16075, ip=10.21.5.173) The 2 worker, Train Epoch: 4 [25600/50000 (51.2%)]	Loss: 0.420664
# (pid=1340) The 0 worker, Train Epoch: 4 [25600/50000 (51.2%)]	Loss: 0.306163
# (pid=15161, ip=10.21.5.174) The 1 worker, Train Epoch: 4 [25600/50000 (51.2%)]	Loss: 0.543323
# (pid=16075, ip=10.21.5.173) The 2 worker, Train Epoch: 4 [32000/50000 (63.9%)]	Loss: 0.448458
# (pid=1340) The 0 worker, Train Epoch: 4 [32000/50000 (63.9%)]	Loss: 0.662388
# (pid=15161, ip=10.21.5.174) The 1 worker, Train Epoch: 4 [32000/50000 (63.9%)]	Loss: 0.375194
# (pid=16075, ip=10.21.5.173) The 2 worker, Train Epoch: 4 [38400/50000 (76.7%)]	Loss: 0.411773
# (pid=15161, ip=10.21.5.174) The 1 worker, Train Epoch: 4 [38400/50000 (76.7%)]	Loss: 0.398410
# (pid=1340) The 0 worker, Train Epoch: 4 [38400/50000 (76.7%)]	Loss: 0.404660
# (pid=16075, ip=10.21.5.173) The 2 worker, Train Epoch: 4 [44800/50000 (89.5%)]	Loss: 0.400863
# (pid=1340) The 0 worker, Train Epoch: 4 [44800/50000 (89.5%)]	Loss: 0.245509
# (pid=15161, ip=10.21.5.174) The 1 worker, Train Epoch: 4 [44800/50000 (89.5%)]	Loss: 0.324670
# (pid=1340) The 0 worker finished its 4 epoch with loss: 0.007000210229307413 and accuracy: 0.8453800082206726
# (pid=1340) The 0 worker, Train Epoch: 5 [0/50000 (0.0%)]	Loss: 0.357432
# (pid=16075, ip=10.21.5.173) The 2 worker finished its 4 epoch with loss: 0.006930743344128132 and accuracy: 0.8468999862670898
# (pid=15161, ip=10.21.5.174) The 1 worker finished its 4 epoch with loss: 0.006948463618755341 and accuracy: 0.8463600277900696
# (pid=16075, ip=10.21.5.173) The 2 worker, Train Epoch: 5 [0/50000 (0.0%)]	Loss: 0.350027
# (pid=15161, ip=10.21.5.174) The 1 worker, Train Epoch: 5 [0/50000 (0.0%)]	Loss: 0.380715
# (pid=1340) The 0 worker, Train Epoch: 5 [6400/50000 (12.8%)]	Loss: 0.349701
# (pid=16075, ip=10.21.5.173) The 2 worker, Train Epoch: 5 [6400/50000 (12.8%)]	Loss: 0.519977
# (pid=15161, ip=10.21.5.174) The 1 worker, Train Epoch: 5 [6400/50000 (12.8%)]	Loss: 0.289194
# (pid=1340) The 0 worker, Train Epoch: 5 [12800/50000 (25.6%)]	Loss: 0.569288
# (pid=16075, ip=10.21.5.173) The 2 worker, Train Epoch: 5 [12800/50000 (25.6%)]	Loss: 0.437036
# (pid=15161, ip=10.21.5.174) The 1 worker, Train Epoch: 5 [12800/50000 (25.6%)]	Loss: 0.382744
# (pid=16075, ip=10.21.5.173) The 2 worker, Train Epoch: 5 [19200/50000 (38.4%)]	Loss: 0.331104
# (pid=1340) The 0 worker, Train Epoch: 5 [19200/50000 (38.4%)]	Loss: 0.406111
# (pid=15161, ip=10.21.5.174) The 1 worker, Train Epoch: 5 [19200/50000 (38.4%)]	Loss: 0.674787
# (pid=1340) The 0 worker, Train Epoch: 5 [25600/50000 (51.2%)]	Loss: 0.263479
# (pid=16075, ip=10.21.5.173) The 2 worker, Train Epoch: 5 [25600/50000 (51.2%)]	Loss: 0.339620
# (pid=15161, ip=10.21.5.174) The 1 worker, Train Epoch: 5 [25600/50000 (51.2%)]	Loss: 0.779337
# (pid=1340) The 0 worker, Train Epoch: 5 [32000/50000 (63.9%)]	Loss: 0.472607
# (pid=16075, ip=10.21.5.173) The 2 worker, Train Epoch: 5 [32000/50000 (63.9%)]	Loss: 0.430008
# (pid=15161, ip=10.21.5.174) The 1 worker, Train Epoch: 5 [32000/50000 (63.9%)]	Loss: 0.441846
# (pid=15161, ip=10.21.5.174) The 1 worker, Train Epoch: 5 [38400/50000 (76.7%)]	Loss: 0.447987
# (pid=1340) The 0 worker, Train Epoch: 5 [38400/50000 (76.7%)]	Loss: 0.263699
# (pid=16075, ip=10.21.5.173) The 2 worker, Train Epoch: 5 [38400/50000 (76.7%)]	Loss: 0.685110
# (pid=1340) The 0 worker, Train Epoch: 5 [44800/50000 (89.5%)]	Loss: 0.266564
# (pid=16075, ip=10.21.5.173) The 2 worker, Train Epoch: 5 [44800/50000 (89.5%)]	Loss: 0.793515
# (pid=15161, ip=10.21.5.174) The 1 worker, Train Epoch: 5 [44800/50000 (89.5%)]	Loss: 0.221542
# (pid=1340) The 0 worker finished its 5 epoch with loss: 0.0063696387223899364 and accuracy: 0.857420027256012
# (pid=16075, ip=10.21.5.173) The 2 worker finished its 5 epoch with loss: 0.006370026618242264 and accuracy: 0.8607199788093567
# (pid=15161, ip=10.21.5.174) The 1 worker finished its 5 epoch with loss: 0.006431235931813717 and accuracy: 0.85725998878479
# (pid=1340) The 0 worker, Train Epoch: 6 [0/50000 (0.0%)]	Loss: 0.445572
# (pid=16075, ip=10.21.5.173) The 2 worker, Train Epoch: 6 [0/50000 (0.0%)]	Loss: 0.432676
# (pid=15161, ip=10.21.5.174) The 1 worker, Train Epoch: 6 [0/50000 (0.0%)]	Loss: 0.497150
# (pid=16075, ip=10.21.5.173) The 2 worker, Train Epoch: 6 [6400/50000 (12.8%)]	Loss: 0.434914
# (pid=1340) The 0 worker, Train Epoch: 6 [6400/50000 (12.8%)]	Loss: 0.389258
# (pid=15161, ip=10.21.5.174) The 1 worker, Train Epoch: 6 [6400/50000 (12.8%)]	Loss: 0.436426
# (pid=16075, ip=10.21.5.173) The 2 worker, Train Epoch: 6 [12800/50000 (25.6%)]	Loss: 0.427428
# (pid=1340) The 0 worker, Train Epoch: 6 [12800/50000 (25.6%)]	Loss: 0.351203
# (pid=15161, ip=10.21.5.174) The 1 worker, Train Epoch: 6 [12800/50000 (25.6%)]	Loss: 0.234303
# (pid=16075, ip=10.21.5.173) The 2 worker, Train Epoch: 6 [19200/50000 (38.4%)]	Loss: 0.299505
# (pid=1340) The 0 worker, Train Epoch: 6 [19200/50000 (38.4%)]	Loss: 0.347673
# (pid=15161, ip=10.21.5.174) The 1 worker, Train Epoch: 6 [19200/50000 (38.4%)]	Loss: 0.598936
# (pid=16075, ip=10.21.5.173) The 2 worker, Train Epoch: 6 [25600/50000 (51.2%)]	Loss: 0.406161
# (pid=1340) The 0 worker, Train Epoch: 6 [25600/50000 (51.2%)]	Loss: 0.388395
# (pid=15161, ip=10.21.5.174) The 1 worker, Train Epoch: 6 [25600/50000 (51.2%)]	Loss: 0.349266
# (pid=1340) The 0 worker, Train Epoch: 6 [32000/50000 (63.9%)]	Loss: 0.478448
# (pid=16075, ip=10.21.5.173) The 2 worker, Train Epoch: 6 [32000/50000 (63.9%)]	Loss: 0.491922
# (pid=15161, ip=10.21.5.174) The 1 worker, Train Epoch: 6 [32000/50000 (63.9%)]	Loss: 0.206770
# (pid=1340) The 0 worker, Train Epoch: 6 [38400/50000 (76.7%)]	Loss: 0.309056
# (pid=16075, ip=10.21.5.173) The 2 worker, Train Epoch: 6 [38400/50000 (76.7%)]	Loss: 0.485043
# (pid=15161, ip=10.21.5.174) The 1 worker, Train Epoch: 6 [38400/50000 (76.7%)]	Loss: 0.231294
# (pid=16075, ip=10.21.5.173) The 2 worker, Train Epoch: 6 [44800/50000 (89.5%)]	Loss: 0.278489
# (pid=1340) The 0 worker, Train Epoch: 6 [44800/50000 (89.5%)]	Loss: 0.308911
# (pid=15161, ip=10.21.5.174) The 1 worker, Train Epoch: 6 [44800/50000 (89.5%)]	Loss: 0.661837
# (pid=16075, ip=10.21.5.173) The 2 worker finished its 6 epoch with loss: 0.005985818803310394 and accuracy: 0.8668000102043152
# (pid=16075, ip=10.21.5.173) The 2 worker, Train Epoch: 7 [0/50000 (0.0%)]	Loss: 0.253911
# (pid=1340) The 0 worker finished its 6 epoch with loss: 0.0059890770353376865 and accuracy: 0.8674200177192688
# (pid=1340) The 0 worker, Train Epoch: 7 [0/50000 (0.0%)]	Loss: 0.293685
# (pid=15161, ip=10.21.5.174) The 1 worker finished its 6 epoch with loss: 0.005908464081585407 and accuracy: 0.8682799935340881
# (pid=15161, ip=10.21.5.174) The 1 worker, Train Epoch: 7 [0/50000 (0.0%)]	Loss: 0.266535
# (pid=1340) The 0 worker, Train Epoch: 7 [6400/50000 (12.8%)]	Loss: 0.399980
# (pid=15161, ip=10.21.5.174) The 1 worker, Train Epoch: 7 [6400/50000 (12.8%)]	Loss: 0.304775
# (pid=16075, ip=10.21.5.173) The 2 worker, Train Epoch: 7 [6400/50000 (12.8%)]	Loss: 0.380484
# (pid=16075, ip=10.21.5.173) The 2 worker, Train Epoch: 7 [12800/50000 (25.6%)]	Loss: 0.336241
# (pid=1340) The 0 worker, Train Epoch: 7 [12800/50000 (25.6%)]	Loss: 0.469374
# (pid=15161, ip=10.21.5.174) The 1 worker, Train Epoch: 7 [12800/50000 (25.6%)]	Loss: 0.359442
# (pid=16075, ip=10.21.5.173) The 2 worker, Train Epoch: 7 [19200/50000 (38.4%)]	Loss: 0.349218
# (pid=1340) The 0 worker, Train Epoch: 7 [19200/50000 (38.4%)]	Loss: 0.292695
# (pid=15161, ip=10.21.5.174) The 1 worker, Train Epoch: 7 [19200/50000 (38.4%)]	Loss: 0.522017
# (pid=16075, ip=10.21.5.173) The 2 worker, Train Epoch: 7 [25600/50000 (51.2%)]	Loss: 0.211148
# (pid=1340) The 0 worker, Train Epoch: 7 [25600/50000 (51.2%)]	Loss: 0.451806
# (pid=15161, ip=10.21.5.174) The 1 worker, Train Epoch: 7 [25600/50000 (51.2%)]	Loss: 0.411964
# (pid=16075, ip=10.21.5.173) The 2 worker, Train Epoch: 7 [32000/50000 (63.9%)]	Loss: 0.417494
# (pid=1340) The 0 worker, Train Epoch: 7 [32000/50000 (63.9%)]	Loss: 0.320744
# (pid=15161, ip=10.21.5.174) The 1 worker, Train Epoch: 7 [32000/50000 (63.9%)]	Loss: 0.470728
# (pid=1340) The 0 worker, Train Epoch: 7 [38400/50000 (76.7%)]	Loss: 0.388801
# (pid=16075, ip=10.21.5.173) The 2 worker, Train Epoch: 7 [38400/50000 (76.7%)]	Loss: 0.313322
# (pid=15161, ip=10.21.5.174) The 1 worker, Train Epoch: 7 [38400/50000 (76.7%)]	Loss: 0.346327
# (pid=1340) The 0 worker, Train Epoch: 7 [44800/50000 (89.5%)]	Loss: 0.341368
# (pid=16075, ip=10.21.5.173) The 2 worker, Train Epoch: 7 [44800/50000 (89.5%)]	Loss: 0.548196
# (pid=15161, ip=10.21.5.174) The 1 worker, Train Epoch: 7 [44800/50000 (89.5%)]	Loss: 0.507807
# (pid=16075, ip=10.21.5.173) The 2 worker finished its 7 epoch with loss: 0.005614389665424824 and accuracy: 0.8747199773788452
# (pid=1340) The 0 worker finished its 7 epoch with loss: 0.005628975108265877 and accuracy: 0.8750600218772888
# (pid=1340) The 0 worker, Train Epoch: 8 [0/50000 (0.0%)]	Loss: 0.199037
# (pid=raylet, ip=10.21.5.173) F1206 14:32:04.686448 16054 object_store_notification_manager.cc:46] Problem communicating with the object store from raylet, check logs or dmesg for previous errors: IOError: No such file or directory
# (pid=raylet, ip=10.21.5.173) *** Check failure stack trace: ***
# (pid=raylet, ip=10.21.5.173)     @           0x6f8d1a  google::LogMessage::Fail()
# (pid=raylet, ip=10.21.5.173)     @           0x6fa103  google::LogMessage::SendToLog()
# (pid=raylet, ip=10.21.5.173)     @           0x6f8a42  google::LogMessage::Flush()
# (pid=raylet, ip=10.21.5.173)     @           0x6f8c31  google::LogMessage::~LogMessage()
# (pid=raylet, ip=10.21.5.173)     @           0x52b0d2  ray::RayLog::~RayLog()
# (pid=raylet, ip=10.21.5.173)     @           0x4a0070  ray::ObjectStoreNotificationManager::ProcessStoreLength()
# (pid=raylet, ip=10.21.5.173)     @           0x49f6ca  boost::asio::detail::read_op<>::operator()()
# (pid=raylet, ip=10.21.5.173)     @           0x49f8c2  boost::asio::detail::reactive_socket_recv_op<>::do_complete()
# (pid=raylet, ip=10.21.5.173)     @           0x425bcd  boost::asio::detail::scheduler::run()
# (pid=raylet, ip=10.21.5.173)     @           0x40fb1d  main
# (pid=raylet, ip=10.21.5.173)     @     0x7fa23080ab97  __libc_start_main
# (pid=raylet, ip=10.21.5.173)     @           0x4207e1  (unknown)
# (pid=15161, ip=10.21.5.174) The 1 worker finished its 7 epoch with loss: 0.005600976292043924 and accuracy: 0.8756200075149536
# (pid=16069, ip=10.21.5.173) Traceback (most recent call last):
# (pid=16069, ip=10.21.5.173)   File "/userhome/34/gyu/anaconda3/envs/pytorch_env/lib/python3.7/site-packages/ray/workers/default_worker.py", line 98, in <module>
# (pid=16069, ip=10.21.5.173)     ray.worker.global_worker.main_loop()
# (pid=16069, ip=10.21.5.173)   File "/userhome/34/gyu/anaconda3/envs/pytorch_env/lib/python3.7/site-packages/ray/worker.py", line 1118, in main_loop
# (pid=16069, ip=10.21.5.173)     task = self._get_next_task_from_raylet()
# (pid=16069, ip=10.21.5.173)   File "/userhome/34/gyu/anaconda3/envs/pytorch_env/lib/python3.7/site-packages/ray/worker.py", line 1101, in _get_next_task_from_raylet
# (pid=16069, ip=10.21.5.173)     task = self.raylet_client.get_task()
# (pid=16069, ip=10.21.5.173)   File "python/ray/_raylet.pyx", line 291, in ray._raylet.RayletClient.get_task
# (pid=16069, ip=10.21.5.173)   File "python/ray/_raylet.pyx", line 98, in ray._raylet.check_status
# (pid=16069, ip=10.21.5.173) ray.exceptions.RayletError: The Raylet died with this message: [RayletClient] Raylet connection closed.
# (pid=16069, ip=10.21.5.173)
# (pid=16069, ip=10.21.5.173) During handling of the above exception, another exception occurred:
# (pid=16069, ip=10.21.5.173)
# (pid=16069, ip=10.21.5.173) Traceback (most recent call last):
# (pid=16069, ip=10.21.5.173)   File "/userhome/34/gyu/anaconda3/envs/pytorch_env/lib/python3.7/site-packages/ray/workers/default_worker.py", line 105, in <module>
# (pid=16069, ip=10.21.5.173)     job_id=None)
# (pid=16069, ip=10.21.5.173)   File "/userhome/34/gyu/anaconda3/envs/pytorch_env/lib/python3.7/site-packages/ray/utils.py", line 67, in push_error_to_driver
# (pid=16069, ip=10.21.5.173)     worker.raylet_client.push_error(job_id, error_type, message, time.time())
# (pid=16069, ip=10.21.5.173)   File "python/ray/_raylet.pyx", line 327, in ray._raylet.RayletClient.push_error
# (pid=16072, ip=10.21.5.173) Traceback (most recent call last):
# (pid=16072, ip=10.21.5.173)   File "/userhome/34/gyu/anaconda3/envs/pytorch_env/lib/python3.7/site-packages/ray/workers/default_worker.py", line 98, in <module>
# (pid=16072, ip=10.21.5.173)     ray.worker.global_worker.main_loop()
# (pid=16072, ip=10.21.5.173)   File "/userhome/34/gyu/anaconda3/envs/pytorch_env/lib/python3.7/site-packages/ray/worker.py", line 1118, in main_loop
# (pid=16072, ip=10.21.5.173)     task = self._get_next_task_from_raylet()
# (pid=16072, ip=10.21.5.173)   File "/userhome/34/gyu/anaconda3/envs/pytorch_env/lib/python3.7/site-packages/ray/worker.py", line 1101, in _get_next_task_from_raylet
# (pid=16072, ip=10.21.5.173)     task = self.raylet_client.get_task()
# (pid=16072, ip=10.21.5.173)   File "python/ray/_raylet.pyx", line 291, in ray._raylet.RayletClient.get_task
# (pid=16072, ip=10.21.5.173)   File "python/ray/_raylet.pyx", line 98, in ray._raylet.check_status
# (pid=16072, ip=10.21.5.173) ray.exceptions.RayletError: The Raylet died with this message: [RayletClient] Raylet connection closed.
# (pid=16072, ip=10.21.5.173)
# (pid=16072, ip=10.21.5.173) During handling of the above exception, another exception occurred:
# (pid=16072, ip=10.21.5.173)
# (pid=16072, ip=10.21.5.173) Traceback (most recent call last):
# (pid=16072, ip=10.21.5.173)   File "/userhome/34/gyu/anaconda3/envs/pytorch_env/lib/python3.7/site-packages/ray/workers/default_worker.py", line 105, in <module>
# (pid=16072, ip=10.21.5.173)     job_id=None)
# (pid=16072, ip=10.21.5.173)   File "/userhome/34/gyu/anaconda3/envs/pytorch_env/lib/python3.7/site-packages/ray/utils.py", line 67, in push_error_to_driver
# (pid=16072, ip=10.21.5.173)     worker.raylet_client.push_error(job_id, error_type, message, time.time())
# (pid=16072, ip=10.21.5.173)   File "python/ray/_raylet.pyx", line 327, in ray._raylet.RayletClient.push_error
# (pid=16072, ip=10.21.5.173)   File "python/ray/_raylet.pyx", line 98, in ray._raylet.check_status
# (pid=16072, ip=10.21.5.173) ray.exceptions.RayletError: The Raylet died with this message: [RayletClient] Connection closed unexpectedly.
# (pid=16070, ip=10.21.5.173) Traceback (most recent call last):
# (pid=16070, ip=10.21.5.173)   File "/userhome/34/gyu/anaconda3/envs/pytorch_env/lib/python3.7/site-packages/ray/workers/default_worker.py", line 98, in <module>
# (pid=16070, ip=10.21.5.173)     ray.worker.global_worker.main_loop()
# (pid=16070, ip=10.21.5.173)   File "/userhome/34/gyu/anaconda3/envs/pytorch_env/lib/python3.7/site-packages/ray/worker.py", line 1118, in main_loop
# (pid=16070, ip=10.21.5.173)     task = self._get_next_task_from_raylet()
# (pid=16070, ip=10.21.5.173)   File "/userhome/34/gyu/anaconda3/envs/pytorch_env/lib/python3.7/site-packages/ray/worker.py", line 1101, in _get_next_task_from_raylet
# (pid=16070, ip=10.21.5.173)     task = self.raylet_client.get_task()
# (pid=16070, ip=10.21.5.173)   File "python/ray/_raylet.pyx", line 291, in ray._raylet.RayletClient.get_task
# (pid=16070, ip=10.21.5.173)   File "python/ray/_raylet.pyx", line 98, in ray._raylet.check_status
# (pid=16070, ip=10.21.5.173) ray.exceptions.RayletError: The Raylet died with this message: [RayletClient] Raylet connection closed.
# (pid=16070, ip=10.21.5.173)
# (pid=16070, ip=10.21.5.173) During handling of the above exception, another exception occurred:
# (pid=16070, ip=10.21.5.173)
# (pid=16070, ip=10.21.5.173) Traceback (most recent call last):
# (pid=16070, ip=10.21.5.173)   File "/userhome/34/gyu/anaconda3/envs/pytorch_env/lib/python3.7/site-packages/ray/workers/default_worker.py", line 105, in <module>
# (pid=16070, ip=10.21.5.173)     job_id=None)
# (pid=16070, ip=10.21.5.173)   File "/userhome/34/gyu/anaconda3/envs/pytorch_env/lib/python3.7/site-packages/ray/utils.py", line 67, in push_error_to_driver
# (pid=16070, ip=10.21.5.173)     worker.raylet_client.push_error(job_id, error_type, message, time.time())
# (pid=16070, ip=10.21.5.173)   File "python/ray/_raylet.pyx", line 327, in ray._raylet.RayletClient.push_error
# (pid=16070, ip=10.21.5.173)   File "python/ray/_raylet.pyx", line 98, in ray._raylet.check_status
# (pid=16070, ip=10.21.5.173) ray.exceptions.RayletError: The Raylet died with this message: [RayletClient] Connection closed unexpectedly.
# (pid=16074, ip=10.21.5.173) Traceback (most recent call last):
# (pid=16074, ip=10.21.5.173)   File "/userhome/34/gyu/anaconda3/envs/pytorch_env/lib/python3.7/site-packages/ray/workers/default_worker.py", line 98, in <module>
# (pid=16074, ip=10.21.5.173)     ray.worker.global_worker.main_loop()
# (pid=16074, ip=10.21.5.173)   File "/userhome/34/gyu/anaconda3/envs/pytorch_env/lib/python3.7/site-packages/ray/worker.py", line 1118, in main_loop
# (pid=16074, ip=10.21.5.173)     task = self._get_next_task_from_raylet()
# (pid=16074, ip=10.21.5.173)   File "/userhome/34/gyu/anaconda3/envs/pytorch_env/lib/python3.7/site-packages/ray/worker.py", line 1101, in _get_next_task_from_raylet
# (pid=16074, ip=10.21.5.173)     task = self.raylet_client.get_task()
# (pid=16074, ip=10.21.5.173)   File "python/ray/_raylet.pyx", line 291, in ray._raylet.RayletClient.get_task
# (pid=16074, ip=10.21.5.173)   File "python/ray/_raylet.pyx", line 98, in ray._raylet.check_status
# (pid=16074, ip=10.21.5.173) ray.exceptions.RayletError: The Raylet died with this message: [RayletClient] Raylet connection closed.
# (pid=16074, ip=10.21.5.173)
# (pid=16074, ip=10.21.5.173) During handling of the above exception, another exception occurred:
# (pid=16074, ip=10.21.5.173)
# (pid=16074, ip=10.21.5.173) Traceback (most recent call last):
# (pid=16074, ip=10.21.5.173)   File "/userhome/34/gyu/anaconda3/envs/pytorch_env/lib/python3.7/site-packages/ray/workers/default_worker.py", line 105, in <module>
# (pid=16074, ip=10.21.5.173)     job_id=None)
# (pid=16074, ip=10.21.5.173)   File "/userhome/34/gyu/anaconda3/envs/pytorch_env/lib/python3.7/site-packages/ray/utils.py", line 67, in push_error_to_driver
# (pid=16074, ip=10.21.5.173)     worker.raylet_client.push_error(job_id, error_type, message, time.time())
# (pid=16074, ip=10.21.5.173)   File "python/ray/_raylet.pyx", line 327, in ray._raylet.RayletClient.push_error
# (pid=16074, ip=10.21.5.173)   File "python/ray/_raylet.pyx", line 98, in ray._raylet.check_status
# (pid=16074, ip=10.21.5.173) ray.exceptions.RayletError: The Raylet died with this message: [RayletClient] Connection closed unexpectedly.
# (pid=16076, ip=10.21.5.173) Traceback (most recent call last):
# (pid=16076, ip=10.21.5.173)   File "/userhome/34/gyu/anaconda3/envs/pytorch_env/lib/python3.7/site-packages/ray/workers/default_worker.py", line 98, in <module>
# (pid=16076, ip=10.21.5.173)     ray.worker.global_worker.main_loop()
# (pid=16076, ip=10.21.5.173)   File "/userhome/34/gyu/anaconda3/envs/pytorch_env/lib/python3.7/site-packages/ray/worker.py", line 1118, in main_loop
# (pid=16076, ip=10.21.5.173)     task = self._get_next_task_from_raylet()
# (pid=16076, ip=10.21.5.173)   File "/userhome/34/gyu/anaconda3/envs/pytorch_env/lib/python3.7/site-packages/ray/worker.py", line 1101, in _get_next_task_from_raylet
# (pid=16076, ip=10.21.5.173)     task = self.raylet_client.get_task()
# (pid=16076, ip=10.21.5.173)   File "python/ray/_raylet.pyx", line 291, in ray._raylet.RayletClient.get_task
# (pid=16076, ip=10.21.5.173)   File "python/ray/_raylet.pyx", line 98, in ray._raylet.check_status
# (pid=16076, ip=10.21.5.173) ray.exceptions.RayletError: The Raylet died with this message: [RayletClient] Raylet connection closed.
# (pid=16076, ip=10.21.5.173)
# (pid=16076, ip=10.21.5.173) During handling of the above exception, another exception occurred:
# (pid=16076, ip=10.21.5.173)
# (pid=16076, ip=10.21.5.173) Traceback (most recent call last):
# (pid=16076, ip=10.21.5.173)   File "/userhome/34/gyu/anaconda3/envs/pytorch_env/lib/python3.7/site-packages/ray/workers/default_worker.py", line 105, in <module>
# (pid=16076, ip=10.21.5.173)     job_id=None)
# (pid=16076, ip=10.21.5.173)   File "/userhome/34/gyu/anaconda3/envs/pytorch_env/lib/python3.7/site-packages/ray/utils.py", line 67, in push_error_to_driver
# (pid=16076, ip=10.21.5.173)     worker.raylet_client.push_error(job_id, error_type, message, time.time())
# (pid=16076, ip=10.21.5.173)   File "python/ray/_raylet.pyx", line 327, in ray._raylet.RayletClient.push_error
# (pid=16076, ip=10.21.5.173)   File "python/ray/_raylet.pyx", line 98, in ray._raylet.check_status
# (pid=16076, ip=10.21.5.173) ray.exceptions.RayletError: The Raylet died with this message: [RayletClient] Connection closed unexpectedly.
# (pid=16073, ip=10.21.5.173) Traceback (most recent call last):
# (pid=16073, ip=10.21.5.173)   File "/userhome/34/gyu/anaconda3/envs/pytorch_env/lib/python3.7/site-packages/ray/workers/default_worker.py", line 98, in <module>
# (pid=16073, ip=10.21.5.173)     ray.worker.global_worker.main_loop()
# (pid=16073, ip=10.21.5.173)   File "/userhome/34/gyu/anaconda3/envs/pytorch_env/lib/python3.7/site-packages/ray/worker.py", line 1118, in main_loop
# (pid=16073, ip=10.21.5.173)     task = self._get_next_task_from_raylet()
# (pid=16073, ip=10.21.5.173)   File "/userhome/34/gyu/anaconda3/envs/pytorch_env/lib/python3.7/site-packages/ray/worker.py", line 1101, in _get_next_task_from_raylet
# (pid=16073, ip=10.21.5.173)     task = self.raylet_client.get_task()
# (pid=16073, ip=10.21.5.173)   File "python/ray/_raylet.pyx", line 291, in ray._raylet.RayletClient.get_task
# (pid=16073, ip=10.21.5.173)   File "python/ray/_raylet.pyx", line 98, in ray._raylet.check_status
# (pid=16073, ip=10.21.5.173) ray.exceptions.RayletError: The Raylet died with this message: [RayletClient] Raylet connection closed.
# (pid=16073, ip=10.21.5.173)
# (pid=16073, ip=10.21.5.173) During handling of the above exception, another exception occurred:
# (pid=16073, ip=10.21.5.173)
# (pid=16073, ip=10.21.5.173) Traceback (most recent call last):
# (pid=16073, ip=10.21.5.173)   File "/userhome/34/gyu/anaconda3/envs/pytorch_env/lib/python3.7/site-packages/ray/workers/default_worker.py", line 105, in <module>
# (pid=16073, ip=10.21.5.173)     job_id=None)
# (pid=16073, ip=10.21.5.173)   File "/userhome/34/gyu/anaconda3/envs/pytorch_env/lib/python3.7/site-packages/ray/utils.py", line 67, in push_error_to_driver
# (pid=16073, ip=10.21.5.173)     worker.raylet_client.push_error(job_id, error_type, message, time.time())
# (pid=16073, ip=10.21.5.173)   File "python/ray/_raylet.pyx", line 327, in ray._raylet.RayletClient.push_error
# (pid=16073, ip=10.21.5.173)   File "python/ray/_raylet.pyx", line 98, in ray._raylet.check_status
# (pid=16073, ip=10.21.5.173) ray.exceptions.RayletError: The Raylet died with this message: [RayletClient] Connection closed unexpectedly.
# (pid=16071, ip=10.21.5.173) Traceback (most recent call last):
# (pid=16071, ip=10.21.5.173)   File "/userhome/34/gyu/anaconda3/envs/pytorch_env/lib/python3.7/site-packages/ray/workers/default_worker.py", line 98, in <module>
# (pid=16071, ip=10.21.5.173)     ray.worker.global_worker.main_loop()
# (pid=16071, ip=10.21.5.173)   File "/userhome/34/gyu/anaconda3/envs/pytorch_env/lib/python3.7/site-packages/ray/worker.py", line 1118, in main_loop
# (pid=16071, ip=10.21.5.173)     task = self._get_next_task_from_raylet()
# (pid=16071, ip=10.21.5.173)   File "/userhome/34/gyu/anaconda3/envs/pytorch_env/lib/python3.7/site-packages/ray/worker.py", line 1101, in _get_next_task_from_raylet
# (pid=16071, ip=10.21.5.173)     task = self.raylet_client.get_task()
# (pid=16071, ip=10.21.5.173)   File "python/ray/_raylet.pyx", line 291, in ray._raylet.RayletClient.get_task
# (pid=16071, ip=10.21.5.173)   File "python/ray/_raylet.pyx", line 98, in ray._raylet.check_status
# (pid=16071, ip=10.21.5.173) ray.exceptions.RayletError: The Raylet died with this message: [RayletClient] Raylet connection closed.
# (pid=16071, ip=10.21.5.173)
# (pid=16071, ip=10.21.5.173) During handling of the above exception, another exception occurred:
# (pid=16071, ip=10.21.5.173)
# (pid=16071, ip=10.21.5.173) Traceback (most recent call last):
# (pid=16071, ip=10.21.5.173)   File "/userhome/34/gyu/anaconda3/envs/pytorch_env/lib/python3.7/site-packages/ray/workers/default_worker.py", line 105, in <module>
# (pid=16071, ip=10.21.5.173)     job_id=None)
# (pid=16071, ip=10.21.5.173)   File "/userhome/34/gyu/anaconda3/envs/pytorch_env/lib/python3.7/site-packages/ray/utils.py", line 67, in push_error_to_driver
# (pid=16071, ip=10.21.5.173)     worker.raylet_client.push_error(job_id, error_type, message, time.time())
# (pid=16071, ip=10.21.5.173)   File "python/ray/_raylet.pyx", line 327, in ray._raylet.RayletClient.push_error
# (pid=16071, ip=10.21.5.173)   File "python/ray/_raylet.pyx", line 98, in ray._raylet.check_status
# (pid=16071, ip=10.21.5.173) ray.exceptions.RayletError: The Raylet died with this message: [RayletClient] Connection closed unexpectedly.
# (pid=16069, ip=10.21.5.173)   File "python/ray/_raylet.pyx", line 98, in ray._raylet.check_status
# (pid=16069, ip=10.21.5.173) ray.exceptions.RayletError: The Raylet died with this message: [RayletClient] Connection closed unexpectedly.
# (pid=raylet, ip=10.21.5.174) F1206 14:32:05.514030 15141 object_store_notification_manager.cc:46] Problem communicating with the object store from raylet, check logs or dmesg for previous errors: IOError: No such file or directory
# (pid=raylet, ip=10.21.5.174) *** Check failure stack trace: ***
# (pid=raylet, ip=10.21.5.174)     @           0x6f8d1a  google::LogMessage::Fail()
# (pid=raylet, ip=10.21.5.174)     @           0x6fa103  google::LogMessage::SendToLog()
# (pid=raylet, ip=10.21.5.174)     @           0x6f8a42  google::LogMessage::Flush()
# (pid=raylet, ip=10.21.5.174)     @           0x6f8c31  google::LogMessage::~LogMessage()
# (pid=raylet, ip=10.21.5.174)     @           0x52b0d2  ray::RayLog::~RayLog()
# (pid=raylet, ip=10.21.5.174)     @           0x4a0070  ray::ObjectStoreNotificationManager::ProcessStoreLength()
# (pid=raylet, ip=10.21.5.174)     @           0x49f6ca  boost::asio::detail::read_op<>::operator()()
# (pid=raylet, ip=10.21.5.174)     @           0x49f8c2  boost::asio::detail::reactive_socket_recv_op<>::do_complete()
# (pid=raylet, ip=10.21.5.174)     @           0x425bcd  boost::asio::detail::scheduler::run()
# (pid=raylet, ip=10.21.5.174)     @           0x40fb1d  main
# (pid=raylet, ip=10.21.5.174)     @     0x7fe6a8d69b97  __libc_start_main
# (pid=raylet, ip=10.21.5.174)     @           0x4207e1  (unknown)
# (pid=15158, ip=10.21.5.174) Traceback (most recent call last):
# (pid=15158, ip=10.21.5.174)   File "/userhome/34/gyu/anaconda3/envs/pytorch_env/lib/python3.7/site-packages/ray/workers/default_worker.py", line 98, in <module>
# (pid=15158, ip=10.21.5.174)     ray.worker.global_worker.main_loop()
# (pid=15158, ip=10.21.5.174)   File "/userhome/34/gyu/anaconda3/envs/pytorch_env/lib/python3.7/site-packages/ray/worker.py", line 1118, in main_loop
# (pid=15158, ip=10.21.5.174)     task = self._get_next_task_from_raylet()
# (pid=15158, ip=10.21.5.174)   File "/userhome/34/gyu/anaconda3/envs/pytorch_env/lib/python3.7/site-packages/ray/worker.py", line 1101, in _get_next_task_from_raylet
# (pid=15158, ip=10.21.5.174)     task = self.raylet_client.get_task()
# (pid=15158, ip=10.21.5.174)   File "python/ray/_raylet.pyx", line 291, in ray._raylet.RayletClient.get_task
# (pid=15160, ip=10.21.5.174) Traceback (most recent call last):
# (pid=15160, ip=10.21.5.174)   File "/userhome/34/gyu/anaconda3/envs/pytorch_env/lib/python3.7/site-packages/ray/workers/default_worker.py", line 98, in <module>
# (pid=15160, ip=10.21.5.174)     ray.worker.global_worker.main_loop()
# (pid=15160, ip=10.21.5.174)   File "/userhome/34/gyu/anaconda3/envs/pytorch_env/lib/python3.7/site-packages/ray/worker.py", line 1118, in main_loop
# (pid=15160, ip=10.21.5.174)     task = self._get_next_task_from_raylet()
# (pid=15160, ip=10.21.5.174)   File "/userhome/34/gyu/anaconda3/envs/pytorch_env/lib/python3.7/site-packages/ray/worker.py", line 1101, in _get_next_task_from_raylet
# (pid=15160, ip=10.21.5.174)     task = self.raylet_client.get_task()
# (pid=15160, ip=10.21.5.174)   File "python/ray/_raylet.pyx", line 291, in ray._raylet.RayletClient.get_task
# (pid=15160, ip=10.21.5.174)   File "python/ray/_raylet.pyx", line 98, in ray._raylet.check_status
# (pid=15157, ip=10.21.5.174) Traceback (most recent call last):
# (pid=15157, ip=10.21.5.174)   File "/userhome/34/gyu/anaconda3/envs/pytorch_env/lib/python3.7/site-packages/ray/workers/default_worker.py", line 98, in <module>
# (pid=15157, ip=10.21.5.174)     ray.worker.global_worker.main_loop()
# (pid=15157, ip=10.21.5.174)   File "/userhome/34/gyu/anaconda3/envs/pytorch_env/lib/python3.7/site-packages/ray/worker.py", line 1118, in main_loop
# (pid=15157, ip=10.21.5.174)     task = self._get_next_task_from_raylet()
# (pid=15157, ip=10.21.5.174)   File "/userhome/34/gyu/anaconda3/envs/pytorch_env/lib/python3.7/site-packages/ray/worker.py", line 1101, in _get_next_task_from_raylet
# (pid=15157, ip=10.21.5.174)     task = self.raylet_client.get_task()
# (pid=15157, ip=10.21.5.174)   File "python/ray/_raylet.pyx", line 291, in ray._raylet.RayletClient.get_task
# (pid=15157, ip=10.21.5.174)   File "python/ray/_raylet.pyx", line 98, in ray._raylet.check_status
# (pid=15159, ip=10.21.5.174) Traceback (most recent call last):
# (pid=15159, ip=10.21.5.174)   File "/userhome/34/gyu/anaconda3/envs/pytorch_env/lib/python3.7/site-packages/ray/workers/default_worker.py", line 98, in <module>
# (pid=15159, ip=10.21.5.174)     ray.worker.global_worker.main_loop()
# (pid=15159, ip=10.21.5.174)   File "/userhome/34/gyu/anaconda3/envs/pytorch_env/lib/python3.7/site-packages/ray/worker.py", line 1118, in main_loop
# (pid=15159, ip=10.21.5.174)     task = self._get_next_task_from_raylet()
# (pid=15159, ip=10.21.5.174)   File "/userhome/34/gyu/anaconda3/envs/pytorch_env/lib/python3.7/site-packages/ray/worker.py", line 1101, in _get_next_task_from_raylet
# (pid=15159, ip=10.21.5.174)     task = self.raylet_client.get_task()
# (pid=15159, ip=10.21.5.174)   File "python/ray/_raylet.pyx", line 291, in ray._raylet.RayletClient.get_task
# (pid=15159, ip=10.21.5.174)   File "python/ray/_raylet.pyx", line 98, in ray._raylet.check_status
# (pid=15159, ip=10.21.5.174) ray.exceptions.RayletError: The Raylet died with this message: [RayletClient] Raylet connection closed.
# (pid=15159, ip=10.21.5.174)
# (pid=15159, ip=10.21.5.174) During handling of the above exception, another exception occurred:
# (pid=15159, ip=10.21.5.174)
# (pid=15159, ip=10.21.5.174) Traceback (most recent call last):
# (pid=15159, ip=10.21.5.174)   File "/userhome/34/gyu/anaconda3/envs/pytorch_env/lib/python3.7/site-packages/ray/workers/default_worker.py", line 105, in <module>
# (pid=15159, ip=10.21.5.174)     job_id=None)
# (pid=15159, ip=10.21.5.174)   File "/userhome/34/gyu/anaconda3/envs/pytorch_env/lib/python3.7/site-packages/ray/utils.py", line 67, in push_error_to_driver
# (pid=15163, ip=10.21.5.174) Traceback (most recent call last):
# (pid=15163, ip=10.21.5.174)   File "/userhome/34/gyu/anaconda3/envs/pytorch_env/lib/python3.7/site-packages/ray/workers/default_worker.py", line 98, in <module>
# (pid=15163, ip=10.21.5.174)     ray.worker.global_worker.main_loop()
# (pid=15163, ip=10.21.5.174)   File "/userhome/34/gyu/anaconda3/envs/pytorch_env/lib/python3.7/site-packages/ray/worker.py", line 1118, in main_loop
# (pid=15163, ip=10.21.5.174)     task = self._get_next_task_from_raylet()
# (pid=15163, ip=10.21.5.174)   File "/userhome/34/gyu/anaconda3/envs/pytorch_env/lib/python3.7/site-packages/ray/worker.py", line 1101, in _get_next_task_from_raylet
# (pid=15163, ip=10.21.5.174)     task = self.raylet_client.get_task()
# (pid=15163, ip=10.21.5.174)   File "python/ray/_raylet.pyx", line 291, in ray._raylet.RayletClient.get_task
# (pid=15163, ip=10.21.5.174)   File "python/ray/_raylet.pyx", line 98, in ray._raylet.check_status
# (pid=15156, ip=10.21.5.174) Traceback (most recent call last):
# (pid=15156, ip=10.21.5.174)   File "/userhome/34/gyu/anaconda3/envs/pytorch_env/lib/python3.7/site-packages/ray/workers/default_worker.py", line 98, in <module>
# (pid=15156, ip=10.21.5.174)     ray.worker.global_worker.main_loop()
# (pid=15156, ip=10.21.5.174)   File "/userhome/34/gyu/anaconda3/envs/pytorch_env/lib/python3.7/site-packages/ray/worker.py", line 1118, in main_loop
# (pid=15156, ip=10.21.5.174)     task = self._get_next_task_from_raylet()
# (pid=15156, ip=10.21.5.174)   File "/userhome/34/gyu/anaconda3/envs/pytorch_env/lib/python3.7/site-packages/ray/worker.py", line 1101, in _get_next_task_from_raylet
# (pid=15156, ip=10.21.5.174)     task = self.raylet_client.get_task()
# (pid=15156, ip=10.21.5.174)   File "python/ray/_raylet.pyx", line 291, in ray._raylet.RayletClient.get_task
# (pid=15156, ip=10.21.5.174)   File "python/ray/_raylet.pyx", line 98, in ray._raylet.check_status
# (pid=15156, ip=10.21.5.174) ray.exceptions.RayletError: The Raylet died with this message: [RayletClient] Raylet connection closed.
# (pid=15156, ip=10.21.5.174)
# (pid=15156, ip=10.21.5.174) During handling of the above exception, another exception occurred:
# (pid=15156, ip=10.21.5.174)
# (pid=15156, ip=10.21.5.174) Traceback (most recent call last):
# (pid=15156, ip=10.21.5.174)   File "/userhome/34/gyu/anaconda3/envs/pytorch_env/lib/python3.7/site-packages/ray/workers/default_worker.py", line 105, in <module>
# (pid=15156, ip=10.21.5.174)     job_id=None)
# (pid=15156, ip=10.21.5.174)   File "/userhome/34/gyu/anaconda3/envs/pytorch_env/lib/python3.7/site-packages/ray/utils.py", line 67, in push_error_to_driver
# (pid=15156, ip=10.21.5.174)     worker.raylet_client.push_error(job_id, error_type, message, time.time())
# (pid=15156, ip=10.21.5.174)   File "python/ray/_raylet.pyx", line 327, in ray._raylet.RayletClient.push_error
# (pid=15156, ip=10.21.5.174)   File "python/ray/_raylet.pyx", line 98, in ray._raylet.check_status
# (pid=15158, ip=10.21.5.174)   File "python/ray/_raylet.pyx", line 98, in ray._raylet.check_status
# (pid=15160, ip=10.21.5.174) ray.exceptions.RayletError: The Raylet died with this message: [RayletClient] Raylet connection closed.
# (pid=15160, ip=10.21.5.174)
# (pid=15160, ip=10.21.5.174) During handling of the above exception, another exception occurred:
# (pid=15160, ip=10.21.5.174)
# (pid=15160, ip=10.21.5.174) Traceback (most recent call last):
# (pid=15160, ip=10.21.5.174)   File "/userhome/34/gyu/anaconda3/envs/pytorch_env/lib/python3.7/site-packages/ray/workers/default_worker.py", line 105, in <module>
# (pid=15160, ip=10.21.5.174)     job_id=None)
# (pid=15160, ip=10.21.5.174)   File "/userhome/34/gyu/anaconda3/envs/pytorch_env/lib/python3.7/site-packages/ray/utils.py", line 67, in push_error_to_driver
# (pid=15160, ip=10.21.5.174)     worker.raylet_client.push_error(job_id, error_type, message, time.time())
# (pid=15160, ip=10.21.5.174)   File "python/ray/_raylet.pyx", line 327, in ray._raylet.RayletClient.push_error
# (pid=15160, ip=10.21.5.174)   File "python/ray/_raylet.pyx", line 98, in ray._raylet.check_status
# (pid=15160, ip=10.21.5.174) ray.exceptions.RayletError: The Raylet died with this message: [RayletClient] Connection closed unexpectedly.
# (pid=15157, ip=10.21.5.174) ray.exceptions.RayletError: The Raylet died with this message: [RayletClient] Raylet connection closed.
# (pid=15157, ip=10.21.5.174)
# (pid=15157, ip=10.21.5.174) During handling of the above exception, another exception occurred:
# (pid=15157, ip=10.21.5.174)
# (pid=15157, ip=10.21.5.174) Traceback (most recent call last):
# (pid=15157, ip=10.21.5.174)   File "/userhome/34/gyu/anaconda3/envs/pytorch_env/lib/python3.7/site-packages/ray/workers/default_worker.py", line 105, in <module>
# (pid=15157, ip=10.21.5.174)     job_id=None)
# (pid=15157, ip=10.21.5.174)   File "/userhome/34/gyu/anaconda3/envs/pytorch_env/lib/python3.7/site-packages/ray/utils.py", line 67, in push_error_to_driver
# (pid=15159, ip=10.21.5.174)     worker.raylet_client.push_error(job_id, error_type, message, time.time())
# (pid=15159, ip=10.21.5.174)   File "python/ray/_raylet.pyx", line 327, in ray._raylet.RayletClient.push_error
# (pid=15159, ip=10.21.5.174)   File "python/ray/_raylet.pyx", line 98, in ray._raylet.check_status
# (pid=15159, ip=10.21.5.174) ray.exceptions.RayletError: The Raylet died with this message: [RayletClient] Connection closed unexpectedly.
# (pid=15163, ip=10.21.5.174) ray.exceptions.RayletError: The Raylet died with this message: [RayletClient] Raylet connection closed.
# (pid=15163, ip=10.21.5.174)
# (pid=15163, ip=10.21.5.174) During handling of the above exception, another exception occurred:
# (pid=15163, ip=10.21.5.174)
# (pid=15163, ip=10.21.5.174) Traceback (most recent call last):
# (pid=15163, ip=10.21.5.174)   File "/userhome/34/gyu/anaconda3/envs/pytorch_env/lib/python3.7/site-packages/ray/workers/default_worker.py", line 105, in <module>
# (pid=15163, ip=10.21.5.174)     job_id=None)
# (pid=15163, ip=10.21.5.174)   File "/userhome/34/gyu/anaconda3/envs/pytorch_env/lib/python3.7/site-packages/ray/utils.py", line 67, in push_error_to_driver
# (pid=15156, ip=10.21.5.174) ray.exceptions.RayletError: The Raylet died with this message: [RayletClient] Connection closed unexpectedly.
# (pid=15158, ip=10.21.5.174) ray.exceptions.RayletError: The Raylet died with this message: [RayletClient] Raylet connection closed.
# (pid=15158, ip=10.21.5.174)
# (pid=15158, ip=10.21.5.174) During handling of the above exception, another exception occurred:
# (pid=15158, ip=10.21.5.174)
# (pid=15158, ip=10.21.5.174) Traceback (most recent call last):
# (pid=15158, ip=10.21.5.174)   File "/userhome/34/gyu/anaconda3/envs/pytorch_env/lib/python3.7/site-packages/ray/workers/default_worker.py", line 105, in <module>
# (pid=15157, ip=10.21.5.174)     worker.raylet_client.push_error(job_id, error_type, message, time.time())
# (pid=15157, ip=10.21.5.174)   File "python/ray/_raylet.pyx", line 327, in ray._raylet.RayletClient.push_error
# (pid=15157, ip=10.21.5.174)   File "python/ray/_raylet.pyx", line 98, in ray._raylet.check_status
# (pid=15157, ip=10.21.5.174) ray.exceptions.RayletError: The Raylet died with this message: [RayletClient] Connection closed unexpectedly.
# (pid=15163, ip=10.21.5.174)     worker.raylet_client.push_error(job_id, error_type, message, time.time())
# (pid=15163, ip=10.21.5.174)   File "python/ray/_raylet.pyx", line 327, in ray._raylet.RayletClient.push_error
# (pid=15163, ip=10.21.5.174)   File "python/ray/_raylet.pyx", line 98, in ray._raylet.check_status
# (pid=15163, ip=10.21.5.174) ray.exceptions.RayletError: The Raylet died with this message: [RayletClient] Connection closed unexpectedly.
# (pid=15158, ip=10.21.5.174)     job_id=None)
# (pid=15158, ip=10.21.5.174)   File "/userhome/34/gyu/anaconda3/envs/pytorch_env/lib/python3.7/site-packages/ray/utils.py", line 67, in push_error_to_driver
# (pid=15158, ip=10.21.5.174)     worker.raylet_client.push_error(job_id, error_type, message, time.time())
# (pid=15158, ip=10.21.5.174)   File "python/ray/_raylet.pyx", line 327, in ray._raylet.RayletClient.push_error
# (pid=15158, ip=10.21.5.174)   File "python/ray/_raylet.pyx", line 98, in ray._raylet.check_status
# (pid=15158, ip=10.21.5.174) ray.exceptions.RayletError: The Raylet died with this message: [RayletClient] Connection closed unexpectedly.
# 2019-12-06 14:32:34,670	WARNING worker.py:1779 -- The node with client ID 65beb82fc417c805b5555607a3a62cef1ec1d61f has been marked dead because the monitor has missed too many heartbeats from it.
# 2019-12-06 14:32:35,570	WARNING worker.py:1779 -- The node with client ID 4489985780ad74659b758df78a415aeb0b065f84 has been marked dead because the monitor has missed too many heartbeats from it.
# 2019-12-06 14:32:41,683	ERROR worker.py:1719 -- Possible unhandled error from worker: ray_worker:__main__.worker_task() (pid=1340, host=gpu-comp-202)
#   File "<ipython-input-3-17925e197079>", line 52, in worker_task
# ray.exceptions.RayActorError: The actor died unexpectedly before finishing this task.

# %%
print(1)

# %%
local_test_loader = generate_test_loader(64)
local_train_loader = generate_train_loader(64,{'num_workers': 1, 'pin_memory': True})

test_writer = SummaryWriter()

local_test_model = models.__dict__["resnet"](dataset="cifar10",depth=args.depth)
checkpoint = torch.load('/userhome/34/gyu/logs_part_bns_56/checkpoint.pth.tar')
local_test_model.load_state_dict(checkpoint['state_dict'])
local_test_model.cuda()

# %%
def test_model(model, test_dataloader):
    local_test_model = model
    local_test_loader = test_dataloader
    # local_test_model.train()
    local_test_model.eval()
    # test dataset loader 
    test_loss = 0.
    correct = 0.
    batch_count = 0.
    for data, target in local_test_loader:
        data,target = data.cuda(),target.cuda()
        batch_count += 1
        data, target = Variable(data, volatile=True), Variable(target)
        output = local_test_model(data)
        test_loss += F.cross_entropy(output, target, size_average=False).data # sum up batch loss
        pred = output.data.max(1, keepdim=True)[1] # get the index of the max log-probability
        batch_correct = pred.eq(target.data.view_as(pred)).sum()
        correct += batch_correct
#         if batch_count % 100  == 0:
#             print("        with model.eval(), batch num: ",batch_count, " with correct: ",int(batch_correct.data), " / ",len(data))

    test_loss /= len(local_test_loader.dataset)

    print('\nTest set: Average loss: {:.4f}, Accuracy: {}/{} ({:.6f})\n'.format(
        test_loss, correct, len(local_test_loader.dataset),
        correct / float(len(local_test_loader.dataset))))

# %%
local_test_model.eval()
test_model(local_test_model,local_test_loader)

# %%
# train dataset loader, but set model.eval(), acc=11% for one epoch 
# local_test_model.eval()
local_test_model.train()
# train dataset loader

test_loss = 0.
correct = 0.
train_batch_count = 0.
num_batch = 0
for data, target in local_train_loader:
    if train_batch_count % 10 == 0:
        print(train_batch_count)
        local_test_model.eval()
        test_model(local_test_model,local_test_loader)
        
    if train_batch_count==100:
        break
        
    num_batch += 1   
    local_test_model.train()
    data,target = data.cuda(),target.cuda()
    train_batch_count += 1
    data, target = Variable(data, volatile=True), Variable(target)
    output = local_test_model(data)
    test_loss += F.cross_entropy(output, target, size_average=False).data # sum up batch loss
    pred = output.data.max(1, keepdim=True)[1] # get the index of the max log-probability
    batch_correct = pred.eq(target.data.view_as(pred)).sum()
    correct += batch_correct
    
    for name,param in local_test_model.named_parameters():
        test_writer.add_histogram(name, param, num_batch)

    
#     if train_batch_count % 100  == 0:
#         print("With model.train(), batch num: ",train_batch_count, " , with correct: ",int(batch_correct.data), " / ", len(data))

test_loss /= len(local_train_loader.dataset)
print('\nTrain set: Average loss: {:.4f}, Accuracy: {}/{} ({:.6f})\n'.format(
    test_loss, correct, len(local_train_loader.dataset),
    correct / float(len(local_train_loader.dataset))))

# %%
local_bns

# %%
local_bns2,local_nonbns2 = _get_params(local_test_model)

# %%
local_bns2

# %%
state_dict = ray.get(ps.pull_weights.remote())

# %%
non_bn={}
for ele in state_dict:
    if 'bn' not in ele:
        non_bn[ele]=state_dict[ele]

# %%
init_wei = ray.get(ps.pull_weights.remote())

# %%
init_wei[]
