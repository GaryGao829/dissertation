# %%
# pytorch optimizer 让动量参与计算，以及手动修改lr

from __future__ import absolute_import
from __future__ import division
from __future__ import print_function

import argparse
import numpy as np

import ray
import models
import random,time
from time import sleep
import copy 
import datetime
import argparse
import sys


import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torchvision import datasets, transforms
from torch.autograd import Variable
import numpy as np
import os
import shutil
from torch.utils.tensorboard import SummaryWriter
from filelock import FileLock
# Out:
# /userhome/34/gyu/anaconda3/envs/pytorch_env/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:541: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /userhome/34/gyu/anaconda3/envs/pytorch_env/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:542: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /userhome/34/gyu/anaconda3/envs/pytorch_env/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:543: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /userhome/34/gyu/anaconda3/envs/pytorch_env/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:544: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /userhome/34/gyu/anaconda3/envs/pytorch_env/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:545: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /userhome/34/gyu/anaconda3/envs/pytorch_env/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:550: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])

# %%
def generate_train_loader(batch_size,kwargs):
    train_loader = torch.utils.data.DataLoader(
        datasets.CIFAR10('./data.cifar10', train=True, download=True,
        transform=transforms.Compose([
            transforms.Pad(4),
            transforms.RandomCrop(32),
            transforms.RandomHorizontalFlip(),
            transforms.ToTensor(),
            transforms.Normalize((0.4914, 0.4822, 0.4465), (0.2023, 0.1994, 0.2010))
        ])),
    batch_size=batch_size, shuffle=True, **kwargs)
    return train_loader

def generate_test_loader(test_batch_size):
    test_loader = torch.utils.data.DataLoader(
        datasets.CIFAR10('./data.cifar10', train=False, transform=transforms.Compose([
            transforms.ToTensor(),
            transforms.Normalize((0.4914, 0.4822, 0.4465), (0.2023, 0.1994, 0.2010))
        ])),batch_size=test_batch_size, shuffle=True)
    return test_loader

def _get_params(model):
    bns = {}
    non_bns = {}
    param_count = 0.
    bn_param_count = 0.
    for name,param in model.named_parameters():
        param_count += len(param)
        if 'bn' in name:
            bns[name] = param
            bn_param_count += len(param)
        else:
            non_bns[name] = param
    print("bn params occupies: ",bn_param_count/param_count)
    return bns,non_bns

@ray.remote
class ParameterServer():
    def __init__(self,args,test_loader):
        self.model = models.__dict__["resnet"](dataset="cifar10",depth=args.depth)
        self.stalness_table = [0] * args.num_workers
        self.stalness_limit = args.stalness_limit 
        self.global_step = 0
        self.lr = args.lr
        self.args = args
        self.eva_model = models.__dict__["resnet"](dataset="cifar10",depth=args.depth)
        self.optimizer = optim.SGD(self.model.parameters(),
                          lr=args.lr,
                          momentum=args.momentum,
                          weight_decay=args.weight_decay)
        self.test_loader = test_loader
        self.model.cpu()
        self.eva_model.cpu()
        self.ps_writer = SummaryWriter(os.path.join(os.getcwd(),(args.tb_path+'/ps')))
        self.save_path = args.save
        self.num_workers = (int)(args.num_workers)
        
        # get point to all non_bns parameters
        self.non_bns = [param.data for name,param in self.model.named_parameters() if 'bn' not in name]
        self.bns = [param.data for name,param in self.model.named_parameters() if 'bn' in name]
        self.bns_sync = [None] * args.num_workers
        
        if args.refine:
            if os.path.isfile(args.refine):
                print('found pruned ckpt')
                checkpoint = torch.load(args.refine)
                self.model = models.__dict__['resnet'](dataset='cifar10', depth=args.depth, cfg=checkpoint['cfg'])
                self.model.load_state_dict(checkpoint['state_dict'])
                
        elif args.resume:
            if os.path.isfile(args.resume):
                print("=> loading checkpoint '{}'".format(args.resume))
                checkpoint = torch.load(args.resume)
                self.global_step = checkpoint['global_step']
                self.model.load_state_dict(checkpoint['state_dict'])
                self.optimizer.load_state_dict(checkpoint['optimizer'])
                self.stalness_table = [self.global_step/args.num_workers] * args.num_workers
                print("=> loaded checkpoint '{}' (global step: {})".format(args.resume, checkpoint['global_step']))                
                if 'epoch' in checkpoint: print("epoch: {}".format(checkpoint['epoch']))
            else:
                print("=> no checkpoint found at '{}'".format(args.resume))                    
                
    def apply_gradients(self, iter_diff, wk_idx, epoch):
        if args.debug: print("applying gradients from the ",wk_idx, " worker")
        
        # updata all params
        for idx, p in enumerate(self.model.parameters()):
            p.data -= iter_diff[idx]

#         if wk_idx == 0:
#             # updata all params
#             for idx, p in enumerate(self.model.parameters()):
#                 p.data -= iter_diff[idx]
#         else:
#             # only update non_bns params
#             for idx, tensor in enumerate(self.non_bns):
#                 tensor -= iter_diff[idx]
        
#         # only update non_bns params
#         for idx, tensor in enumerate(self.non_bns):
#             tensor -= iter_diff[idx]
        
        self.stalness_table[wk_idx] += 1
        self.global_step += 1
        if args.debug: print("finished applying gradients from the ",wk_idx, " worker")
        if self.global_step % 1000 == 0:
#             print("global_step: ",self.global_step," and prepare evaluate")
#             self.evaluate()
            self.save_ckpt({
                'epoch':epoch,
                'global_step':self.global_step,
                'state_dict':self.model.state_dict(),
                'optimizer':self.optimizer.state_dict()
            },filepath=os.path.join(os.getcwd(),self.save_path))
    
    def apply_gradients_with_running_bn(self,iter_diff,wk_idx,epoch):
        state = self.model.state_dict()
        for idx, p in enumerate(state):
            state[p] -= iter_diff[idx]
            
        self.stalness_table[wk_idx] += 1
        self.global_step += 1
        if args.debug: print("finished applying gradients from the ",wk_idx, " worker")
        if self.global_step % 1000 == 0:
            self.save_ckpt({
                'epoch':epoch,
                'global_step':self.global_step,
                'state_dict':self.model.state_dict(),
                'optimizer':self.optimizer.state_dict()
            },filepath=os.path.join(os.getcwd(),self.save_path))
#         if self.global_step % 3000 == 0:
#             print("global_step: ",self.global_step," and prepare evaluate")
#             self.evaluate()

    
    def apply_gradients_non_bns(self,iter_diff,wk_idx,epoch):
        for i in range(len(self.non_bns)):
            self.non_bns[i] -= iter_diff[i]
#         print(wk_idx,"finished updating non bns on ps")

        
    def apply_gradients_bns(self,iter_diff,wk_idx,epoch):
        for idx, tensor in enumerate(self.bns):
#             if idx == len(iter_diff) / 2:
#                 print(wk_idx,"is in the middle of updating bns on ps")
            tensor -= iter_diff[idx]
#         print(wk_idx,"finished updating non bns on ps")
#         self.stalness_table[wk_idx] += 1
#         self.global_step += 1

    def apply_gradients_partical_bns(self, iter_diff, wk_idx, epoch):
        if wk_idx == 0 :
            for i in range(0,(int)(len(self.bns)/self.num_workers)):
                self.bns[i] -= iter_diff[i]
        elif wk_idx == self.num_workers:
            for i in range((int)(len(self.bns) * wk_idx / self.num_workers + 1) , len(self.bns)):
                self.bns[i] -= iter_diff[i]
        else:
            for i in range((int)(len(self.bns) * wk_idx / self.num_workers + 1) , (int)(len(self.bns) * (wk_idx + 1) / self.num_workers)):
                self.bns[i] -= iter_diff[i]
        self.stalness_table[wk_idx] += 1
        self.global_step += 1
        if self.global_step % 1000 == 0:
            self.save_ckpt({
                'epoch':epoch,
                'global_step':self.global_step,
                'state_dict':self.model.state_dict(),
                'optimizer':self.optimizer.state_dict()
            },filepath=os.path.join(os.getcwd(),self.save_path))

        
    def pull_weights(self):
        return self.model.state_dict()
    
    def pull_non_bn_weights(self):
        self.non_bns = [param.data for name,param in self.model.named_parameters() if 'bn' not in name]
        return copy.deepcopy(self.non_bns)
    
    def pull_bn_weights(self):
        self.bns = [param.data for name,param in self.model.named_parameters() if 'bn' in name]
        return copy.deepcopy(self.bns)
    
    def get_optim(self):
        return self.optimizer
    
    def pull_optimizer_state(self):
        return self.optimizer.state_dict()

    def check_stalness(self,wk_idx):
        min_iter = min(self.stalness_table)
        return self.stalness_table[wk_idx] - min_iter < self.stalness_limit
        
    def get_stalness(self):
        return min(self.stalness_table)
    
    def get_stalness_table(self):
        return self.stalness_table
    
    def get_global_step(self):
        return self.global_step
    
    def get_model(self):
        return self.model
    
    def save_ckpt(self,state,filepath):
        torch.save(state,os.path.join(filepath,'checkpoint.pth.tar'))
    
    def get_bns_ready(self):
        return any(self.bns_sync) == False
        
    def aggregate_bns(self,wk_bns,worker_index):
        self.bns_sync[worker_index] = wk_bns
        if all(self.bns_sync):
            for i in range(len(self.bns)):
                tmp = copy.deepcopy(self.bns_sync[0][i])
                for j in range(1, self.num_workers):
                    tmp += self.bns_sync[j][i]
                self.bns[i] = tmp / self.num_workers    
            self.bns_sync = [None] * self.num_workers
        return self.bns_sync
    
    def evaluate(self):
        print("going to evaluate")
        test_loss = 0.
        correct = 0.
        print("pulled weights")
        self.eva_model.load_state_dict(copy.deepcopy(self.model.state_dict()))
        print("loaded weights")
        print("length of the test_loader dataset is : ",len(self.test_loader.dataset))
        self.eva_model.eval()
        count = 0
        for data,target in self.test_loader:
            count += 1
            if count % 20 == 0: print("in eval, the batch is: ",count)
            data, target = Variable(data,volatile=True),Variable(target)
            output = self.eva_model(data)
            batch_loss = F.cross_entropy(output, target, size_average=False).data
            test_loss += batch_loss
            pred = output.data.max(1, keepdim=True)[1]
            correct += pred.eq(target.data.view_as(pred)).cpu().sum()
        len_testset = len(self.test_loader.dataset)
        test_loss /= len_testset 
        accuracy = correct / len_testset
        # log 
        print('\nTest set: Average loss: {:.4f}, Accuracy: {}/{} ({:.1f}%)\n'.format(
        test_loss, correct, len_testset,accuracy))

        self.ps_writer.add_scalar('Accuracy/eval', accuracy, self.global_step)
        self.ps_writer.add_scalar('Loss/eval',test_loss , self.global_step)

# %%
@ray.remote(num_gpus=1)
def worker_task(args,ps,worker_index, train_loader):
    # Initialize the model.
#     if args.debug: print(worker_index, " worker is going to sleep ",worker_index*5000)
#     time.sleep(worker_index * 5000)
    
    model = models.__dict__["resnet"](dataset="cifar10",depth=args.depth)
    local_step = 0
    
    wk_non_bns = [param.data for name,param in model.named_parameters() if 'bn' not in name]
    wk_bns = [param.data for name,param in model.named_parameters() if 'bn' in name]
    
    if args.cuda:
        starttime = datetime.datetime.now()
        model.cuda()
        endtime = datetime.datetime.now()
        time_cost = (endtime - starttime).seconds
        if args.debug: print("move model to gpu takes: ", time_cost, "seconds")
            
    # all workers owns the same init values
    init_wei = ray.get(ps.pull_weights.remote())
    model.load_state_dict(init_wei)
    sync_bns_flag = False
    
    optimizer = optim.SGD(model.parameters(),
                      lr=args.lr,
                      momentum=args.momentum,
                      weight_decay=args.weight_decay)
            
    if args.refine:
        if os.path.isfile(args.refine):
            print('found pruned ckpt')
            checkpoint = torch.load(args.refine)
            model = models.__dict__['resnet'](dataset='cifar10', depth=args.depth, cfg=checkpoint['cfg'])
            model.load_state_dict(checkpoint['state_dict'])
    elif args.resume:
        checkpoint = torch.load(args.resume)
        local_step = int(checkpoint['global_step'] / args.num_workers)
        optimizer.load_state_dict(checkpoint['optimizer'])
        print("worker #",worker_index,"resumes from local_step: ",local_step)
        if 'epoch' in checkpoint:
            args.start_epoch = checkpoint['epoch']
            
    
    wk_writer = SummaryWriter(os.path.join(os.getcwd(),args.tb_path,('wk_'+str(worker_index))))
    print("worker #",worker_index," is online")
    
#     if local_step in [5500,7000]:
    for param_group in optimizer.param_groups:
        print("previous lr: ",param_group['lr'])
        param_group['lr'] = 0.001
        print("new lr: ",param_group['lr'])

    
    for epoch in range(args.start_epoch,args.epochs):
        avg_loss = 0.
        train_correct = 0.
        for batch_idx,(data,target) in enumerate(train_loader):
            if args.cuda:
                starttime = datetime.datetime.now()
                data,target = data.cuda(),target.cuda()
                mid = datetime.datetime.now()
                if args.debug: print("move data to gpu takes: ", (mid - starttime).seconds, "seconds")
                model.cuda()
                endtime = datetime.datetime.now()
                time_cost = (endtime - starttime).seconds
                if args.debug: print("move model to gpu takes: ", time_cost, "seconds")
                
            while(local_step - ray.get(ps.get_stalness.remote()) > args.stalness_limit):
                sleep(1)
            

            # Get all weights from the parameter server.
            if args.debug: print("the ",worker_index," pulls wei from ps.")
            init_wei = ray.get(ps.pull_weights.remote())
            model.load_state_dict(init_wei)
            model.cpu()
#           # This doesn't contain BN running mean and var
#             old_tensors = copy.deepcopy([p.data for p in model.parameters()]) 

            old_tensors = copy.deepcopy([param.data for name, param in model.state_dict().items()])

            model.cuda()
#             if args.debug: print("the ",worker_index," loaded the latest wei from ps.")
#             model.cpu()    
#             wk_non_bns = [param.data for name,param in model.named_parameters() if 'bn' not in name]
#             wk_bns = [param.data for name,param in model.named_parameters() if 'bn' in name]
#             model.cuda()
#             old_tensors_non_bns = copy.deepcopy(wk_non_bns)
#             old_tensors_bns = copy.deepcopy(wk_bns)
                
#             # Get only non-bn weights from the parameter server.
#             ps_non_bns = ray.get(ps.pull_non_bn_weights.remote())
#             print(worker_index,"pulled non bns from ps")
#             assert len(ps_non_bns) == len(wk_non_bns)
#             for i in range(len(ps_non_bns)):
#                 if i == len(ps_non_bns) / 2:
#                     print(worker_index,"is in the middle of updating non bns")
#                 wk_non_bns[i] = ps_non_bns[i]
#             print(worker_index,"updated non bns from ps and is going to pull bns ")
            
#             # Get only bn weights from the parameter server.
#             ps_bns = ray.get(ps.pull_bn_weights.remote())
#             print(worker_index,"pulled bns from ps")
#             assert len(ps_bns) == len(wk_bns)
#             for i in range(len(ps_bns)):
#                 if i == len(ps_bns) / 2 :
#                     print(worker_index, "is in the middle of updating bns")
#                 wk_bns[i] = ps_bns[i]
#             print(worker_index,"updated bns from ps")

                
            # Compute an update and push it to the parameter server.        
            data, target = Variable(data), Variable(target)
            optimizer.zero_grad()
            if args.debug: print(worker_index,' is generating output')
            output = model(data)
            if args.debug: print(worker_index,' generated output done and going to calculate loss')
            loss = F.cross_entropy(output,target)
            avg_loss += loss
            pred = output.data.max(1,keepdim=True)[1]
            batch_correct = pred.eq(target.data.view_as(pred)).cpu().sum()
            train_correct += batch_correct
            if args.debug: print(worker_index,' calculated loss and going to bp')
            loss.backward()
            if args.debug: print(worker_index,' bp done')
            
            if(args.sr):
                # additional subgradient descent on the sparsity-induced penalty term
                for m in model.modules():
                    if isinstance(m, nn.BatchNorm2d):
                        m.weight.grad.data.add_(args.s*torch.sign(m.weight.data))  # L1

            
            # calculate difference for this iteration
            optimizer.step()
            model.cpu()
#           # This doesn't contain BN running mean and var            
#             new_tensors = [p.data for p in model.parameters()]
            new_tensors = [param.data for name, param in model.state_dict().items()]

            iter_diff = [(old_tensor - new_tensor)/args.num_workers for (old_tensor, new_tensor) in zip(old_tensors,new_tensors)]
            model.cuda()
            # print("passing sizes: ",sys.getsizeof(iter_diff))
#             ps.apply_gradients.remote(iter_diff,worker_index,epoch)
            ps.apply_gradients_with_running_bn.remote(iter_diff,worker_index,epoch)
#             else:
#                 old_tensors_non_bns = copy.deepcopy([param.data for name,param in model.named_parameters() if 'bn' not in name])
#                 optimizer.step()
#                 wk_non_bns = [param.data for name,param in model.named_parameters() if 'bn' not in name]
#                 iter_diff_non_bns = [(old_tensor_non_bns - new_tensor_non_bns)/args.num_workers for (old_tensor_non_bns, new_tensor_non_bns) in zip(old_tensors_non_bns,wk_non_bns)]
#                 ps.apply_gradients_non_bns.remote(iter_diff_non_bns,worker_index,epoch)
        

                
            
#             if worker_index == 0:
# #                 print(worker_index, "passing all params")
#                 # calculate difference for this iteration
#                 old_tensors = copy.deepcopy([p.data for p in model.parameters()])    
#                 optimizer.step()
#                 new_tensors = [p.data for p in model.parameters()]
#                 iter_diff = [(old_tensor - new_tensor)/args.num_workers for (old_tensor, new_tensor) in zip(old_tensors,new_tensors)]
#                 # print("passing sizes: ",sys.getsizeof(iter_diff))
#                 ps.apply_gradients.remote(iter_diff,worker_index,epoch)
#             else:
# #                 print(worker_index, "passing non bn params")
#                 #calculate only non-bn parameters difference 
#                 old_tensors = copy.deepcopy([param.data for name,param in model.named_parameters() if 'bn' not in name])
#                 optimizer.step()
#                 new_tensors = [param.data for name,param in model.named_parameters() if 'bn' not in name]
#                 iter_diff = [(old_tensor - new_tensor)/args.num_workers for (old_tensor, new_tensor) in zip(old_tensors,new_tensors)]
#                 # print("passing sizes: ",sys.getsizeof(iter_diff))
#                 ps.apply_gradients.remote(iter_diff,worker_index,epoch)

#             # calculate bns and non_bns parameters difference
#             optimizer.step()
#             model.cpu()
#             new_tensors_non_bns = [param.data for name,param in model.named_parameters() if 'bn' not in name]
#             new_tensors_bns = [param.data for name,param in model.named_parameters() if 'bn' in name]
#             model.cuda()
#             iter_diff_non_bns = [(old_tensor_non_bns - new_tensor_non_bns)/args.num_workers for (old_tensor_non_bns, new_tensor_non_bns) in zip(old_tensors_non_bns,new_tensors_non_bns)]
#             iter_diff_bns = [(old_tensor_bns - new_tensor_bns)/args.num_workers for (old_tensor_bns, new_tensor_bns) in zip(old_tensors_bns,new_tensors_bns)]
#             # print("passing sizes: ",sys.getsizeof(iter_diff))
#             ps.apply_gradients_non_bns.remote(iter_diff_non_bns,worker_index,epoch)
#             print(worker_index, "pushed non bns to ps and is going to push bns to ps")
#             ps.apply_gradients_partical_bns.remote(iter_diff_bns,worker_index,epoch)
#             print(worker_index, "pushed bns to ps")
            
            
#             # aggregate and sync bn parameters    
#             if sync_bns_flag:
#                 print("SYNC BNS: worker #",worker_index," is checking to pull bns from ps ")
#                 if ray.get(ps.get_bns_ready.remote()):
#                     print("SYNC BNS: worker #",worker_index," is pulling bns from ps ")
#                     ps_wei = ray.get(ps.pull_weights.remote())
#                     model.load_state_dict(ps_wei)
#                     sync_bns_flag = False
#             if local_step % args.sync_bns == 0:
#                 sync_bns_flag = True
#                 model.cpu()
#                 if args.debug: print("SYNC BNS: goint to aggregate bns")
#                 wk_bns = [param.data for name,param in model.named_parameters() if 'bn' in name]
#                 bns_sync = ray.get(ps.aggregate_bns.remote(wk_bns,worker_index))
#                 print("SYNC BNS: bns of worker #",worker_index," have been pushed")
                
#                 if any(bns_sync) == False: # when all workers have pushed their own bns parameters to ps
#                     print("SYNC BNS: worker #",worker_index," is last worker pushed its bns")
#                     ps_wei = ray.get(ps.pull_weights.remote())
#                     model.load_state_dict(ps_wei)
#                     sync_bns_flag = False
#                 if args.cuda: model.cuda()
            
                
                
                
            
#             if local_step in [5500,7000]:
#                 for param_group in optimizer.param_groups:
#                     print("previous lr: ",param_group['lr'])
#                     param_group['lr'] *= 0.1
#                     print("new lr: ",param_group['lr'])
                
            local_step += 1

            if batch_idx % args.log_interval == 0:
                print('The {} worker, Train Epoch: {} [{}/{} ({:.1f}%)]\tLoss: {:.6f}'.format(
                worker_index, epoch, batch_idx * len(data), len(train_loader.dataset),
                100. * batch_idx / len(train_loader), loss.data))
                
                for name,param in model.named_parameters():
                    wk_writer.add_histogram(name, param, local_step)

                wk_writer.add_scalar("Loss/worker_train",loss,local_step)
                wk_writer.add_scalar("Accuracy/worker_train",batch_correct.float()/len(data),local_step)
                
        print("The {} worker finished its {} epoch with loss: {} and accuracy: {}".format(
            worker_index,
            epoch,
            avg_loss / float(len(train_loader.dataset)),
            train_correct.float() / float(len(train_loader.dataset))
        ))

# %%
parser = argparse.ArgumentParser(description='Distributed SSP CIFAR-10 Restnet train with network slimming')
parser.add_argument('--ray-master',type=str,default='127.0.0.1')
parser.add_argument('--redis-port',type=str,default='6379')
parser.add_argument('--batch-size',type=int,default=64)
parser.add_argument('--test-batch-size', type=int, default=64)
parser.add_argument('--epochs', type=int, default=160)
parser.add_argument('--start-epoch', default=0, type=int)
parser.add_argument('--lr', type=float, default=0.01)
parser.add_argument('--momentum', type=float, default=0.9)
parser.add_argument('--weight-decay', '--wd', default=1e-4, type=float)
parser.add_argument('--resume', default=None, type=str) 
parser.add_argument('--refine', default=None, type=str) 
parser.add_argument('--no-cuda', action='store_true', default=False)
parser.add_argument('--save', default='./logs', type=str)
parser.add_argument('--depth', default=164, type=int)
parser.add_argument('--tb-path', default='./logs', type=str)
parser.add_argument('--log-interval', type=int, default=100)
parser.add_argument('--num-workers',type=int,default=1)
parser.add_argument('--stalness-limit',type=int,default=5)
parser.add_argument('--debug',action='store_true',default=False)
parser.add_argument('--sync-bns',type=int, default=194)
parser.add_argument('--sparsity-regularization', '-sr', dest='sr', action='store_true',
                    help='train with channel sparsity regularization')
parser.add_argument('--s', type=float, default=0.0001,
                    help='scale sparse rate (default: 0.0001)')


args = parser.parse_args(args=['-sr','--s=0.00001','--num-workers=3','--tb-path=/userhome/34/gyu/logs_sr','--save=/userhome/34/gyu/logs_sr','--resume=/userhome/34/gyu/logs_sr/checkpoint.pth.tar'])
# '--resume=/userhome/34/gyu/logs_sr/checkpoint.pth.tar'
# '--tb-path=logs_no_bns','--save=logs_no_bns'

args.cuda = not args.no_cuda and torch.cuda.is_available()

# %%
if ray.is_initialized():
    ray.shutdown()

# %%
ray.init(address=args.ray_master+':'+args.redis_port)
# Out:
# {'node_ip_address': '10.21.5.132',
#  'redis_address': '10.21.5.132:6379',
#  'object_store_address': '/tmp/ray/session_2019-12-16_12-44-03_367671_28012/sockets/plasma_store',
#  'raylet_socket_name': '/tmp/ray/session_2019-12-16_12-44-03_367671_28012/sockets/raylet',
#  'webui_url': 'http://10.21.5.132:8080/?token=5c1a32cee7a3eb0090623519f574fd10793b8ee7bd1a5513',
#  'session_dir': '/tmp/ray/session_2019-12-16_12-44-03_367671_28012'}

# %%
kwargs = {'num_workers': 1, 'pin_memory': True} if args.cuda else {}

test_loader = generate_test_loader(args.test_batch_size)
train_loaders = [generate_train_loader(args.batch_size,kwargs) for _ in range(args.num_workers)]

resume_from_ckpt = args.resume if (args.resume and os.path.isfile(args.resume)) else None

ps = ParameterServer.remote(args,test_loader)
# Out:
# Files already downloaded and verified
# Files already downloaded and verified
# Files already downloaded and verified

# %%
worker_tasks = [worker_task.remote(args,ps,idx,train_loaders[idx]) for idx in range(args.num_workers)]
# Out:
# (pid=16063, ip=10.21.5.134) => loading checkpoint '/userhome/34/gyu/logs_sr/checkpoint.pth.tar'
# (pid=16063, ip=10.21.5.134) => loaded checkpoint '/userhome/34/gyu/logs_sr/checkpoint.pth.tar' (global step: 21000)
# (pid=16063, ip=10.21.5.134) epoch: 8
# (pid=12338, ip=10.21.5.133) /userhome/34/gyu/anaconda3/envs/pytorch_env/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:541: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=12338, ip=10.21.5.133)   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# (pid=12338, ip=10.21.5.133) /userhome/34/gyu/anaconda3/envs/pytorch_env/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:542: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=12338, ip=10.21.5.133)   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# (pid=12338, ip=10.21.5.133) /userhome/34/gyu/anaconda3/envs/pytorch_env/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:543: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=12338, ip=10.21.5.133)   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# (pid=12338, ip=10.21.5.133) /userhome/34/gyu/anaconda3/envs/pytorch_env/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:544: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=12338, ip=10.21.5.133)   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# (pid=12338, ip=10.21.5.133) /userhome/34/gyu/anaconda3/envs/pytorch_env/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:545: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=12338, ip=10.21.5.133)   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# (pid=12338, ip=10.21.5.133) /userhome/34/gyu/anaconda3/envs/pytorch_env/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:550: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=12338, ip=10.21.5.133)   np_resource = np.dtype([("resource", np.ubyte, 1)])
# (pid=29313) /userhome/34/gyu/anaconda3/envs/pytorch_env/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:541: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=29313)   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# (pid=29313) /userhome/34/gyu/anaconda3/envs/pytorch_env/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:542: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=29313)   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# (pid=29313) /userhome/34/gyu/anaconda3/envs/pytorch_env/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:543: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=29313)   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# (pid=29313) /userhome/34/gyu/anaconda3/envs/pytorch_env/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:544: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=29313)   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# (pid=29313) /userhome/34/gyu/anaconda3/envs/pytorch_env/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:545: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=29313)   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# (pid=29313) /userhome/34/gyu/anaconda3/envs/pytorch_env/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:550: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=29313)   np_resource = np.dtype([("resource", np.ubyte, 1)])
# (pid=12338, ip=10.21.5.133) worker # 0 resumes from local_step:  7000
# (pid=12338, ip=10.21.5.133) worker # 0  is online
# (pid=12338, ip=10.21.5.133) previous lr:  0.1
# (pid=12338, ip=10.21.5.133) new lr:  0.001
# (pid=12338, ip=10.21.5.133) The 0 worker, Train Epoch: 8 [0/50000 (0.0%)]	Loss: 0.167990
# (pid=29313) worker # 1 resumes from local_step:  7000
# (pid=29313) worker # 1  is online
# (pid=29313) previous lr:  0.1
# (pid=29313) new lr:  0.001
# (pid=29313) The 1 worker, Train Epoch: 8 [0/50000 (0.0%)]	Loss: 0.066632
# 2019-12-16 13:30:43,656	WARNING worker.py:1779 -- The actor or task with ID 6d63d2544fafffffffff04000000 is pending and cannot currently be scheduled. It requires {CPU: 1.000000}, {GPU: 1.000000} for execution and {CPU: 1.000000}, {GPU: 1.000000} for placement, but this node only has remaining {GPU: 1.000000}, {CPU: 4.000000}, {memory: 13.330078 GiB}, {object_store_memory: 3.906250 GiB}. In total there are 1 pending tasks and 0 pending actors on this node. This is likely due to all cluster resources being claimed by actors. To resolve the issue, consider creating fewer actors or increase the resources available to this Ray cluster.
# 2019-12-16 13:30:46,002	WARNING worker.py:1779 -- WARNING: 12 PYTHON workers have been started. This could be a result of using a large number of actors, or it could be a consequence of using nested tasks (see https://github.com/ray-project/ray/issues/3644) for some a discussion of workarounds.
# (pid=16712, ip=10.21.5.134) /userhome/34/gyu/anaconda3/envs/pytorch_env/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:541: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=16712, ip=10.21.5.134)   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# (pid=16712, ip=10.21.5.134) /userhome/34/gyu/anaconda3/envs/pytorch_env/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:542: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=16712, ip=10.21.5.134)   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# (pid=16712, ip=10.21.5.134) /userhome/34/gyu/anaconda3/envs/pytorch_env/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:543: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=16712, ip=10.21.5.134)   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# (pid=16712, ip=10.21.5.134) /userhome/34/gyu/anaconda3/envs/pytorch_env/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:544: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=16712, ip=10.21.5.134)   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# (pid=16712, ip=10.21.5.134) /userhome/34/gyu/anaconda3/envs/pytorch_env/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:545: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=16712, ip=10.21.5.134)   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# (pid=16712, ip=10.21.5.134) /userhome/34/gyu/anaconda3/envs/pytorch_env/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:550: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=16712, ip=10.21.5.134)   np_resource = np.dtype([("resource", np.ubyte, 1)])
# (pid=16711, ip=10.21.5.134) /userhome/34/gyu/anaconda3/envs/pytorch_env/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:541: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=16711, ip=10.21.5.134)   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# (pid=16711, ip=10.21.5.134) /userhome/34/gyu/anaconda3/envs/pytorch_env/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:542: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=16711, ip=10.21.5.134)   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# (pid=16711, ip=10.21.5.134) /userhome/34/gyu/anaconda3/envs/pytorch_env/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:543: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=16711, ip=10.21.5.134)   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# (pid=16711, ip=10.21.5.134) /userhome/34/gyu/anaconda3/envs/pytorch_env/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:544: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=16711, ip=10.21.5.134)   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# (pid=16711, ip=10.21.5.134) /userhome/34/gyu/anaconda3/envs/pytorch_env/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:545: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=16711, ip=10.21.5.134)   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# (pid=16711, ip=10.21.5.134) /userhome/34/gyu/anaconda3/envs/pytorch_env/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:550: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=16711, ip=10.21.5.134)   np_resource = np.dtype([("resource", np.ubyte, 1)])
# (pid=16713, ip=10.21.5.134) /userhome/34/gyu/anaconda3/envs/pytorch_env/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:541: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=16713, ip=10.21.5.134)   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# (pid=16713, ip=10.21.5.134) /userhome/34/gyu/anaconda3/envs/pytorch_env/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:542: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=16713, ip=10.21.5.134)   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# (pid=16713, ip=10.21.5.134) /userhome/34/gyu/anaconda3/envs/pytorch_env/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:543: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=16713, ip=10.21.5.134)   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# (pid=16713, ip=10.21.5.134) /userhome/34/gyu/anaconda3/envs/pytorch_env/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:544: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=16713, ip=10.21.5.134)   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# (pid=16713, ip=10.21.5.134) /userhome/34/gyu/anaconda3/envs/pytorch_env/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:545: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=16713, ip=10.21.5.134)   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# (pid=16713, ip=10.21.5.134) /userhome/34/gyu/anaconda3/envs/pytorch_env/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:550: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=16713, ip=10.21.5.134)   np_resource = np.dtype([("resource", np.ubyte, 1)])
# (pid=16710, ip=10.21.5.134) /userhome/34/gyu/anaconda3/envs/pytorch_env/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:541: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=16710, ip=10.21.5.134)   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# (pid=16710, ip=10.21.5.134) /userhome/34/gyu/anaconda3/envs/pytorch_env/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:542: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=16710, ip=10.21.5.134)   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# (pid=16710, ip=10.21.5.134) /userhome/34/gyu/anaconda3/envs/pytorch_env/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:543: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=16710, ip=10.21.5.134)   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# (pid=16710, ip=10.21.5.134) /userhome/34/gyu/anaconda3/envs/pytorch_env/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:544: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=16710, ip=10.21.5.134)   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# (pid=16710, ip=10.21.5.134) /userhome/34/gyu/anaconda3/envs/pytorch_env/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:545: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=16710, ip=10.21.5.134)   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# (pid=16710, ip=10.21.5.134) /userhome/34/gyu/anaconda3/envs/pytorch_env/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:550: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=16710, ip=10.21.5.134)   np_resource = np.dtype([("resource", np.ubyte, 1)])
# (pid=16735, ip=10.21.5.134) /userhome/34/gyu/anaconda3/envs/pytorch_env/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:541: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=16735, ip=10.21.5.134)   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# (pid=16735, ip=10.21.5.134) /userhome/34/gyu/anaconda3/envs/pytorch_env/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:542: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=16735, ip=10.21.5.134)   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# (pid=16735, ip=10.21.5.134) /userhome/34/gyu/anaconda3/envs/pytorch_env/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:543: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=16735, ip=10.21.5.134)   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# (pid=16735, ip=10.21.5.134) /userhome/34/gyu/anaconda3/envs/pytorch_env/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:544: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=16735, ip=10.21.5.134)   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# (pid=16735, ip=10.21.5.134) /userhome/34/gyu/anaconda3/envs/pytorch_env/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:545: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=16735, ip=10.21.5.134)   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# (pid=16735, ip=10.21.5.134) /userhome/34/gyu/anaconda3/envs/pytorch_env/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:550: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=16735, ip=10.21.5.134)   np_resource = np.dtype([("resource", np.ubyte, 1)])
# (pid=16737, ip=10.21.5.134) /userhome/34/gyu/anaconda3/envs/pytorch_env/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:541: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=16737, ip=10.21.5.134)   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# (pid=16737, ip=10.21.5.134) /userhome/34/gyu/anaconda3/envs/pytorch_env/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:542: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=16737, ip=10.21.5.134)   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# (pid=16737, ip=10.21.5.134) /userhome/34/gyu/anaconda3/envs/pytorch_env/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:543: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=16737, ip=10.21.5.134)   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# (pid=16737, ip=10.21.5.134) /userhome/34/gyu/anaconda3/envs/pytorch_env/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:544: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=16737, ip=10.21.5.134)   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# (pid=16737, ip=10.21.5.134) /userhome/34/gyu/anaconda3/envs/pytorch_env/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:545: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=16737, ip=10.21.5.134)   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# (pid=16737, ip=10.21.5.134) /userhome/34/gyu/anaconda3/envs/pytorch_env/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:550: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=16737, ip=10.21.5.134)   np_resource = np.dtype([("resource", np.ubyte, 1)])
# (pid=16736, ip=10.21.5.134) /userhome/34/gyu/anaconda3/envs/pytorch_env/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:541: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=16736, ip=10.21.5.134)   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# (pid=16736, ip=10.21.5.134) /userhome/34/gyu/anaconda3/envs/pytorch_env/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:542: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=16736, ip=10.21.5.134)   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# (pid=16736, ip=10.21.5.134) /userhome/34/gyu/anaconda3/envs/pytorch_env/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:543: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=16736, ip=10.21.5.134)   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# (pid=16736, ip=10.21.5.134) /userhome/34/gyu/anaconda3/envs/pytorch_env/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:544: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=16736, ip=10.21.5.134)   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# (pid=16736, ip=10.21.5.134) /userhome/34/gyu/anaconda3/envs/pytorch_env/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:545: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=16736, ip=10.21.5.134)   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# (pid=16736, ip=10.21.5.134) /userhome/34/gyu/anaconda3/envs/pytorch_env/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:550: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=16736, ip=10.21.5.134)   np_resource = np.dtype([("resource", np.ubyte, 1)])
# (pid=16738, ip=10.21.5.134) /userhome/34/gyu/anaconda3/envs/pytorch_env/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:541: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=16738, ip=10.21.5.134)   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# (pid=16738, ip=10.21.5.134) /userhome/34/gyu/anaconda3/envs/pytorch_env/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:542: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=16738, ip=10.21.5.134)   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# (pid=16738, ip=10.21.5.134) /userhome/34/gyu/anaconda3/envs/pytorch_env/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:543: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=16738, ip=10.21.5.134)   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# (pid=16738, ip=10.21.5.134) /userhome/34/gyu/anaconda3/envs/pytorch_env/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:544: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=16738, ip=10.21.5.134)   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# (pid=16738, ip=10.21.5.134) /userhome/34/gyu/anaconda3/envs/pytorch_env/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:545: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=16738, ip=10.21.5.134)   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# (pid=16738, ip=10.21.5.134) /userhome/34/gyu/anaconda3/envs/pytorch_env/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:550: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=16738, ip=10.21.5.134)   np_resource = np.dtype([("resource", np.ubyte, 1)])
# (pid=16753, ip=10.21.5.134) /userhome/34/gyu/anaconda3/envs/pytorch_env/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:541: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=16753, ip=10.21.5.134)   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# (pid=16753, ip=10.21.5.134) /userhome/34/gyu/anaconda3/envs/pytorch_env/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:542: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=16753, ip=10.21.5.134)   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# (pid=16753, ip=10.21.5.134) /userhome/34/gyu/anaconda3/envs/pytorch_env/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:543: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=16753, ip=10.21.5.134)   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# (pid=16753, ip=10.21.5.134) /userhome/34/gyu/anaconda3/envs/pytorch_env/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:544: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=16753, ip=10.21.5.134)   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# (pid=16753, ip=10.21.5.134) /userhome/34/gyu/anaconda3/envs/pytorch_env/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:545: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=16753, ip=10.21.5.134)   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# (pid=16753, ip=10.21.5.134) /userhome/34/gyu/anaconda3/envs/pytorch_env/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:550: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=16753, ip=10.21.5.134)   np_resource = np.dtype([("resource", np.ubyte, 1)])
# (pid=16764, ip=10.21.5.134) /userhome/34/gyu/anaconda3/envs/pytorch_env/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:541: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=16764, ip=10.21.5.134)   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# (pid=16764, ip=10.21.5.134) /userhome/34/gyu/anaconda3/envs/pytorch_env/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:542: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=16764, ip=10.21.5.134)   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# (pid=16764, ip=10.21.5.134) /userhome/34/gyu/anaconda3/envs/pytorch_env/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:543: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=16764, ip=10.21.5.134)   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# (pid=16764, ip=10.21.5.134) /userhome/34/gyu/anaconda3/envs/pytorch_env/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:544: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=16764, ip=10.21.5.134)   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# (pid=16764, ip=10.21.5.134) /userhome/34/gyu/anaconda3/envs/pytorch_env/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:545: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=16764, ip=10.21.5.134)   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# (pid=16764, ip=10.21.5.134) /userhome/34/gyu/anaconda3/envs/pytorch_env/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:550: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=16764, ip=10.21.5.134)   np_resource = np.dtype([("resource", np.ubyte, 1)])
# (pid=16765, ip=10.21.5.134) /userhome/34/gyu/anaconda3/envs/pytorch_env/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:541: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=16765, ip=10.21.5.134)   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# (pid=16765, ip=10.21.5.134) /userhome/34/gyu/anaconda3/envs/pytorch_env/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:542: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=16765, ip=10.21.5.134)   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# (pid=16765, ip=10.21.5.134) /userhome/34/gyu/anaconda3/envs/pytorch_env/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:543: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=16765, ip=10.21.5.134)   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# (pid=16765, ip=10.21.5.134) /userhome/34/gyu/anaconda3/envs/pytorch_env/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:544: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=16765, ip=10.21.5.134)   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# (pid=16765, ip=10.21.5.134) /userhome/34/gyu/anaconda3/envs/pytorch_env/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:545: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=16765, ip=10.21.5.134)   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# (pid=16765, ip=10.21.5.134) /userhome/34/gyu/anaconda3/envs/pytorch_env/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:550: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=16765, ip=10.21.5.134)   np_resource = np.dtype([("resource", np.ubyte, 1)])
# (pid=16712, ip=10.21.5.134) worker # 2 resumes from local_step:  7000
# (pid=16712, ip=10.21.5.134) worker # 2  is online
# (pid=16712, ip=10.21.5.134) previous lr:  0.1
# (pid=16712, ip=10.21.5.134) new lr:  0.001
# (pid=16712, ip=10.21.5.134) The 2 worker, Train Epoch: 8 [0/50000 (0.0%)]	Loss: 0.129822
# (pid=29313) The 1 worker, Train Epoch: 8 [6400/50000 (12.8%)]	Loss: 0.174777
# (pid=12338, ip=10.21.5.133) The 0 worker, Train Epoch: 8 [6400/50000 (12.8%)]	Loss: 0.131989
# (pid=16712, ip=10.21.5.134) The 2 worker, Train Epoch: 8 [6400/50000 (12.8%)]	Loss: 0.080532

# %%
print(1)
# Out:
# 1
# (pid=12338, ip=10.21.5.133) The 0 worker, Train Epoch: 8 [12800/50000 (25.6%)]	Loss: 0.231976
# (pid=29313) The 1 worker, Train Epoch: 8 [12800/50000 (25.6%)]	Loss: 0.064827
# (pid=16712, ip=10.21.5.134) The 2 worker, Train Epoch: 8 [12800/50000 (25.6%)]	Loss: 0.122059
# (pid=29313) The 1 worker, Train Epoch: 8 [19200/50000 (38.4%)]	Loss: 0.113435
# (pid=12338, ip=10.21.5.133) The 0 worker, Train Epoch: 8 [19200/50000 (38.4%)]	Loss: 0.073640
# (pid=16712, ip=10.21.5.134) The 2 worker, Train Epoch: 8 [19200/50000 (38.4%)]	Loss: 0.204745
# (pid=29313) The 1 worker, Train Epoch: 8 [25600/50000 (51.2%)]	Loss: 0.078092
# (pid=12338, ip=10.21.5.133) The 0 worker, Train Epoch: 8 [25600/50000 (51.2%)]	Loss: 0.092043
# (pid=16712, ip=10.21.5.134) The 2 worker, Train Epoch: 8 [25600/50000 (51.2%)]	Loss: 0.120998
# (pid=29313) The 1 worker, Train Epoch: 8 [32000/50000 (63.9%)]	Loss: 0.056154
# (pid=12338, ip=10.21.5.133) The 0 worker, Train Epoch: 8 [32000/50000 (63.9%)]	Loss: 0.082258
# (pid=16712, ip=10.21.5.134) The 2 worker, Train Epoch: 8 [32000/50000 (63.9%)]	Loss: 0.152943
# (pid=29313) The 1 worker, Train Epoch: 8 [38400/50000 (76.7%)]	Loss: 0.070043
# (pid=12338, ip=10.21.5.133) The 0 worker, Train Epoch: 8 [38400/50000 (76.7%)]	Loss: 0.184220
# (pid=16712, ip=10.21.5.134) The 2 worker, Train Epoch: 8 [38400/50000 (76.7%)]	Loss: 0.059508
# (pid=12338, ip=10.21.5.133) The 0 worker, Train Epoch: 8 [44800/50000 (89.5%)]	Loss: 0.135755
# (pid=29313) The 1 worker, Train Epoch: 8 [44800/50000 (89.5%)]	Loss: 0.222125
# (pid=16712, ip=10.21.5.134) The 2 worker, Train Epoch: 8 [44800/50000 (89.5%)]	Loss: 0.109529
# (pid=12338, ip=10.21.5.133) The 0 worker finished its 8 epoch with loss: 0.0023835396859794855 and accuracy: 0.9478800296783447
# (pid=29313) The 1 worker finished its 8 epoch with loss: 0.0023910263553261757 and accuracy: 0.947920024394989
# (pid=12338, ip=10.21.5.133) The 0 worker, Train Epoch: 9 [0/50000 (0.0%)]	Loss: 0.100644
# (pid=29313) The 1 worker, Train Epoch: 9 [0/50000 (0.0%)]	Loss: 0.129957
# (pid=16712, ip=10.21.5.134) The 2 worker finished its 8 epoch with loss: 0.0023449219297617674 and accuracy: 0.9478399753570557
# (pid=16712, ip=10.21.5.134) The 2 worker, Train Epoch: 9 [0/50000 (0.0%)]	Loss: 0.144137
# (pid=12338, ip=10.21.5.133) The 0 worker, Train Epoch: 9 [6400/50000 (12.8%)]	Loss: 0.102221
# (pid=29313) The 1 worker, Train Epoch: 9 [6400/50000 (12.8%)]	Loss: 0.139162
# (pid=16712, ip=10.21.5.134) The 2 worker, Train Epoch: 9 [6400/50000 (12.8%)]	Loss: 0.179060
# (pid=12338, ip=10.21.5.133) The 0 worker, Train Epoch: 9 [12800/50000 (25.6%)]	Loss: 0.107885
# (pid=29313) The 1 worker, Train Epoch: 9 [12800/50000 (25.6%)]	Loss: 0.103104
# (pid=16712, ip=10.21.5.134) The 2 worker, Train Epoch: 9 [12800/50000 (25.6%)]	Loss: 0.180313
# (pid=12338, ip=10.21.5.133) The 0 worker, Train Epoch: 9 [19200/50000 (38.4%)]	Loss: 0.196010
# (pid=29313) The 1 worker, Train Epoch: 9 [19200/50000 (38.4%)]	Loss: 0.120780
# (pid=16712, ip=10.21.5.134) The 2 worker, Train Epoch: 9 [19200/50000 (38.4%)]	Loss: 0.136988
# (pid=12338, ip=10.21.5.133) The 0 worker, Train Epoch: 9 [25600/50000 (51.2%)]	Loss: 0.122471
# (pid=29313) The 1 worker, Train Epoch: 9 [25600/50000 (51.2%)]	Loss: 0.283457
# (pid=16712, ip=10.21.5.134) The 2 worker, Train Epoch: 9 [25600/50000 (51.2%)]	Loss: 0.158035

# %%
ray.get(ps.get_stalness.remote())

# %%
local_test_loader = generate_test_loader(64)
local_train_loader = generate_train_loader(64,{'num_workers': 1, 'pin_memory': True})
# Out:
# Files already downloaded and verified

# %%
test_writer = SummaryWriter()

local_test_model = models.__dict__["resnet"](dataset="cifar10",depth=164)
checkpoint = torch.load('/userhome/34/gyu/tmp/prune_40/ssp_refine_1wk/checkpoint.pth.tar')
local_test_model.load_state_dict(checkpoint['state_dict'])
local_test_model.cuda()

# %%
# load pruned model
local_test_loader = generate_test_loader(64)
local_train_loader = generate_train_loader(64,{'num_workers': 1, 'pin_memory': True})

test_writer = SummaryWriter()


checkpoint = torch.load(args.refine)
local_test_model = models.__dict__['resnet'](dataset='cifar10', depth=args.depth, cfg=checkpoint['cfg'])

checkpoint = torch.load('/userhome/34/gyu/tmp/prune_40/ssp_refine_1wk_runningbn/checkpoint.pth.tar')
local_test_model.load_state_dict(checkpoint['state_dict'])
local_test_model.cuda()

# %%
from torchsummary import summary
summary(local_test_model, input_size=(3, 32, 32))

# %%
data=[]
state = local_test_model.state_dict()
for idx, p in enumerate(state):
    data.append(state[p])

# %%
data[0][0][0][0][0] = 100

# %%
data2=[]
state2 = local_test_model.state_dict()
for idx, p in enumerate(state2):
    data2.append(state2[p])

# %%
data2[0][0][0][0][0]

# %%
state1 = local_test_model.state_dict()

# %%
state1['layer1.0.bn1.running_mean']

# %%
state1['layer1.0.bn1.running_var']

# %%
state1['layer1.0.bn1.weight']

# %%
state1['layer1.0.bn1.bias']

# %%
local_test_model = ray.get(ps.get_model.remote())

# %%
def test_model(model, test_dataloader):
    local_test_model = model
    local_test_loader = test_dataloader
    # local_test_model.train()
    local_test_model.eval()
    # test dataset loader 
    test_loss = 0.
    correct = 0.
    batch_count = 0.
    for data, target in local_test_loader:
        data,target = data.cuda(),target.cuda()
        batch_count += 1
        data, target = Variable(data, volatile=True), Variable(target)
        output = local_test_model(data)
        test_loss += F.cross_entropy(output, target, size_average=False).data # sum up batch loss
        pred = output.data.max(1, keepdim=True)[1] # get the index of the max log-probability
        batch_correct = pred.eq(target.data.view_as(pred)).sum()
        correct += batch_correct
#         if batch_count % 100  == 0:
#             print("        with model.eval(), batch num: ",batch_count, " with correct: ",int(batch_correct.data), " / ",len(data))

    test_loss /= len(local_test_loader.dataset)

    print('\nTest set: Average loss: {:.4f}, Accuracy: {}/{} ({:.6f})\n'.format(
        test_loss, correct, len(local_test_loader.dataset),
        correct / float(len(local_test_loader.dataset))))

# %%
local_test_model.eval()
local_test_model.cuda()
test_model(local_test_model,local_test_loader)
# Out:
# /userhome/34/gyu/anaconda3/envs/pytorch_env/lib/python3.7/site-packages/ipykernel_launcher.py:13: UserWarning: volatile was removed and now has no effect. Use `with torch.no_grad():` instead.
#   del sys.path[0]
# Test set: Average loss: 0.2663, Accuracy: 9110/10000 (0.000000)
#
# (pid=29313) The 1 worker, Train Epoch: 10 [19200/50000 (38.4%)]	Loss: 0.070545
# (pid=12338, ip=10.21.5.133) The 0 worker, Train Epoch: 10 [19200/50000 (38.4%)]	Loss: 0.143112
# (pid=16712, ip=10.21.5.134) The 2 worker, Train Epoch: 10 [19200/50000 (38.4%)]	Loss: 0.139001
# (pid=12338, ip=10.21.5.133) The 0 worker, Train Epoch: 10 [25600/50000 (51.2%)]	Loss: 0.070135
# (pid=29313) The 1 worker, Train Epoch: 10 [25600/50000 (51.2%)]	Loss: 0.057098
# (pid=16712, ip=10.21.5.134) The 2 worker, Train Epoch: 10 [25600/50000 (51.2%)]	Loss: 0.196494
# (pid=12338, ip=10.21.5.133) The 0 worker, Train Epoch: 10 [32000/50000 (63.9%)]	Loss: 0.217444
# (pid=29313) The 1 worker, Train Epoch: 10 [32000/50000 (63.9%)]	Loss: 0.108058
# (pid=16712, ip=10.21.5.134) The 2 worker, Train Epoch: 10 [32000/50000 (63.9%)]	Loss: 0.176464
# (pid=12338, ip=10.21.5.133) The 0 worker, Train Epoch: 10 [38400/50000 (76.7%)]	Loss: 0.088032
# (pid=29313) The 1 worker, Train Epoch: 10 [38400/50000 (76.7%)]	Loss: 0.112986
# (pid=16712, ip=10.21.5.134) The 2 worker, Train Epoch: 10 [38400/50000 (76.7%)]	Loss: 0.081880
# (pid=12338, ip=10.21.5.133) The 0 worker, Train Epoch: 10 [44800/50000 (89.5%)]	Loss: 0.177740
# (pid=29313) The 1 worker, Train Epoch: 10 [44800/50000 (89.5%)]	Loss: 0.185725
# (pid=16712, ip=10.21.5.134) The 2 worker, Train Epoch: 10 [44800/50000 (89.5%)]	Loss: 0.073555
# (pid=29313) The 1 worker finished its 10 epoch with loss: 0.0022336910478770733 and accuracy: 0.9519199728965759
# (pid=12338, ip=10.21.5.133) The 0 worker finished its 10 epoch with loss: 0.002255838830024004 and accuracy: 0.9506199955940247
# (pid=29313) The 1 worker, Train Epoch: 11 [0/50000 (0.0%)]	Loss: 0.236122
# (pid=12338, ip=10.21.5.133) The 0 worker, Train Epoch: 11 [0/50000 (0.0%)]	Loss: 0.252831
# (pid=16712, ip=10.21.5.134) The 2 worker finished its 10 epoch with loss: 0.002267595613375306 and accuracy: 0.9505400061607361
# (pid=16712, ip=10.21.5.134) The 2 worker, Train Epoch: 11 [0/50000 (0.0%)]	Loss: 0.086093
# (pid=12338, ip=10.21.5.133) The 0 worker, Train Epoch: 11 [6400/50000 (12.8%)]	Loss: 0.338290
# (pid=29313) The 1 worker, Train Epoch: 11 [6400/50000 (12.8%)]	Loss: 0.233773
# (pid=16712, ip=10.21.5.134) The 2 worker, Train Epoch: 11 [6400/50000 (12.8%)]	Loss: 0.086767
# (pid=29313) The 1 worker, Train Epoch: 11 [12800/50000 (25.6%)]	Loss: 0.170988
# (pid=12338, ip=10.21.5.133) The 0 worker, Train Epoch: 11 [12800/50000 (25.6%)]	Loss: 0.285625
# (pid=16712, ip=10.21.5.134) The 2 worker, Train Epoch: 11 [12800/50000 (25.6%)]	Loss: 0.116238
# (pid=12338, ip=10.21.5.133) The 0 worker, Train Epoch: 11 [19200/50000 (38.4%)]	Loss: 0.072554
# (pid=29313) The 1 worker, Train Epoch: 11 [19200/50000 (38.4%)]	Loss: 0.107515
# (pid=16712, ip=10.21.5.134) The 2 worker, Train Epoch: 11 [19200/50000 (38.4%)]	Loss: 0.140017
# (pid=12338, ip=10.21.5.133) The 0 worker, Train Epoch: 11 [25600/50000 (51.2%)]	Loss: 0.096725
# (pid=29313) The 1 worker, Train Epoch: 11 [25600/50000 (51.2%)]	Loss: 0.076720
# (pid=16712, ip=10.21.5.134) The 2 worker, Train Epoch: 11 [25600/50000 (51.2%)]	Loss: 0.098623
# 2019-12-16 14:27:20,968	ERROR worker.py:1719 -- Possible unhandled error from worker: ray_ParameterServer:get_stalness() (pid=16063, host=gpu-comp-104)
#   File "/userhome/34/gyu/anaconda3/envs/pytorch_env/lib/python3.7/site-packages/ray/memory_monitor.py", line 130, in raise_if_low_memory
#     self.error_threshold))
# ray.memory_monitor.RayOutOfMemoryError: More than 95% of the memory on node gpu-comp-104 is used (27.32 / 28.75 GB). The top 10 memory consumers are:
#
# PID	MEM	COMMAND
# 17530	16.29GiB	python /userhome/34/gyu/git-repo/rethinking-network-pruning/cifar/network-slimming/resprune.py --dat
# 16712	2.53GiB	ray_worker:__main__.worker_task()
# 17422	2.53GiB	ray_worker:__main__.worker_task()
# 16063	0.12GiB	ray_ParameterServer:get_stalness()
# 16711	0.09GiB	ray_worker
# 16765	0.09GiB	ray_worker
# 16738	0.09GiB	ray_worker
# 16710	0.09GiB	ray_worker
# 16764	0.09GiB	ray_worker
# 16753	0.09GiB	ray_worker
#
# In addition, up to 5.88 GiB of shared memory is currently being used by the Ray object store. You can set the object store size with the `object_store_memory` parameter when starting Ray, and the max Redis size with `redis_max_memory`. Note that Ray assumes all system memory is available for use by workers. If your system has other applications running, you should manually set these memory limits to a lower value.
#
# 2019-12-16 14:27:21,973	ERROR worker.py:1719 -- Possible unhandled error from worker: ray_worker:__main__.worker_task() (pid=12338, host=gpu-comp-103)
#   File "<ipython-input-3-c8386ab073bd>", line 69, in worker_task
# ray.exceptions.RayTaskError: ray_ParameterServer:get_stalness() (pid=16063, host=gpu-comp-104)
#   File "/userhome/34/gyu/anaconda3/envs/pytorch_env/lib/python3.7/site-packages/ray/memory_monitor.py", line 130, in raise_if_low_memory
#     self.error_threshold))
# ray.memory_monitor.RayOutOfMemoryError: More than 95% of the memory on node gpu-comp-104 is used (27.32 / 28.75 GB). The top 10 memory consumers are:
#
# PID	MEM	COMMAND
# 17530	16.29GiB	python /userhome/34/gyu/git-repo/rethinking-network-pruning/cifar/network-slimming/resprune.py --dat
# 16712	2.53GiB	ray_worker:__main__.worker_task()
# 17422	2.53GiB	ray_worker:__main__.worker_task()
# 16063	0.12GiB	ray_ParameterServer:get_stalness()
# 16711	0.09GiB	ray_worker
# 16765	0.09GiB	ray_worker
# 16738	0.09GiB	ray_worker
# 16710	0.09GiB	ray_worker
# 16764	0.09GiB	ray_worker
# 16753	0.09GiB	ray_worker
#
# In addition, up to 5.88 GiB of shared memory is currently being used by the Ray object store. You can set the object store size with the `object_store_memory` parameter when starting Ray, and the max Redis size with `redis_max_memory`. Note that Ray assumes all system memory is available for use by workers. If your system has other applications running, you should manually set these memory limits to a lower value.
#
#
# 2019-12-16 14:27:28,532	ERROR worker.py:1719 -- Possible unhandled error from worker: ray_ParameterServer:apply_gradients_with_running_bn() (pid=16063, host=gpu-comp-104)
#   File "/userhome/34/gyu/anaconda3/envs/pytorch_env/lib/python3.7/site-packages/ray/memory_monitor.py", line 130, in raise_if_low_memory
#     self.error_threshold))
# ray.memory_monitor.RayOutOfMemoryError: More than 95% of the memory on node gpu-comp-104 is used (27.37 / 28.75 GB). The top 10 memory consumers are:
#
# PID	MEM	COMMAND
# 17530	16.31GiB	python /userhome/34/gyu/git-repo/rethinking-network-pruning/cifar/network-slimming/resprune.py --dat
# 16712	2.53GiB	ray_worker:__main__.worker_task()
# 17422	2.53GiB	ray_worker:__main__.worker_task()
# 16063	0.12GiB	ray_ParameterServer:apply_gradients_with_running_bn()
# 16711	0.09GiB	ray_worker
# 16765	0.09GiB	ray_worker
# 16738	0.09GiB	ray_worker
# 16710	0.09GiB	ray_worker
# 16764	0.09GiB	ray_worker
# 16753	0.09GiB	ray_worker
#
# In addition, up to 5.88 GiB of shared memory is currently being used by the Ray object store. You can set the object store size with the `object_store_memory` parameter when starting Ray, and the max Redis size with `redis_max_memory`. Note that Ray assumes all system memory is available for use by workers. If your system has other applications running, you should manually set these memory limits to a lower value.
#
# 2019-12-16 14:27:34,397	ERROR worker.py:1719 -- Possible unhandled error from worker: ray_ParameterServer:get_stalness() (pid=16063, host=gpu-comp-104)
#   File "/userhome/34/gyu/anaconda3/envs/pytorch_env/lib/python3.7/site-packages/ray/memory_monitor.py", line 130, in raise_if_low_memory
#     self.error_threshold))
# ray.memory_monitor.RayOutOfMemoryError: More than 95% of the memory on node gpu-comp-104 is used (27.32 / 28.75 GB). The top 10 memory consumers are:
#
# PID	MEM	COMMAND
# 17530	16.29GiB	python /userhome/34/gyu/git-repo/rethinking-network-pruning/cifar/network-slimming/resprune.py --dat
# 16712	2.53GiB	ray_worker:__main__.worker_task()
# 17422	2.53GiB	ray_worker:__main__.worker_task()
# 16063	0.12GiB	ray_ParameterServer:get_stalness()
# 16711	0.09GiB	ray_worker
# 16765	0.09GiB	ray_worker
# 16738	0.09GiB	ray_worker
# 16710	0.09GiB	ray_worker
# 16764	0.09GiB	ray_worker
# 16753	0.09GiB	ray_worker
#
# In addition, up to 5.88 GiB of shared memory is currently being used by the Ray object store. You can set the object store size with the `object_store_memory` parameter when starting Ray, and the max Redis size with `redis_max_memory`. Note that Ray assumes all system memory is available for use by workers. If your system has other applications running, you should manually set these memory limits to a lower value.
#
# 2019-12-16 14:27:35,400	ERROR worker.py:1719 -- Possible unhandled error from worker: ray_worker:__main__.worker_task() (pid=29313, host=gpu-comp-102)
#   File "<ipython-input-3-c8386ab073bd>", line 69, in worker_task
# ray.exceptions.RayTaskError: ray_ParameterServer:get_stalness() (pid=16063, host=gpu-comp-104)
#   File "/userhome/34/gyu/anaconda3/envs/pytorch_env/lib/python3.7/site-packages/ray/memory_monitor.py", line 130, in raise_if_low_memory
#     self.error_threshold))
# ray.memory_monitor.RayOutOfMemoryError: More than 95% of the memory on node gpu-comp-104 is used (27.32 / 28.75 GB). The top 10 memory consumers are:
#
# PID	MEM	COMMAND
# 17530	16.29GiB	python /userhome/34/gyu/git-repo/rethinking-network-pruning/cifar/network-slimming/resprune.py --dat
# 16712	2.53GiB	ray_worker:__main__.worker_task()
# 17422	2.53GiB	ray_worker:__main__.worker_task()
# 16063	0.12GiB	ray_ParameterServer:get_stalness()
# 16711	0.09GiB	ray_worker
# 16765	0.09GiB	ray_worker
# 16738	0.09GiB	ray_worker
# 16710	0.09GiB	ray_worker
# 16764	0.09GiB	ray_worker
# 16753	0.09GiB	ray_worker
#
# In addition, up to 5.88 GiB of shared memory is currently being used by the Ray object store. You can set the object store size with the `object_store_memory` parameter when starting Ray, and the max Redis size with `redis_max_memory`. Note that Ray assumes all system memory is available for use by workers. If your system has other applications running, you should manually set these memory limits to a lower value.
#
#
# 2019-12-16 14:27:38,405	ERROR worker.py:1719 -- Possible unhandled error from worker: ray_ParameterServer:apply_gradients_with_running_bn() (pid=16063, host=gpu-comp-104)
#   File "/userhome/34/gyu/anaconda3/envs/pytorch_env/lib/python3.7/site-packages/ray/memory_monitor.py", line 130, in raise_if_low_memory
#     self.error_threshold))
# ray.memory_monitor.RayOutOfMemoryError: More than 95% of the memory on node gpu-comp-104 is used (27.39 / 28.75 GB). The top 10 memory consumers are:
#
# PID	MEM	COMMAND
# 17530	16.35GiB	python /userhome/34/gyu/git-repo/rethinking-network-pruning/cifar/network-slimming/resprune.py --dat
# 16712	2.53GiB	ray_worker:__main__.worker_task()
# 17422	2.53GiB	ray_worker:__main__.worker_task()
# 16063	0.12GiB	ray_ParameterServer:apply_gradients_with_running_bn()
# 16711	0.09GiB	ray_worker
# 16765	0.09GiB	ray_worker
# 16738	0.09GiB	ray_worker
# 16710	0.09GiB	ray_worker
# 16764	0.09GiB	ray_worker
# 16753	0.09GiB	ray_worker
#
# In addition, up to 5.88 GiB of shared memory is currently being used by the Ray object store. You can set the object store size with the `object_store_memory` parameter when starting Ray, and the max Redis size with `redis_max_memory`. Note that Ray assumes all system memory is available for use by workers. If your system has other applications running, you should manually set these memory limits to a lower value.
# 2019-12-16 14:27:42,409	ERROR worker.py:1719 -- Possible unhandled error from worker: ray_ParameterServer:get_stalness() (pid=16063, host=gpu-comp-104)
#   File "/userhome/34/gyu/anaconda3/envs/pytorch_env/lib/python3.7/site-packages/ray/memory_monitor.py", line 130, in raise_if_low_memory
#     self.error_threshold))
# ray.memory_monitor.RayOutOfMemoryError: More than 95% of the memory on node gpu-comp-104 is used (27.56 / 28.75 GB). The top 10 memory consumers are:
#
# PID	MEM	COMMAND
# 17530	16.52GiB	python /userhome/34/gyu/git-repo/rethinking-network-pruning/cifar/network-slimming/resprune.py --dat
# 16712	2.53GiB	ray_worker:__main__.worker_task()
# 17422	2.53GiB	ray_worker:__main__.worker_task()
# 16063	0.12GiB	ray_ParameterServer:get_stalness()
# 16711	0.09GiB	ray_worker
# 16765	0.09GiB	ray_worker
# 16738	0.09GiB	ray_worker
# 16710	0.09GiB	ray_worker
# 16764	0.09GiB	ray_worker
# 16753	0.09GiB	ray_worker
#
# In addition, up to 5.88 GiB of shared memory is currently being used by the Ray object store. You can set the object store size with the `object_store_memory` parameter when starting Ray, and the max Redis size with `redis_max_memory`. Note that Ray assumes all system memory is available for use by workers. If your system has other applications running, you should manually set these memory limits to a lower value.
#
# 2019-12-16 14:27:42,411	ERROR worker.py:1719 -- Possible unhandled error from worker: ray_worker:__main__.worker_task() (pid=16712, host=gpu-comp-104)
#   File "<ipython-input-3-c8386ab073bd>", line 69, in worker_task
# ray.exceptions.RayTaskError: ray_ParameterServer:get_stalness() (pid=16063, host=gpu-comp-104)
#   File "/userhome/34/gyu/anaconda3/envs/pytorch_env/lib/python3.7/site-packages/ray/memory_monitor.py", line 130, in raise_if_low_memory
#     self.error_threshold))
# ray.memory_monitor.RayOutOfMemoryError: More than 95% of the memory on node gpu-comp-104 is used (27.56 / 28.75 GB). The top 10 memory consumers are:
#
# PID	MEM	COMMAND
# 17530	16.52GiB	python /userhome/34/gyu/git-repo/rethinking-network-pruning/cifar/network-slimming/resprune.py --dat
# 16712	2.53GiB	ray_worker:__main__.worker_task()
# 17422	2.53GiB	ray_worker:__main__.worker_task()
# 16063	0.12GiB	ray_ParameterServer:get_stalness()
# 16711	0.09GiB	ray_worker
# 16765	0.09GiB	ray_worker
# 16738	0.09GiB	ray_worker
# 16710	0.09GiB	ray_worker
# 16764	0.09GiB	ray_worker
# 16753	0.09GiB	ray_worker
#
# In addition, up to 5.88 GiB of shared memory is currently being used by the Ray object store. You can set the object store size with the `object_store_memory` parameter when starting Ray, and the max Redis size with `redis_max_memory`. Note that Ray assumes all system memory is available for use by workers. If your system has other applications running, you should manually set these memory limits to a lower value.
# (pid=12338, ip=10.21.5.133) found pruned ckpt
# (pid=13363, ip=10.21.5.133) /userhome/34/gyu/anaconda3/envs/pytorch_env/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:541: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=13363, ip=10.21.5.133)   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# (pid=13363, ip=10.21.5.133) /userhome/34/gyu/anaconda3/envs/pytorch_env/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:542: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=13363, ip=10.21.5.133)   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# (pid=13363, ip=10.21.5.133) /userhome/34/gyu/anaconda3/envs/pytorch_env/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:543: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=13363, ip=10.21.5.133)   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# (pid=13363, ip=10.21.5.133) /userhome/34/gyu/anaconda3/envs/pytorch_env/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:544: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=13363, ip=10.21.5.133)   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# (pid=13363, ip=10.21.5.133) /userhome/34/gyu/anaconda3/envs/pytorch_env/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:545: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=13363, ip=10.21.5.133)   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# (pid=13363, ip=10.21.5.133) /userhome/34/gyu/anaconda3/envs/pytorch_env/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:550: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=13363, ip=10.21.5.133)   np_resource = np.dtype([("resource", np.ubyte, 1)])
# (pid=16711, ip=10.21.5.134) found pruned ckpt
# (pid=29313) move model to gpu takes:  0 seconds
# (pid=29313) found pruned ckpt
# (pid=29313) worker # 0  is online
# (pid=29313) move data to gpu takes:  0 seconds
# (pid=29313) move model to gpu takes:  0 seconds
# (pid=29313) the  0  pulls wei from ps.
# (pid=29313) 0  is generating output
# (pid=29313) 0  generated output done and going to calculate loss
# (pid=29313) 0  calculated loss and going to bp
# (pid=29313) 0  bp done
# (pid=29313) The 0 worker, Train Epoch: 0 [0/50000 (0.0%)]	Loss: 0.426212
# (pid=16711, ip=10.21.5.134) finished applying gradients from the  0  worker
# (pid=29313) move data to gpu takes:  0 seconds
# (pid=29313) move model to gpu takes:  0 seconds
# (pid=29313) the  0  pulls wei from ps.
# (pid=29313) 0  is generating output
# (pid=29313) 0  generated output done and going to calculate loss
# (pid=29313) 0  calculated loss and going to bp
# (pid=29313) 0  bp done
# (pid=29313) move data to gpu takes:  0 seconds
# (pid=29313) move model to gpu takes:  0 seconds
# (pid=16711, ip=10.21.5.134) finished applying gradients from the  0  worker
# (pid=29313) the  0  pulls wei from ps.
# (pid=29313) 0  is generating output
# (pid=29313) 0  generated output done and going to calculate loss
# (pid=29313) 0  calculated loss and going to bp
# (pid=29313) 0  bp done
# (pid=29313) move data to gpu takes:  0 seconds
# (pid=29313) move model to gpu takes:  0 seconds
# (pid=29313) the  0  pulls wei from ps.
# (pid=16711, ip=10.21.5.134) finished applying gradients from the  0  worker
# (pid=29313) 0  is generating output
# (pid=29313) 0  generated output done and going to calculate loss
# (pid=29313) 0  calculated loss and going to bp
# (pid=29313) 0  bp done
# (pid=29313) move data to gpu takes:  0 seconds
# (pid=29313) move model to gpu takes:  0 seconds
# (pid=29313) the  0  pulls wei from ps.
# (pid=16711, ip=10.21.5.134) finished applying gradients from the  0  worker
# (pid=29313) 0  is generating output
# (pid=29313) 0  generated output done and going to calculate loss
# (pid=29313) 0  calculated loss and going to bp
# (pid=13363, ip=10.21.5.133) move model to gpu takes:  0 seconds
# (pid=13363, ip=10.21.5.133) found pruned ckpt
# (pid=29313) 0  bp done
# (pid=29313) move data to gpu takes:  0 seconds
# (pid=29313) move model to gpu takes:  0 seconds
# (pid=29313) the  0  pulls wei from ps.
# (pid=16711, ip=10.21.5.134) finished applying gradients from the  0  worker
# (pid=13363, ip=10.21.5.133) worker # 1  is online
# (pid=13363, ip=10.21.5.133) move data to gpu takes:  0 seconds
# (pid=13363, ip=10.21.5.133) move model to gpu takes:  0 seconds
# (pid=13363, ip=10.21.5.133) the  1  pulls wei from ps.
# (pid=29313) 0  is generating output
# (pid=29313) 0  generated output done and going to calculate loss
# (pid=29313) 0  calculated loss and going to bp
# (pid=29313) 0  bp done
# (pid=13363, ip=10.21.5.133) 1  is generating output
# (pid=29313) move data to gpu takes:  0 seconds
# (pid=29313) move model to gpu takes:  0 seconds
# (pid=16711, ip=10.21.5.134) finished applying gradients from the  0  worker
# (pid=13363, ip=10.21.5.133) 1  generated output done and going to calculate loss
# (pid=13363, ip=10.21.5.133) 1  calculated loss and going to bp
# (pid=13363, ip=10.21.5.133) 1  bp done
# (pid=13363, ip=10.21.5.133) The 1 worker, Train Epoch: 0 [0/50000 (0.0%)]	Loss: 0.242780
# (pid=16711, ip=10.21.5.134) finished applying gradients from the  1  worker
# (pid=13363, ip=10.21.5.133) move data to gpu takes:  0 seconds
# (pid=13363, ip=10.21.5.133) move model to gpu takes:  0 seconds
# (pid=13363, ip=10.21.5.133) the  1  pulls wei from ps.
# (pid=13363, ip=10.21.5.133) 1  is generating output
# (pid=13363, ip=10.21.5.133) 1  generated output done and going to calculate loss
# (pid=13363, ip=10.21.5.133) 1  calculated loss and going to bp
# (pid=13363, ip=10.21.5.133) 1  bp done
# (pid=13363, ip=10.21.5.133) move data to gpu takes:  0 seconds
# (pid=13363, ip=10.21.5.133) move model to gpu takes:  0 seconds
# (pid=16711, ip=10.21.5.134) finished applying gradients from the  1  worker
# (pid=13363, ip=10.21.5.133) the  1  pulls wei from ps.
# (pid=13363, ip=10.21.5.133) 1  is generating output
# (pid=13363, ip=10.21.5.133) 1  generated output done and going to calculate loss
# (pid=13363, ip=10.21.5.133) 1  calculated loss and going to bp
# (pid=13363, ip=10.21.5.133) 1  bp done
# (pid=13363, ip=10.21.5.133) move data to gpu takes:  0 seconds
# (pid=13363, ip=10.21.5.133) move model to gpu takes:  0 seconds
# (pid=13363, ip=10.21.5.133) the  1  pulls wei from ps.
# (pid=16711, ip=10.21.5.134) finished applying gradients from the  1  worker
# (pid=13363, ip=10.21.5.133) 1  is generating output
# (pid=16712, ip=10.21.5.134) move model to gpu takes:  0 seconds
# (pid=16712, ip=10.21.5.134) found pruned ckpt
# (pid=13363, ip=10.21.5.133) 1  generated output done and going to calculate loss
# (pid=13363, ip=10.21.5.133) 1  calculated loss and going to bp
# (pid=13363, ip=10.21.5.133) 1  bp done
# (pid=16712, ip=10.21.5.134) worker # 2  is online
# (pid=16712, ip=10.21.5.134) move data to gpu takes:  0 seconds
# (pid=13363, ip=10.21.5.133) move data to gpu takes:  0 seconds
# (pid=13363, ip=10.21.5.133) move model to gpu takes:  0 seconds
# (pid=16711, ip=10.21.5.134) finished applying gradients from the  1  worker
# (pid=13363, ip=10.21.5.133) the  1  pulls wei from ps.
# (pid=16712, ip=10.21.5.134) move model to gpu takes:  0 seconds
# (pid=16712, ip=10.21.5.134) the  2  pulls wei from ps.
# (pid=16712, ip=10.21.5.134) 2  is generating output
# (pid=13363, ip=10.21.5.133) 1  is generating output
# (pid=13363, ip=10.21.5.133) 1  generated output done and going to calculate loss
# (pid=13363, ip=10.21.5.133) 1  calculated loss and going to bp
# (pid=16712, ip=10.21.5.134) 2  generated output done and going to calculate loss
# (pid=16712, ip=10.21.5.134) 2  calculated loss and going to bp
# (pid=13363, ip=10.21.5.133) 1  bp done
# (pid=13363, ip=10.21.5.133) move data to gpu takes:  0 seconds
# (pid=13363, ip=10.21.5.133) move model to gpu takes:  0 seconds
# (pid=13363, ip=10.21.5.133) the  1  pulls wei from ps.
# (pid=16711, ip=10.21.5.134) finished applying gradients from the  1  worker
# (pid=13363, ip=10.21.5.133) 1  is generating output
# (pid=13363, ip=10.21.5.133) 1  generated output done and going to calculate loss
# (pid=13363, ip=10.21.5.133) 1  calculated loss and going to bp
# (pid=13363, ip=10.21.5.133) 1  bp done
# (pid=13363, ip=10.21.5.133) move data to gpu takes:  0 seconds
# (pid=13363, ip=10.21.5.133) move model to gpu takes:  0 seconds
# (pid=16711, ip=10.21.5.134) finished applying gradients from the  1  worker
# (pid=16712, ip=10.21.5.134) 2  bp done
# (pid=16712, ip=10.21.5.134) The 2 worker, Train Epoch: 0 [0/50000 (0.0%)]	Loss: 0.562283
# (pid=16711, ip=10.21.5.134) finished applying gradients from the  2  worker
# (pid=13363, ip=10.21.5.133) the  1  pulls wei from ps.
# (pid=29313) the  0  pulls wei from ps.
# (pid=13363, ip=10.21.5.133) 1  is generating output
# (pid=13363, ip=10.21.5.133) 1  generated output done and going to calculate loss
# (pid=13363, ip=10.21.5.133) 1  calculated loss and going to bp
# (pid=29313) 0  is generating output
# (pid=29313) 0  generated output done and going to calculate loss
# (pid=29313) 0  calculated loss and going to bp
# (pid=13363, ip=10.21.5.133) 1  bp done
# (pid=29313) 0  bp done
# (pid=13363, ip=10.21.5.133) move data to gpu takes:  0 seconds
# (pid=13363, ip=10.21.5.133) move model to gpu takes:  0 seconds
# (pid=16711, ip=10.21.5.134) finished applying gradients from the  1  worker
# (pid=29313) move data to gpu takes:  0 seconds
# (pid=29313) move model to gpu takes:  0 seconds
# (pid=16711, ip=10.21.5.134) finished applying gradients from the  0  worker
# (pid=16712, ip=10.21.5.134) move data to gpu takes:  0 seconds
# (pid=16712, ip=10.21.5.134) move model to gpu takes:  0 seconds
# (pid=16712, ip=10.21.5.134) the  2  pulls wei from ps.
# (pid=16712, ip=10.21.5.134) 2  is generating output
# (pid=16712, ip=10.21.5.134) 2  generated output done and going to calculate loss
# (pid=16712, ip=10.21.5.134) 2  calculated loss and going to bp
# (pid=16712, ip=10.21.5.134) 2  bp done
# (pid=16738, ip=10.21.5.134) found pruned ckpt
# (pid=16710, ip=10.21.5.134) found pruned ckpt
# (pid=16737, ip=10.21.5.134) found pruned ckpt
# (pid=16737, ip=10.21.5.134) worker # 0  is online
# (pid=16737, ip=10.21.5.134) The 0 worker, Train Epoch: 0 [0/50000 (0.0%)]	Loss: 0.599172
# 2019-12-16 14:56:12,178	WARNING worker.py:1779 -- WARNING: 12 PYTHON workers have been started. This could be a result of using a large number of actors, or it could be a consequence of using nested tasks (see https://github.com/ray-project/ray/issues/3644) for some a discussion of workarounds.
# 2019-12-16 14:56:12,474	WARNING worker.py:1779 -- WARNING: 12 PYTHON workers have been started. This could be a result of using a large number of actors, or it could be a consequence of using nested tasks (see https://github.com/ray-project/ray/issues/3644) for some a discussion of workarounds.
# (pid=31165) /userhome/34/gyu/anaconda3/envs/pytorch_env/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:541: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=31165)   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# (pid=31165) /userhome/34/gyu/anaconda3/envs/pytorch_env/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:542: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=31165)   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# (pid=31165) /userhome/34/gyu/anaconda3/envs/pytorch_env/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:543: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=31165)   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# (pid=31165) /userhome/34/gyu/anaconda3/envs/pytorch_env/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:544: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=31165)   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# (pid=31165) /userhome/34/gyu/anaconda3/envs/pytorch_env/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:545: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=31165)   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# (pid=31165) /userhome/34/gyu/anaconda3/envs/pytorch_env/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:550: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=31165)   np_resource = np.dtype([("resource", np.ubyte, 1)])
# (pid=13467, ip=10.21.5.133) /userhome/34/gyu/anaconda3/envs/pytorch_env/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:541: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=13467, ip=10.21.5.133)   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# (pid=13467, ip=10.21.5.133) /userhome/34/gyu/anaconda3/envs/pytorch_env/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:542: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=13467, ip=10.21.5.133)   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# (pid=13467, ip=10.21.5.133) /userhome/34/gyu/anaconda3/envs/pytorch_env/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:543: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=13467, ip=10.21.5.133)   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# (pid=13467, ip=10.21.5.133) /userhome/34/gyu/anaconda3/envs/pytorch_env/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:544: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=13467, ip=10.21.5.133)   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# (pid=13467, ip=10.21.5.133) /userhome/34/gyu/anaconda3/envs/pytorch_env/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:545: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=13467, ip=10.21.5.133)   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# (pid=13467, ip=10.21.5.133) /userhome/34/gyu/anaconda3/envs/pytorch_env/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:550: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=13467, ip=10.21.5.133)   np_resource = np.dtype([("resource", np.ubyte, 1)])
# (pid=13466, ip=10.21.5.133) /userhome/34/gyu/anaconda3/envs/pytorch_env/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:541: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=13466, ip=10.21.5.133)   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# (pid=13466, ip=10.21.5.133) /userhome/34/gyu/anaconda3/envs/pytorch_env/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:542: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=13466, ip=10.21.5.133)   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# (pid=13466, ip=10.21.5.133) /userhome/34/gyu/anaconda3/envs/pytorch_env/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:543: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=13466, ip=10.21.5.133)   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# (pid=13466, ip=10.21.5.133) /userhome/34/gyu/anaconda3/envs/pytorch_env/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:544: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=13466, ip=10.21.5.133)   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# (pid=13466, ip=10.21.5.133) /userhome/34/gyu/anaconda3/envs/pytorch_env/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:545: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=13466, ip=10.21.5.133)   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# (pid=13466, ip=10.21.5.133) /userhome/34/gyu/anaconda3/envs/pytorch_env/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:550: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=13466, ip=10.21.5.133)   np_resource = np.dtype([("resource", np.ubyte, 1)])
# (pid=13468, ip=10.21.5.133) /userhome/34/gyu/anaconda3/envs/pytorch_env/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:541: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=13468, ip=10.21.5.133)   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# (pid=13468, ip=10.21.5.133) /userhome/34/gyu/anaconda3/envs/pytorch_env/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:542: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=13468, ip=10.21.5.133)   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# (pid=13468, ip=10.21.5.133) /userhome/34/gyu/anaconda3/envs/pytorch_env/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:543: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=13468, ip=10.21.5.133)   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# (pid=13468, ip=10.21.5.133) /userhome/34/gyu/anaconda3/envs/pytorch_env/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:544: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=13468, ip=10.21.5.133)   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# (pid=13468, ip=10.21.5.133) /userhome/34/gyu/anaconda3/envs/pytorch_env/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:545: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=13468, ip=10.21.5.133)   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# (pid=13468, ip=10.21.5.133) /userhome/34/gyu/anaconda3/envs/pytorch_env/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:550: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=13468, ip=10.21.5.133)   np_resource = np.dtype([("resource", np.ubyte, 1)])
# (pid=13469, ip=10.21.5.133) /userhome/34/gyu/anaconda3/envs/pytorch_env/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:541: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=13469, ip=10.21.5.133)   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# (pid=13469, ip=10.21.5.133) /userhome/34/gyu/anaconda3/envs/pytorch_env/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:542: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=13469, ip=10.21.5.133)   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# (pid=13469, ip=10.21.5.133) /userhome/34/gyu/anaconda3/envs/pytorch_env/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:543: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=13469, ip=10.21.5.133)   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# (pid=13469, ip=10.21.5.133) /userhome/34/gyu/anaconda3/envs/pytorch_env/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:544: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=13469, ip=10.21.5.133)   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# (pid=13469, ip=10.21.5.133) /userhome/34/gyu/anaconda3/envs/pytorch_env/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:545: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=13469, ip=10.21.5.133)   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# (pid=13469, ip=10.21.5.133) /userhome/34/gyu/anaconda3/envs/pytorch_env/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:550: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=13469, ip=10.21.5.133)   np_resource = np.dtype([("resource", np.ubyte, 1)])
# (pid=31166) /userhome/34/gyu/anaconda3/envs/pytorch_env/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:541: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=31166)   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# (pid=31166) /userhome/34/gyu/anaconda3/envs/pytorch_env/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:542: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=31166)   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# (pid=31166) /userhome/34/gyu/anaconda3/envs/pytorch_env/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:543: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=31166)   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# (pid=31166) /userhome/34/gyu/anaconda3/envs/pytorch_env/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:544: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=31166)   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# (pid=31166) /userhome/34/gyu/anaconda3/envs/pytorch_env/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:545: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=31166)   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# (pid=31166) /userhome/34/gyu/anaconda3/envs/pytorch_env/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:550: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=31166)   np_resource = np.dtype([("resource", np.ubyte, 1)])
# (pid=31167) /userhome/34/gyu/anaconda3/envs/pytorch_env/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:541: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=31167)   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# (pid=31167) /userhome/34/gyu/anaconda3/envs/pytorch_env/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:542: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=31167)   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# (pid=31167) /userhome/34/gyu/anaconda3/envs/pytorch_env/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:543: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=31167)   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# (pid=31167) /userhome/34/gyu/anaconda3/envs/pytorch_env/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:544: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=31167)   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# (pid=31167) /userhome/34/gyu/anaconda3/envs/pytorch_env/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:545: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=31167)   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# (pid=31167) /userhome/34/gyu/anaconda3/envs/pytorch_env/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:550: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=31167)   np_resource = np.dtype([("resource", np.ubyte, 1)])
# (pid=31168) /userhome/34/gyu/anaconda3/envs/pytorch_env/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:541: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=31168)   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# (pid=31168) /userhome/34/gyu/anaconda3/envs/pytorch_env/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:542: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=31168)   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# (pid=31168) /userhome/34/gyu/anaconda3/envs/pytorch_env/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:543: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=31168)   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# (pid=31168) /userhome/34/gyu/anaconda3/envs/pytorch_env/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:544: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=31168)   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# (pid=31168) /userhome/34/gyu/anaconda3/envs/pytorch_env/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:545: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=31168)   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# (pid=31168) /userhome/34/gyu/anaconda3/envs/pytorch_env/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:550: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=31168)   np_resource = np.dtype([("resource", np.ubyte, 1)])
# (pid=31175) /userhome/34/gyu/anaconda3/envs/pytorch_env/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:541: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=31175)   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# (pid=31175) /userhome/34/gyu/anaconda3/envs/pytorch_env/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:542: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=31175)   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# (pid=31175) /userhome/34/gyu/anaconda3/envs/pytorch_env/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:543: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=31175)   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# (pid=31175) /userhome/34/gyu/anaconda3/envs/pytorch_env/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:544: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=31175)   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# (pid=31175) /userhome/34/gyu/anaconda3/envs/pytorch_env/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:545: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=31175)   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# (pid=31175) /userhome/34/gyu/anaconda3/envs/pytorch_env/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:550: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=31175)   np_resource = np.dtype([("resource", np.ubyte, 1)])
# (pid=13485, ip=10.21.5.133) /userhome/34/gyu/anaconda3/envs/pytorch_env/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:541: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=13485, ip=10.21.5.133)   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# (pid=13485, ip=10.21.5.133) /userhome/34/gyu/anaconda3/envs/pytorch_env/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:542: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=13485, ip=10.21.5.133)   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# (pid=13485, ip=10.21.5.133) /userhome/34/gyu/anaconda3/envs/pytorch_env/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:543: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=13485, ip=10.21.5.133)   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# (pid=13485, ip=10.21.5.133) /userhome/34/gyu/anaconda3/envs/pytorch_env/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:544: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=13485, ip=10.21.5.133)   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# (pid=13485, ip=10.21.5.133) /userhome/34/gyu/anaconda3/envs/pytorch_env/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:545: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=13485, ip=10.21.5.133)   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# ...
# (pid=16737, ip=10.21.5.134) The 0 worker, Train Epoch: 0 [19200/50000 (38.4%)]	Loss: 0.230233
# (pid=31165) The 1 worker, Train Epoch: 0 [19200/50000 (38.4%)]	Loss: 0.171348
# (pid=13469, ip=10.21.5.133) The 2 worker, Train Epoch: 0 [19200/50000 (38.4%)]	Loss: 0.185452
# (pid=31165) The 1 worker, Train Epoch: 0 [25600/50000 (51.2%)]	Loss: 0.171706
# (pid=16737, ip=10.21.5.134) The 0 worker, Train Epoch: 0 [25600/50000 (51.2%)]	Loss: 0.262645
# (pid=13469, ip=10.21.5.133) The 2 worker, Train Epoch: 0 [25600/50000 (51.2%)]	Loss: 0.143708
# (pid=31165) The 1 worker, Train Epoch: 0 [32000/50000 (63.9%)]	Loss: 0.310978
# (pid=16737, ip=10.21.5.134) The 0 worker, Train Epoch: 0 [32000/50000 (63.9%)]	Loss: 0.261778
# (pid=13469, ip=10.21.5.133) The 2 worker, Train Epoch: 0 [32000/50000 (63.9%)]	Loss: 0.120054
# (pid=31165) The 1 worker, Train Epoch: 0 [38400/50000 (76.7%)]	Loss: 0.192879
# (pid=16737, ip=10.21.5.134) The 0 worker, Train Epoch: 0 [38400/50000 (76.7%)]	Loss: 0.214151
# (pid=13469, ip=10.21.5.133) The 2 worker, Train Epoch: 0 [38400/50000 (76.7%)]	Loss: 0.192001
# (pid=16737, ip=10.21.5.134) The 0 worker, Train Epoch: 0 [44800/50000 (89.5%)]	Loss: 0.123763
# (pid=31165) The 1 worker, Train Epoch: 0 [44800/50000 (89.5%)]	Loss: 0.174392
# (pid=13469, ip=10.21.5.133) The 2 worker, Train Epoch: 0 [44800/50000 (89.5%)]	Loss: 0.181086
# (pid=31165) The 1 worker finished its 0 epoch with loss: 0.003547810949385166 and accuracy: 0.9218599796295166
# (pid=16737, ip=10.21.5.134) The 0 worker finished its 0 epoch with loss: 0.0035619824193418026 and accuracy: 0.9215800166130066
# (pid=16737, ip=10.21.5.134) The 0 worker, Train Epoch: 1 [0/50000 (0.0%)]	Loss: 0.237502
# (pid=31165) The 1 worker, Train Epoch: 1 [0/50000 (0.0%)]	Loss: 0.247961
# (pid=13469, ip=10.21.5.133) The 2 worker finished its 0 epoch with loss: 0.003572846297174692 and accuracy: 0.921280026435852
# (pid=13469, ip=10.21.5.133) The 2 worker, Train Epoch: 1 [0/50000 (0.0%)]	Loss: 0.245125
# (pid=16737, ip=10.21.5.134) The 0 worker, Train Epoch: 1 [6400/50000 (12.8%)]	Loss: 0.119601
# (pid=31165) The 1 worker, Train Epoch: 1 [6400/50000 (12.8%)]	Loss: 0.151492
# (pid=13469, ip=10.21.5.133) The 2 worker, Train Epoch: 1 [6400/50000 (12.8%)]	Loss: 0.130040
# (pid=31165) The 1 worker, Train Epoch: 1 [12800/50000 (25.6%)]	Loss: 0.176510
# (pid=16737, ip=10.21.5.134) The 0 worker, Train Epoch: 1 [12800/50000 (25.6%)]	Loss: 0.177223
# (pid=13469, ip=10.21.5.133) The 2 worker, Train Epoch: 1 [12800/50000 (25.6%)]	Loss: 0.051640
# (pid=31165) The 1 worker, Train Epoch: 1 [19200/50000 (38.4%)]	Loss: 0.186148
# (pid=16737, ip=10.21.5.134) The 0 worker, Train Epoch: 1 [19200/50000 (38.4%)]	Loss: 0.165624
# (pid=13469, ip=10.21.5.133) The 2 worker, Train Epoch: 1 [19200/50000 (38.4%)]	Loss: 0.279970
# (pid=16737, ip=10.21.5.134) The 0 worker, Train Epoch: 1 [25600/50000 (51.2%)]	Loss: 0.129340
# (pid=31165) The 1 worker, Train Epoch: 1 [25600/50000 (51.2%)]	Loss: 0.210016
# (pid=13469, ip=10.21.5.133) The 2 worker, Train Epoch: 1 [25600/50000 (51.2%)]	Loss: 0.223263
# (pid=31165) The 1 worker, Train Epoch: 1 [32000/50000 (63.9%)]	Loss: 0.178439
# (pid=16737, ip=10.21.5.134) The 0 worker, Train Epoch: 1 [32000/50000 (63.9%)]	Loss: 0.181722
# (pid=13469, ip=10.21.5.133) The 2 worker, Train Epoch: 1 [32000/50000 (63.9%)]	Loss: 0.096387
# (pid=16737, ip=10.21.5.134) The 0 worker, Train Epoch: 1 [38400/50000 (76.7%)]	Loss: 0.156534
# (pid=31165) The 1 worker, Train Epoch: 1 [38400/50000 (76.7%)]	Loss: 0.155487
# (pid=13469, ip=10.21.5.133) The 2 worker, Train Epoch: 1 [38400/50000 (76.7%)]	Loss: 0.184420
# (pid=16737, ip=10.21.5.134) The 0 worker, Train Epoch: 1 [44800/50000 (89.5%)]	Loss: 0.254372
# (pid=31165) The 1 worker, Train Epoch: 1 [44800/50000 (89.5%)]	Loss: 0.076443
# (pid=13469, ip=10.21.5.133) The 2 worker, Train Epoch: 1 [44800/50000 (89.5%)]	Loss: 0.102966
# (pid=31165) The 1 worker finished its 1 epoch with loss: 0.0028479937463998795 and accuracy: 0.9370399713516235
# (pid=16737, ip=10.21.5.134) The 0 worker finished its 1 epoch with loss: 0.0028989254496991634 and accuracy: 0.9359400272369385
# (pid=31165) The 1 worker, Train Epoch: 2 [0/50000 (0.0%)]	Loss: 0.146667
# (pid=16737, ip=10.21.5.134) The 0 worker, Train Epoch: 2 [0/50000 (0.0%)]	Loss: 0.134173
# (pid=13469, ip=10.21.5.133) The 2 worker finished its 1 epoch with loss: 0.0028748614713549614 and accuracy: 0.9367799758911133
# (pid=13469, ip=10.21.5.133) The 2 worker, Train Epoch: 2 [0/50000 (0.0%)]	Loss: 0.202052
# (pid=31165) The 1 worker, Train Epoch: 2 [6400/50000 (12.8%)]	Loss: 0.214322
# (pid=16737, ip=10.21.5.134) The 0 worker, Train Epoch: 2 [6400/50000 (12.8%)]	Loss: 0.160184
# (pid=13469, ip=10.21.5.133) The 2 worker, Train Epoch: 2 [6400/50000 (12.8%)]	Loss: 0.122070
# (pid=31165) The 1 worker, Train Epoch: 2 [12800/50000 (25.6%)]	Loss: 0.164044
# (pid=16737, ip=10.21.5.134) The 0 worker, Train Epoch: 2 [12800/50000 (25.6%)]	Loss: 0.197459
# (pid=13469, ip=10.21.5.133) The 2 worker, Train Epoch: 2 [12800/50000 (25.6%)]	Loss: 0.179967
# (pid=31165) The 1 worker, Train Epoch: 2 [19200/50000 (38.4%)]	Loss: 0.211345
# (pid=16737, ip=10.21.5.134) The 0 worker, Train Epoch: 2 [19200/50000 (38.4%)]	Loss: 0.060606
# (pid=13469, ip=10.21.5.133) The 2 worker, Train Epoch: 2 [19200/50000 (38.4%)]	Loss: 0.099126
# (pid=31165) The 1 worker, Train Epoch: 2 [25600/50000 (51.2%)]	Loss: 0.181544
# (pid=16737, ip=10.21.5.134) The 0 worker, Train Epoch: 2 [25600/50000 (51.2%)]	Loss: 0.288569
# (pid=13469, ip=10.21.5.133) The 2 worker, Train Epoch: 2 [25600/50000 (51.2%)]	Loss: 0.321343
# (pid=31165) The 1 worker, Train Epoch: 2 [32000/50000 (63.9%)]	Loss: 0.185740
# (pid=16737, ip=10.21.5.134) The 0 worker, Train Epoch: 2 [32000/50000 (63.9%)]	Loss: 0.063950
# (pid=13469, ip=10.21.5.133) The 2 worker, Train Epoch: 2 [32000/50000 (63.9%)]	Loss: 0.178726
# (pid=16737, ip=10.21.5.134) The 0 worker, Train Epoch: 2 [38400/50000 (76.7%)]	Loss: 0.091922
# (pid=31165) The 1 worker, Train Epoch: 2 [38400/50000 (76.7%)]	Loss: 0.145969
# (pid=13469, ip=10.21.5.133) The 2 worker, Train Epoch: 2 [38400/50000 (76.7%)]	Loss: 0.075267
# (pid=31165) The 1 worker, Train Epoch: 2 [44800/50000 (89.5%)]	Loss: 0.168981
# (pid=16737, ip=10.21.5.134) The 0 worker, Train Epoch: 2 [44800/50000 (89.5%)]	Loss: 0.027214
# (pid=16710, ip=10.21.5.134) 2019-12-16 15:34:54,303	WARNING worker.py:352 -- WARNING: Falling back to serializing objects of type <class 'torch.nn.backends.thnn.THNNFunctionBackend'> by using pickle. This may be inefficient.
# (pid=13469, ip=10.21.5.133) The 2 worker, Train Epoch: 2 [44800/50000 (89.5%)]	Loss: 0.153096
# (pid=31165) The 1 worker finished its 2 epoch with loss: 0.0025887524243444204 and accuracy: 0.9424200057983398
# (pid=16737, ip=10.21.5.134) The 0 worker finished its 2 epoch with loss: 0.002528395736590028 and accuracy: 0.9430999755859375
# (pid=31165) The 1 worker, Train Epoch: 3 [0/50000 (0.0%)]	Loss: 0.214363
# (pid=16737, ip=10.21.5.134) The 0 worker, Train Epoch: 3 [0/50000 (0.0%)]	Loss: 0.279825
# (pid=13469, ip=10.21.5.133) The 2 worker finished its 2 epoch with loss: 0.002505522919818759 and accuracy: 0.9436600208282471
# (pid=13469, ip=10.21.5.133) The 2 worker, Train Epoch: 3 [0/50000 (0.0%)]	Loss: 0.111375
# (pid=16737, ip=10.21.5.134) The 0 worker, Train Epoch: 3 [6400/50000 (12.8%)]	Loss: 0.142281
# (pid=31165) The 1 worker, Train Epoch: 3 [6400/50000 (12.8%)]	Loss: 0.160155
# (pid=13469, ip=10.21.5.133) The 2 worker, Train Epoch: 3 [6400/50000 (12.8%)]	Loss: 0.217434
# (pid=31165) The 1 worker, Train Epoch: 3 [12800/50000 (25.6%)]	Loss: 0.069488
# (pid=16737, ip=10.21.5.134) The 0 worker, Train Epoch: 3 [12800/50000 (25.6%)]	Loss: 0.198684
# (pid=13469, ip=10.21.5.133) The 2 worker, Train Epoch: 3 [12800/50000 (25.6%)]	Loss: 0.331699
# (pid=31165) The 1 worker, Train Epoch: 3 [19200/50000 (38.4%)]	Loss: 0.104832
# (pid=16737, ip=10.21.5.134) The 0 worker, Train Epoch: 3 [19200/50000 (38.4%)]	Loss: 0.207512
# (pid=13469, ip=10.21.5.133) The 2 worker, Train Epoch: 3 [19200/50000 (38.4%)]	Loss: 0.184606
# (pid=31165) The 1 worker, Train Epoch: 3 [25600/50000 (51.2%)]	Loss: 0.089632
# (pid=16737, ip=10.21.5.134) The 0 worker, Train Epoch: 3 [25600/50000 (51.2%)]	Loss: 0.051234
# (pid=13469, ip=10.21.5.133) The 2 worker, Train Epoch: 3 [25600/50000 (51.2%)]	Loss: 0.157148
# (pid=16737, ip=10.21.5.134) The 0 worker, Train Epoch: 3 [32000/50000 (63.9%)]	Loss: 0.037909
# (pid=31165) The 1 worker, Train Epoch: 3 [32000/50000 (63.9%)]	Loss: 0.177597
# (pid=13469, ip=10.21.5.133) The 2 worker, Train Epoch: 3 [32000/50000 (63.9%)]	Loss: 0.187272
# (pid=16737, ip=10.21.5.134) The 0 worker, Train Epoch: 3 [38400/50000 (76.7%)]	Loss: 0.180673
# (pid=31165) The 1 worker, Train Epoch: 3 [38400/50000 (76.7%)]	Loss: 0.190232
# (pid=13469, ip=10.21.5.133) The 2 worker, Train Epoch: 3 [38400/50000 (76.7%)]	Loss: 0.139238
# (pid=16737, ip=10.21.5.134) The 0 worker, Train Epoch: 3 [44800/50000 (89.5%)]	Loss: 0.121742
# (pid=31165) The 1 worker, Train Epoch: 3 [44800/50000 (89.5%)]	Loss: 0.204199
# (pid=13469, ip=10.21.5.133) The 2 worker, Train Epoch: 3 [44800/50000 (89.5%)]	Loss: 0.118834
# (pid=16737, ip=10.21.5.134) The 0 worker finished its 3 epoch with loss: 0.002282040426507592 and accuracy: 0.9492800235748291
# (pid=31165) The 1 worker finished its 3 epoch with loss: 0.002350087044760585 and accuracy: 0.9472000002861023
# (pid=16737, ip=10.21.5.134) The 0 worker, Train Epoch: 4 [0/50000 (0.0%)]	Loss: 0.137993
# (pid=31165) The 1 worker, Train Epoch: 4 [0/50000 (0.0%)]	Loss: 0.115433
# (pid=13469, ip=10.21.5.133) The 2 worker finished its 3 epoch with loss: 0.00229246006347239 and accuracy: 0.9491599798202515
# (pid=13469, ip=10.21.5.133) The 2 worker, Train Epoch: 4 [0/50000 (0.0%)]	Loss: 0.210348
# (pid=16737, ip=10.21.5.134) The 0 worker, Train Epoch: 4 [6400/50000 (12.8%)]	Loss: 0.120925
# (pid=31165) The 1 worker, Train Epoch: 4 [6400/50000 (12.8%)]	Loss: 0.227915
# (pid=13469, ip=10.21.5.133) The 2 worker, Train Epoch: 4 [6400/50000 (12.8%)]	Loss: 0.159225
# (pid=16737, ip=10.21.5.134) The 0 worker, Train Epoch: 4 [12800/50000 (25.6%)]	Loss: 0.122111
# (pid=31165) The 1 worker, Train Epoch: 4 [12800/50000 (25.6%)]	Loss: 0.128123
# (pid=13469, ip=10.21.5.133) The 2 worker, Train Epoch: 4 [12800/50000 (25.6%)]	Loss: 0.094176
# (pid=16737, ip=10.21.5.134) The 0 worker, Train Epoch: 4 [19200/50000 (38.4%)]	Loss: 0.052966
# (pid=31165) The 1 worker, Train Epoch: 4 [19200/50000 (38.4%)]	Loss: 0.156838
# (pid=13469, ip=10.21.5.133) The 2 worker, Train Epoch: 4 [19200/50000 (38.4%)]	Loss: 0.149354
# (pid=31165) The 1 worker, Train Epoch: 4 [25600/50000 (51.2%)]	Loss: 0.154979
# (pid=16737, ip=10.21.5.134) The 0 worker, Train Epoch: 4 [25600/50000 (51.2%)]	Loss: 0.101269
# (pid=13469, ip=10.21.5.133) The 2 worker, Train Epoch: 4 [25600/50000 (51.2%)]	Loss: 0.177233
# (pid=16737, ip=10.21.5.134) The 0 worker, Train Epoch: 4 [32000/50000 (63.9%)]	Loss: 0.087817
# (pid=31165) The 1 worker, Train Epoch: 4 [32000/50000 (63.9%)]	Loss: 0.138416
# (pid=13469, ip=10.21.5.133) The 2 worker, Train Epoch: 4 [32000/50000 (63.9%)]	Loss: 0.058653
# (pid=31165) The 1 worker, Train Epoch: 4 [38400/50000 (76.7%)]	Loss: 0.045372
# (pid=16737, ip=10.21.5.134) The 0 worker, Train Epoch: 4 [38400/50000 (76.7%)]	Loss: 0.136511
# (pid=13469, ip=10.21.5.133) The 2 worker, Train Epoch: 4 [38400/50000 (76.7%)]	Loss: 0.158470
# (pid=16737, ip=10.21.5.134) The 0 worker, Train Epoch: 4 [44800/50000 (89.5%)]	Loss: 0.215988
# (pid=31165) The 1 worker, Train Epoch: 4 [44800/50000 (89.5%)]	Loss: 0.131538
# (pid=13469, ip=10.21.5.133) The 2 worker, Train Epoch: 4 [44800/50000 (89.5%)]	Loss: 0.164654
# (pid=31165) The 1 worker finished its 4 epoch with loss: 0.0020461606327444315 and accuracy: 0.9546599984169006
# (pid=16737, ip=10.21.5.134) The 0 worker finished its 4 epoch with loss: 0.0021041063591837883 and accuracy: 0.953540027141571
# (pid=31165) The 1 worker, Train Epoch: 5 [0/50000 (0.0%)]	Loss: 0.181296
# (pid=16737, ip=10.21.5.134) The 0 worker, Train Epoch: 5 [0/50000 (0.0%)]	Loss: 0.106918
# (pid=13469, ip=10.21.5.133) The 2 worker finished its 4 epoch with loss: 0.0020339777693152428 and accuracy: 0.95524001121521
# (pid=13469, ip=10.21.5.133) The 2 worker, Train Epoch: 5 [0/50000 (0.0%)]	Loss: 0.034375
# (pid=31165) The 1 worker, Train Epoch: 5 [6400/50000 (12.8%)]	Loss: 0.036221
# (pid=16737, ip=10.21.5.134) The 0 worker, Train Epoch: 5 [6400/50000 (12.8%)]	Loss: 0.104182
# (pid=13469, ip=10.21.5.133) The 2 worker, Train Epoch: 5 [6400/50000 (12.8%)]	Loss: 0.074945
# (pid=16737, ip=10.21.5.134) The 0 worker, Train Epoch: 5 [12800/50000 (25.6%)]	Loss: 0.123534
# (pid=31165) The 1 worker, Train Epoch: 5 [12800/50000 (25.6%)]	Loss: 0.104351
# (pid=13469, ip=10.21.5.133) The 2 worker, Train Epoch: 5 [12800/50000 (25.6%)]	Loss: 0.077643
# (pid=16737, ip=10.21.5.134) The 0 worker, Train Epoch: 5 [19200/50000 (38.4%)]	Loss: 0.281835
# (pid=31165) The 1 worker, Train Epoch: 5 [19200/50000 (38.4%)]	Loss: 0.124003
# (pid=13469, ip=10.21.5.133) The 2 worker, Train Epoch: 5 [19200/50000 (38.4%)]	Loss: 0.117847
# (pid=16737, ip=10.21.5.134) The 0 worker, Train Epoch: 5 [25600/50000 (51.2%)]	Loss: 0.047065
# (pid=31165) The 1 worker, Train Epoch: 5 [25600/50000 (51.2%)]	Loss: 0.213136
# (pid=13469, ip=10.21.5.133) The 2 worker, Train Epoch: 5 [25600/50000 (51.2%)]	Loss: 0.207814
# (pid=16737, ip=10.21.5.134) The 0 worker, Train Epoch: 5 [32000/50000 (63.9%)]	Loss: 0.109397
# (pid=31165) The 1 worker, Train Epoch: 5 [32000/50000 (63.9%)]	Loss: 0.081613
# (pid=13469, ip=10.21.5.133) The 2 worker, Train Epoch: 5 [32000/50000 (63.9%)]	Loss: 0.121772
# (pid=31165) The 1 worker, Train Epoch: 5 [38400/50000 (76.7%)]	Loss: 0.109808
# (pid=16737, ip=10.21.5.134) The 0 worker, Train Epoch: 5 [38400/50000 (76.7%)]	Loss: 0.107103
# (pid=13469, ip=10.21.5.133) The 2 worker, Train Epoch: 5 [38400/50000 (76.7%)]	Loss: 0.150724
# (pid=16737, ip=10.21.5.134) The 0 worker, Train Epoch: 5 [44800/50000 (89.5%)]	Loss: 0.080173
# (pid=31165) The 1 worker, Train Epoch: 5 [44800/50000 (89.5%)]	Loss: 0.137338
# (pid=13469, ip=10.21.5.133) The 2 worker, Train Epoch: 5 [44800/50000 (89.5%)]	Loss: 0.140846
# (pid=16737, ip=10.21.5.134) The 0 worker finished its 5 epoch with loss: 0.0018779770471155643 and accuracy: 0.9583799839019775
# (pid=31165) The 1 worker finished its 5 epoch with loss: 0.0019103599479421973 and accuracy: 0.957099974155426
# (pid=16737, ip=10.21.5.134) The 0 worker, Train Epoch: 6 [0/50000 (0.0%)]	Loss: 0.107149
# (pid=31165) The 1 worker, Train Epoch: 6 [0/50000 (0.0%)]	Loss: 0.210635
# (pid=13469, ip=10.21.5.133) The 2 worker finished its 5 epoch with loss: 0.0018945880001410842 and accuracy: 0.9581000208854675
# (pid=13469, ip=10.21.5.133) The 2 worker, Train Epoch: 6 [0/50000 (0.0%)]	Loss: 0.091100
# (pid=16737, ip=10.21.5.134) The 0 worker, Train Epoch: 6 [6400/50000 (12.8%)]	Loss: 0.168863
# (pid=31165) The 1 worker, Train Epoch: 6 [6400/50000 (12.8%)]	Loss: 0.070042
# (pid=13469, ip=10.21.5.133) The 2 worker, Train Epoch: 6 [6400/50000 (12.8%)]	Loss: 0.092402
# (pid=31165) The 1 worker, Train Epoch: 6 [12800/50000 (25.6%)]	Loss: 0.021948
# (pid=16737, ip=10.21.5.134) The 0 worker, Train Epoch: 6 [12800/50000 (25.6%)]	Loss: 0.075949
# (pid=13469, ip=10.21.5.133) The 2 worker, Train Epoch: 6 [12800/50000 (25.6%)]	Loss: 0.114343
# (pid=31165) The 1 worker, Train Epoch: 6 [19200/50000 (38.4%)]	Loss: 0.091211
# (pid=16737, ip=10.21.5.134) The 0 worker, Train Epoch: 6 [19200/50000 (38.4%)]	Loss: 0.146237
# (pid=13469, ip=10.21.5.133) The 2 worker, Train Epoch: 6 [19200/50000 (38.4%)]	Loss: 0.103557
# (pid=31165) The 1 worker, Train Epoch: 6 [25600/50000 (51.2%)]	Loss: 0.113268
# (pid=16737, ip=10.21.5.134) The 0 worker, Train Epoch: 6 [25600/50000 (51.2%)]	Loss: 0.099967
# (pid=13469, ip=10.21.5.133) The 2 worker, Train Epoch: 6 [25600/50000 (51.2%)]	Loss: 0.118178
# (pid=31165) The 1 worker, Train Epoch: 6 [32000/50000 (63.9%)]	Loss: 0.103573
# (pid=16737, ip=10.21.5.134) The 0 worker, Train Epoch: 6 [32000/50000 (63.9%)]	Loss: 0.078981
# (pid=13469, ip=10.21.5.133) The 2 worker, Train Epoch: 6 [32000/50000 (63.9%)]	Loss: 0.072856
# (pid=31165) The 1 worker, Train Epoch: 6 [38400/50000 (76.7%)]	Loss: 0.045673

# %%
# 经过一个epoch 的 test set
state2 = local_test_model.state_dict()

# %%
state2['layer1.0.bn1.running_mean']

# %%
state2['layer1.0.bn1.running_var']

# %%
state2['layer1.0.bn1.weight']

# %%
state2['layer1.0.bn1.bias']

# %%
# bn层的4个参数都没有变

# %%
# train dataset loader, but set model.eval(), acc=11% for one epoch 
# local_test_model.eval()
local_test_model.train()
# train dataset loader

test_loss = 0.
correct = 0.
train_batch_count = 0.
num_batch = 0
for data, target in local_train_loader:
#     if train_batch_count % 30 == 0:
#         print(train_batch_count)
#         local_test_model.eval()
#         test_model(local_test_model,local_test_loader)
        
    if train_batch_count==150:
        break
        
    num_batch += 1   
    local_test_model.train()
    data,target = data.cuda(),target.cuda()
    train_batch_count += 1
    data, target = Variable(data, volatile=True), Variable(target)
    output = local_test_model(data)
    test_loss += F.cross_entropy(output, target, size_average=False).data # sum up batch loss
    pred = output.data.max(1, keepdim=True)[1] # get the index of the max log-probability
    batch_correct = pred.eq(target.data.view_as(pred)).sum()
    correct += batch_correct
    
    for name,param in local_test_model.named_parameters():
        test_writer.add_histogram(name, param, num_batch)

    
#     if train_batch_count % 100  == 0:
#         print("With model.train(), batch num: ",train_batch_count, " , with correct: ",int(batch_correct.data), " / ", len(data))

test_loss /= len(local_train_loader.dataset)
print('\nTrain set: Average loss: {:.4f}, Accuracy: {}/{} ({:.6f})\n'.format(
    test_loss, correct, len(local_train_loader.dataset),
    correct / float(len(local_train_loader.dataset))))

# %%
state3 = local_test_model.state_dict()
print(state3['layer1.0.bn1.running_mean'])
print(state3['layer1.0.bn1.running_var'])
print(state3['layer1.0.bn1.weight'])
print(state3['layer1.0.bn1.bias'])

# %%
bn_name = []
bn_li = []
for m in local_test_model.modules():
    if isinstance(m, nn.BatchNorm2d):
        bn_name.append(m.name)
        bn_li.append(m.weight.data)

# %%
state = {
    'state_dict':local_test_model.state_dict(),
}
torch.save(state,'/userhome/34/gyu/tmp/checkpoint_tmp.pth.tar')

# %%
local_test_model2
test_model(local_test_model2,local_test_loader)

# %%
def _get_params(model):
    bns = {}
    non_bns = {}
    param_count = 0.
    bn_param_count = 0.
    for name,param in model.named_parameters():
        param_count += len(param)
        if 'bn' in name:
            bns[name] = param
            bn_param_count += len(param)
        else:
            non_bns[name] = param
    print("bn params occupies: ",bn_param_count/param_count)
    return bns,non_bns

# %%
_get_params(local_test_model)

# %%
local_bns2

# %%
state_dict = ray.get(ps.pull_weights.remote())

# %%
non_bn={}
for ele in state_dict:
    if 'bn' not in ele:
        non_bn[ele]=state_dict[ele]

# %%
init_wei = ray.get(ps.pull_weights.remote())

# %%
init_wei[]

# %%
import _to_remove_resnet.models as tmpmodels

# %%
res56 = tmpmodels.__dict__["resnet"](dataset="cifar10",depth=56)
res56.cuda()

# %%
from torchsummary import summary
summary(res56, input_size=(3, 32, 32))

# %%
import torch
wide_50 = torch.hub.load('pytorch/vision:v0.4.2', 'wide_resnet50_2', pretrained=True)
wide_50.cuda()

# %%
summary(wide_50, input_size=(3, 32, 32))

# %%
resnext50 = torch.hub.load('pytorch/vision:v0.4.2', 'resnext50_32x4d', pretrained=True)
resnext50.cuda()

# %%
summary(resnext50, input_size=(3, 64, 64))
