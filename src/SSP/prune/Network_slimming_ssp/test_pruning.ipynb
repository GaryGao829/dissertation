# %%
import argparse
import numpy as np
import os

import torch
import torch.nn as nn
from torch.autograd import Variable
from torchvision import datasets, transforms

import models 
from models import channel_selection

# %%
# # 从原始的model 来初始化，然后把ckpt里面的参数填进去

# model = models.__dict__['resnet'](dataset='cifar10', depth=164)
# # model.cuda()

# if os.path.isfile('/userhome/34/gyu/logs_sr/3wk_p1/checkpoint_3EPO_sr.pth.tar'):
#     checkpoint = torch.load('/userhome/34/gyu/logs_sr/3wk_p1/checkpoint_3EPO_sr.pth.tar')
#     model.load_state_dict(checkpoint['state_dict'])

# %%
# 剪枝过后的 model 来初始化，然后把ckpt里面的参数填进去
checkpoint = torch.load('/userhome/34/gyu/logs_sr/3wk_p1/prune_1st/pruned.pth.tar')

model = models.__dict__['resnet'](dataset='cifar10', depth=164, cfg=checkpoint['cfg'])
model.load_state_dict(checkpoint['state_dict'])                
# model.cuda()
# Out:
# IncompatibleKeys(missing_keys=[], unexpected_keys=[])

# %%
model
# Out:
# resnet(
#   (conv1): Conv2d(3, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#   (layer1): Sequential(
#     (0): Bottleneck(
#       (bn1): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (select): channel_selection()
#       (conv1): Conv2d(11, 12, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn2): BatchNorm2d(12, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(12, 14, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn3): BatchNorm2d(14, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(14, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (relu): ReLU(inplace)
#       (downsample): Sequential(
#         (0): Conv2d(16, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       )
#     )
#     (1): Bottleneck(
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (select): channel_selection()
#       (conv1): Conv2d(34, 12, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn2): BatchNorm2d(12, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(12, 11, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn3): BatchNorm2d(11, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(11, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (relu): ReLU(inplace)
#     )
#     (2): Bottleneck(
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (select): channel_selection()
#       (conv1): Conv2d(42, 13, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn2): BatchNorm2d(13, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(13, 13, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn3): BatchNorm2d(13, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(13, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (relu): ReLU(inplace)
#     )
#     (3): Bottleneck(
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (select): channel_selection()
#       (conv1): Conv2d(44, 12, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn2): BatchNorm2d(12, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(12, 13, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn3): BatchNorm2d(13, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(13, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (relu): ReLU(inplace)
#     )
#     (4): Bottleneck(
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (select): channel_selection()
#       (conv1): Conv2d(41, 13, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn2): BatchNorm2d(13, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(13, 14, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn3): BatchNorm2d(14, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(14, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (relu): ReLU(inplace)
#     )
#     (5): Bottleneck(
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (select): channel_selection()
#       (conv1): Conv2d(35, 13, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn2): BatchNorm2d(13, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(13, 10, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn3): BatchNorm2d(10, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(10, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (relu): ReLU(inplace)
#     )
#     (6): Bottleneck(
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (select): channel_selection()
#       (conv1): Conv2d(37, 11, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn2): BatchNorm2d(11, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(11, 12, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn3): BatchNorm2d(12, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(12, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (relu): ReLU(inplace)
#     )
#     (7): Bottleneck(
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (select): channel_selection()
#       (conv1): Conv2d(37, 12, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn2): BatchNorm2d(12, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(12, 13, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn3): BatchNorm2d(13, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(13, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (relu): ReLU(inplace)
#     )
#     (8): Bottleneck(
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (select): channel_selection()
#       (conv1): Conv2d(41, 12, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn2): BatchNorm2d(12, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(12, 11, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn3): BatchNorm2d(11, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(11, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (relu): ReLU(inplace)
#     )
#     (9): Bottleneck(
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (select): channel_selection()
#       (conv1): Conv2d(43, 11, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn2): BatchNorm2d(11, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(11, 12, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn3): BatchNorm2d(12, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(12, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (relu): ReLU(inplace)
#     )
#     (10): Bottleneck(
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (select): channel_selection()
#       (conv1): Conv2d(40, 9, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn2): BatchNorm2d(9, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(9, 10, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn3): BatchNorm2d(10, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(10, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (relu): ReLU(inplace)
#     )
#     (11): Bottleneck(
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (select): channel_selection()
#       (conv1): Conv2d(40, 12, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn2): BatchNorm2d(12, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(12, 13, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn3): BatchNorm2d(13, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(13, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (relu): ReLU(inplace)
#     )
#     (12): Bottleneck(
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (select): channel_selection()
#       (conv1): Conv2d(34, 7, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn2): BatchNorm2d(7, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(7, 15, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn3): BatchNorm2d(15, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(15, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (relu): ReLU(inplace)
#     )
#     (13): Bottleneck(
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (select): channel_selection()
#       (conv1): Conv2d(46, 13, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn2): BatchNorm2d(13, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(13, 9, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn3): BatchNorm2d(9, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(9, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (relu): ReLU(inplace)
#     )
#     (14): Bottleneck(
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (select): channel_selection()
#       (conv1): Conv2d(41, 12, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn2): BatchNorm2d(12, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(12, 9, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn3): BatchNorm2d(9, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(9, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (relu): ReLU(inplace)
#     )
#     (15): Bottleneck(
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (select): channel_selection()
#       (conv1): Conv2d(42, 12, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn2): BatchNorm2d(12, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(12, 9, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn3): BatchNorm2d(9, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(9, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (relu): ReLU(inplace)
#     )
#     (16): Bottleneck(
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (select): channel_selection()
#       (conv1): Conv2d(46, 11, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn2): BatchNorm2d(11, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(11, 10, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn3): BatchNorm2d(10, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(10, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (relu): ReLU(inplace)
#     )
#     (17): Bottleneck(
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (select): channel_selection()
#       (conv1): Conv2d(42, 10, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn2): BatchNorm2d(10, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(10, 9, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn3): BatchNorm2d(9, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(9, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (relu): ReLU(inplace)
#     )
#   )
#   (layer2): Sequential(
#     (0): Bottleneck(
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (select): channel_selection()
#       (conv1): Conv2d(42, 25, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn2): BatchNorm2d(25, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(25, 30, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn3): BatchNorm2d(30, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(30, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (relu): ReLU(inplace)
#       (downsample): Sequential(
#         (0): Conv2d(64, 128, kernel_size=(1, 1), stride=(2, 2), bias=False)
#       )
#     )
#     (1): Bottleneck(
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (select): channel_selection()
#       (conv1): Conv2d(94, 21, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn2): BatchNorm2d(21, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(21, 31, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn3): BatchNorm2d(31, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(31, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (relu): ReLU(inplace)
#     )
#     (2): Bottleneck(
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (select): channel_selection()
#       (conv1): Conv2d(89, 21, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn2): BatchNorm2d(21, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(21, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn3): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(32, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (relu): ReLU(inplace)
#     )
#     (3): Bottleneck(
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (select): channel_selection()
#       (conv1): Conv2d(88, 26, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn2): BatchNorm2d(26, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(26, 30, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn3): BatchNorm2d(30, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(30, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (relu): ReLU(inplace)
#     )
#     (4): Bottleneck(
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (select): channel_selection()
#       (conv1): Conv2d(91, 24, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn2): BatchNorm2d(24, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(24, 30, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn3): BatchNorm2d(30, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(30, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (relu): ReLU(inplace)
#     )
#     (5): Bottleneck(
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (select): channel_selection()
#       (conv1): Conv2d(93, 21, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn2): BatchNorm2d(21, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(21, 30, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn3): BatchNorm2d(30, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(30, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (relu): ReLU(inplace)
#     )
#     (6): Bottleneck(
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (select): channel_selection()
#       (conv1): Conv2d(89, 24, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn2): BatchNorm2d(24, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(24, 30, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn3): BatchNorm2d(30, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(30, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (relu): ReLU(inplace)
#     )
#     (7): Bottleneck(
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (select): channel_selection()
#       (conv1): Conv2d(84, 19, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn2): BatchNorm2d(19, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(19, 30, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn3): BatchNorm2d(30, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(30, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (relu): ReLU(inplace)
#     )
#     (8): Bottleneck(
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (select): channel_selection()
#       (conv1): Conv2d(95, 26, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn2): BatchNorm2d(26, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(26, 29, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn3): BatchNorm2d(29, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(29, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (relu): ReLU(inplace)
#     )
#     (9): Bottleneck(
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (select): channel_selection()
#       (conv1): Conv2d(87, 20, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn2): BatchNorm2d(20, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(20, 31, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn3): BatchNorm2d(31, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(31, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (relu): ReLU(inplace)
#     )
#     (10): Bottleneck(
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (select): channel_selection()
#       (conv1): Conv2d(94, 23, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn2): BatchNorm2d(23, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(23, 28, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn3): BatchNorm2d(28, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(28, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (relu): ReLU(inplace)
#     )
#     (11): Bottleneck(
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (select): channel_selection()
#       (conv1): Conv2d(90, 23, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn2): BatchNorm2d(23, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(23, 31, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn3): BatchNorm2d(31, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(31, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (relu): ReLU(inplace)
#     )
#     (12): Bottleneck(
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (select): channel_selection()
#       (conv1): Conv2d(91, 24, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn2): BatchNorm2d(24, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(24, 30, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn3): BatchNorm2d(30, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(30, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (relu): ReLU(inplace)
#     )
#     (13): Bottleneck(
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (select): channel_selection()
#       (conv1): Conv2d(97, 22, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn2): BatchNorm2d(22, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(22, 29, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn3): BatchNorm2d(29, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(29, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (relu): ReLU(inplace)
#     )
#     (14): Bottleneck(
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (select): channel_selection()
#       (conv1): Conv2d(91, 26, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn2): BatchNorm2d(26, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(26, 31, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn3): BatchNorm2d(31, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(31, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (relu): ReLU(inplace)
#     )
#     (15): Bottleneck(
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (select): channel_selection()
#       (conv1): Conv2d(94, 22, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn2): BatchNorm2d(22, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(22, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn3): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(32, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (relu): ReLU(inplace)
#     )
#     (16): Bottleneck(
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (select): channel_selection()
#       (conv1): Conv2d(96, 21, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn2): BatchNorm2d(21, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(21, 31, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn3): BatchNorm2d(31, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(31, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (relu): ReLU(inplace)
#     )
#     (17): Bottleneck(
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (select): channel_selection()
#       (conv1): Conv2d(88, 23, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn2): BatchNorm2d(23, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(23, 30, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn3): BatchNorm2d(30, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(30, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (relu): ReLU(inplace)
#     )
#   )
#   (layer3): Sequential(
#     (0): Bottleneck(
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (select): channel_selection()
#       (conv1): Conv2d(93, 45, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn2): BatchNorm2d(45, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(45, 64, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn3): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (relu): ReLU(inplace)
#       (downsample): Sequential(
#         (0): Conv2d(128, 256, kernel_size=(1, 1), stride=(2, 2), bias=False)
#       )
#     )
#     (1): Bottleneck(
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (select): channel_selection()
#       (conv1): Conv2d(209, 41, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn2): BatchNorm2d(41, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(41, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn3): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (relu): ReLU(inplace)
#     )
#     (2): Bottleneck(
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (select): channel_selection()
#       (conv1): Conv2d(198, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn2): BatchNorm2d(48, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(48, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn3): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (relu): ReLU(inplace)
#     )
#     (3): Bottleneck(
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (select): channel_selection()
#       (conv1): Conv2d(209, 49, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn2): BatchNorm2d(49, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(49, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn3): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (relu): ReLU(inplace)
#     )
#     (4): Bottleneck(
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (select): channel_selection()
#       (conv1): Conv2d(205, 46, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn2): BatchNorm2d(46, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(46, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn3): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (relu): ReLU(inplace)
#     )
#     (5): Bottleneck(
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (select): channel_selection()
#       (conv1): Conv2d(216, 40, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn2): BatchNorm2d(40, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(40, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn3): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (relu): ReLU(inplace)
#     )
#     (6): Bottleneck(
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (select): channel_selection()
#       (conv1): Conv2d(214, 45, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn2): BatchNorm2d(45, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(45, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn3): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (relu): ReLU(inplace)
#     )
#     (7): Bottleneck(
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (select): channel_selection()
#       (conv1): Conv2d(212, 43, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn2): BatchNorm2d(43, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(43, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn3): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (relu): ReLU(inplace)
#     )
#     (8): Bottleneck(
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (select): channel_selection()
#       (conv1): Conv2d(220, 54, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn2): BatchNorm2d(54, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(54, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn3): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (relu): ReLU(inplace)
#     )
#     (9): Bottleneck(
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (select): channel_selection()
#       (conv1): Conv2d(211, 41, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn2): BatchNorm2d(41, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(41, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn3): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (relu): ReLU(inplace)
#     )
#     (10): Bottleneck(
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (select): channel_selection()
#       (conv1): Conv2d(219, 46, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn2): BatchNorm2d(46, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(46, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn3): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (relu): ReLU(inplace)
#     )
#     (11): Bottleneck(
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (select): channel_selection()
#       (conv1): Conv2d(219, 49, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn2): BatchNorm2d(49, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(49, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn3): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (relu): ReLU(inplace)
#     )
#     (12): Bottleneck(
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (select): channel_selection()
#       (conv1): Conv2d(221, 49, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn2): BatchNorm2d(49, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(49, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn3): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (relu): ReLU(inplace)
#     )
#     (13): Bottleneck(
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (select): channel_selection()
#       (conv1): Conv2d(215, 50, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn2): BatchNorm2d(50, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(50, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn3): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (relu): ReLU(inplace)
#     )
#     (14): Bottleneck(
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (select): channel_selection()
#       (conv1): Conv2d(230, 55, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn2): BatchNorm2d(55, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(55, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn3): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (relu): ReLU(inplace)
#     )
#     (15): Bottleneck(
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (select): channel_selection()
#       (conv1): Conv2d(231, 50, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn2): BatchNorm2d(50, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(50, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn3): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (relu): ReLU(inplace)
#     )
#     (16): Bottleneck(
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (select): channel_selection()
#       (conv1): Conv2d(225, 47, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn2): BatchNorm2d(47, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(47, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn3): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (relu): ReLU(inplace)
#     )
#     (17): Bottleneck(
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (select): channel_selection()
#       (conv1): Conv2d(236, 52, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn2): BatchNorm2d(52, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(52, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn3): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (relu): ReLU(inplace)
#     )
#   )
#   (bn): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (select): channel_selection()
#   (relu): ReLU(inplace)
#   (avgpool): AvgPool2d(kernel_size=8, stride=8, padding=0)
#   (fc): Linear(in_features=245, out_features=10, bias=True)
# )

# %%
def count_conv_channels(model):
    sum_channel = 0
    for m in model.modules():
        if isinstance(m, nn.Conv2d):
            sum_channel += m.in_channels
#     print(sum_channel)
    return sum_channel

# %%
print("observe from the conv angle :::")
print("  original model conv channels: ",count_conv_channels(models.__dict__['resnet'](dataset='cifar10', depth=164)))
print("  after prune 20%: ",count_conv_channels(model))
print("  9655/12067 = 0.8001")
print("observe from the cfg angle :::")
n = (164 - 2) // 9
orig_cfg = [[16, 16, 16], [64, 16, 16]*(n-1), [64, 32, 32], [128, 32, 32]*(n-1), [128, 64, 64], [256, 64, 64]*(n-1), [256]]
orig_cfg = [item for sub_list in orig_cfg for item in sub_list]
print("  oringinal cfg sum: ", sum(orig_cfg))
print("  after prune 20%: ", sum(checkpoint['cfg']))
print("  9689 / 12112 =  0.79995")
# Out:
# observe from the conv angle :::
#   original model conv channels:  12067
#   after prune 20%:  9655
#   9655/12067 = 0.8001
# observe from the cfg angle :::
#   oringinal cfg sum:  12112
#   after prune 20%:  9689
#   9689 / 12112 =  0.79995

# %%
# total = 0
# # total ： 当前总channel数量

# for m in model.modules():
#     if isinstance(m, nn.BatchNorm2d):
#         total += m.weight.data.shape[0]
# print(total)

# %%
# update: 这里应该判定一下，当bn后一层是cs层的时候，这里不能用bn的shape，而是应该用它后一层的cs层里面select了多少来算
total = 0
module_list = list(model.modules())
for i in range(len(module_list)):
    m = module_list[i]
    if (i + 1< len(module_list)) and isinstance(m, nn.BatchNorm2d) and isinstance(module_list[i+1],channel_selection):
        cs = module_list[i+1]
        total += int(torch.sum(cs.indexes))
    elif isinstance(m, nn.BatchNorm2d):
        total += m.weight.data.shape[0]
print(total)
# Out:
# 9689

# %%
# total = 11452
# bn = torch.zeros(total)

# index = 0
# for m in model.modules():
#     if isinstance(m, nn.BatchNorm2d):
#         size = m.weight.data.shape[0]
#         bn[index:(index+size)] = m.weight.data.abs().clone() # 的确应该取绝对值
#         index += size
# print(index)

# %%
bn = torch.zeros(total)

index = 0
for i in range(len(module_list)):
    m = module_list[i]
    if i+1 < len(module_list) and isinstance(m, nn.BatchNorm2d) and isinstance(module_list[i+1],channel_selection):
        cs = module_list[i+1]
        size = int(torch.sum(cs.indexes))
        mask = cs.indexes.clone().detach().numpy()
        bn[index:(index+size)] = torch.from_numpy(m.weight.data.abs().clone().numpy()[np.where(mask)])
        index += size
    elif isinstance(m, nn.BatchNorm2d):
        size = m.weight.data.shape[0]
        bn[index:(index+size)] = m.weight.data.abs().clone() # 的确应该取绝对值
        index += size

# %%
bn # 所有bn的weight
# Out:
# tensor([0.4114, 0.7914, 0.5157,  ..., 0.6796, 0.6411, 0.6802])

# %%
y, i = torch.sort(bn)
thre_index = int(total * 0.2)
thre = y[thre_index]
# y,i = y.cuda(),i.cuda()
# thre = thre.cuda()
print(y)
print(thre)
# Out:
# tensor([0.3462, 0.3462, 0.3462,  ..., 1.3288, 1.4001, 1.5130])
# tensor(0.3676)

# %%
# y: 排序后的bn数组
# i: 对应元素在排序前的index
# thre: 小于阈值的被剪枝

# %%
pruned = 0
cfg = []
cfg_mask = []
for k, m in enumerate(model.modules()):
    if isinstance(m, nn.BatchNorm2d):
        weight_copy = m.weight.data.abs().clone()
        mask = weight_copy.gt(thre).float() # 大于阈值 mask 对应元素为 1
        pruned = pruned + mask.shape[0] - torch.sum(mask) # pruned += mask中为0的元素个数
        m.weight.data.mul_(mask)
        m.bias.data.mul_(mask)
        cfg.append(int(torch.sum(mask))) # cfg 为mask中元素等于1的个数
        cfg_mask.append(mask.clone())
        print('layer index: {:d} \t total channel: {:d} \t remaining channel: {:d}'.
            format(k, mask.shape[0], int(torch.sum(mask))))
    elif isinstance(m, nn.MaxPool2d):
        cfg.append('M')
# Out:
# layer index: 4 	 total channel: 16 	 remaining channel: 10
# layer index: 7 	 total channel: 12 	 remaining channel: 11
# layer index: 9 	 total channel: 14 	 remaining channel: 12
# layer index: 15 	 total channel: 64 	 remaining channel: 30
# layer index: 18 	 total channel: 12 	 remaining channel: 11
# layer index: 20 	 total channel: 11 	 remaining channel: 11
# layer index: 24 	 total channel: 64 	 remaining channel: 32
# layer index: 27 	 total channel: 13 	 remaining channel: 11
# layer index: 29 	 total channel: 13 	 remaining channel: 13
# layer index: 33 	 total channel: 64 	 remaining channel: 38
# layer index: 36 	 total channel: 12 	 remaining channel: 12
# layer index: 38 	 total channel: 13 	 remaining channel: 11
# layer index: 42 	 total channel: 64 	 remaining channel: 37
# layer index: 45 	 total channel: 13 	 remaining channel: 13
# layer index: 47 	 total channel: 14 	 remaining channel: 12
# layer index: 51 	 total channel: 64 	 remaining channel: 32
# layer index: 54 	 total channel: 13 	 remaining channel: 13
# layer index: 56 	 total channel: 10 	 remaining channel: 9
# layer index: 60 	 total channel: 64 	 remaining channel: 34
# layer index: 63 	 total channel: 11 	 remaining channel: 11
# layer index: 65 	 total channel: 12 	 remaining channel: 12
# layer index: 69 	 total channel: 64 	 remaining channel: 34
# layer index: 72 	 total channel: 12 	 remaining channel: 11
# layer index: 74 	 total channel: 13 	 remaining channel: 13
# layer index: 78 	 total channel: 64 	 remaining channel: 35
# layer index: 81 	 total channel: 12 	 remaining channel: 10
# layer index: 83 	 total channel: 11 	 remaining channel: 9
# layer index: 87 	 total channel: 64 	 remaining channel: 36
# layer index: 90 	 total channel: 11 	 remaining channel: 11
# layer index: 92 	 total channel: 12 	 remaining channel: 12
# layer index: 96 	 total channel: 64 	 remaining channel: 32
# layer index: 99 	 total channel: 9 	 remaining channel: 9
# layer index: 101 	 total channel: 10 	 remaining channel: 9
# layer index: 105 	 total channel: 64 	 remaining channel: 34
# layer index: 108 	 total channel: 12 	 remaining channel: 12
# layer index: 110 	 total channel: 13 	 remaining channel: 10
# layer index: 114 	 total channel: 64 	 remaining channel: 30
# layer index: 117 	 total channel: 7 	 remaining channel: 7
# layer index: 119 	 total channel: 15 	 remaining channel: 15
# layer index: 123 	 total channel: 64 	 remaining channel: 38
# layer index: 126 	 total channel: 13 	 remaining channel: 11
# layer index: 128 	 total channel: 9 	 remaining channel: 7
# layer index: 132 	 total channel: 64 	 remaining channel: 33
# layer index: 135 	 total channel: 12 	 remaining channel: 11
# layer index: 137 	 total channel: 9 	 remaining channel: 8
# layer index: 141 	 total channel: 64 	 remaining channel: 36
# layer index: 144 	 total channel: 12 	 remaining channel: 11
# layer index: 146 	 total channel: 9 	 remaining channel: 8
# layer index: 150 	 total channel: 64 	 remaining channel: 43
# layer index: 153 	 total channel: 11 	 remaining channel: 11
# layer index: 155 	 total channel: 10 	 remaining channel: 9
# layer index: 159 	 total channel: 64 	 remaining channel: 34
# layer index: 162 	 total channel: 10 	 remaining channel: 7
# layer index: 164 	 total channel: 9 	 remaining channel: 7
# layer index: 169 	 total channel: 64 	 remaining channel: 31
# layer index: 172 	 total channel: 25 	 remaining channel: 22
# layer index: 174 	 total channel: 30 	 remaining channel: 25
# layer index: 180 	 total channel: 128 	 remaining channel: 74
# layer index: 183 	 total channel: 21 	 remaining channel: 17
# layer index: 185 	 total channel: 31 	 remaining channel: 28
# layer index: 189 	 total channel: 128 	 remaining channel: 69
# layer index: 192 	 total channel: 21 	 remaining channel: 20
# layer index: 194 	 total channel: 32 	 remaining channel: 32
# layer index: 198 	 total channel: 128 	 remaining channel: 72
# layer index: 201 	 total channel: 26 	 remaining channel: 22
# layer index: 203 	 total channel: 30 	 remaining channel: 29
# layer index: 207 	 total channel: 128 	 remaining channel: 74
# layer index: 210 	 total channel: 24 	 remaining channel: 23
# layer index: 212 	 total channel: 30 	 remaining channel: 28
# layer index: 216 	 total channel: 128 	 remaining channel: 72
# layer index: 219 	 total channel: 21 	 remaining channel: 17
# layer index: 221 	 total channel: 30 	 remaining channel: 30
# layer index: 225 	 total channel: 128 	 remaining channel: 81
# layer index: 228 	 total channel: 24 	 remaining channel: 16
# layer index: 230 	 total channel: 30 	 remaining channel: 29
# layer index: 234 	 total channel: 128 	 remaining channel: 67
# layer index: 237 	 total channel: 19 	 remaining channel: 15
# layer index: 239 	 total channel: 30 	 remaining channel: 29
# layer index: 243 	 total channel: 128 	 remaining channel: 71
# layer index: 246 	 total channel: 26 	 remaining channel: 21
# layer index: 248 	 total channel: 29 	 remaining channel: 25
# layer index: 252 	 total channel: 128 	 remaining channel: 67
# layer index: 255 	 total channel: 20 	 remaining channel: 16
# layer index: 257 	 total channel: 31 	 remaining channel: 29
# layer index: 261 	 total channel: 128 	 remaining channel: 72
# layer index: 264 	 total channel: 23 	 remaining channel: 19
# layer index: 266 	 total channel: 28 	 remaining channel: 24
# layer index: 270 	 total channel: 128 	 remaining channel: 67
# layer index: 273 	 total channel: 23 	 remaining channel: 18
# layer index: 275 	 total channel: 31 	 remaining channel: 29
# layer index: 279 	 total channel: 128 	 remaining channel: 76
# layer index: 282 	 total channel: 24 	 remaining channel: 21
# layer index: 284 	 total channel: 30 	 remaining channel: 28
# layer index: 288 	 total channel: 128 	 remaining channel: 75
# layer index: 291 	 total channel: 22 	 remaining channel: 20
# layer index: 293 	 total channel: 29 	 remaining channel: 26
# layer index: 297 	 total channel: 128 	 remaining channel: 74
# layer index: 300 	 total channel: 26 	 remaining channel: 22
# layer index: 302 	 total channel: 31 	 remaining channel: 27
# layer index: 306 	 total channel: 128 	 remaining channel: 71
# layer index: 309 	 total channel: 22 	 remaining channel: 19
# layer index: 311 	 total channel: 32 	 remaining channel: 31
# layer index: 315 	 total channel: 128 	 remaining channel: 80
# layer index: 318 	 total channel: 21 	 remaining channel: 17
# layer index: 320 	 total channel: 31 	 remaining channel: 28
# layer index: 324 	 total channel: 128 	 remaining channel: 67
# layer index: 327 	 total channel: 23 	 remaining channel: 20
# layer index: 329 	 total channel: 30 	 remaining channel: 29
# layer index: 334 	 total channel: 128 	 remaining channel: 66
# layer index: 337 	 total channel: 45 	 remaining channel: 33
# layer index: 339 	 total channel: 64 	 remaining channel: 63
# layer index: 345 	 total channel: 256 	 remaining channel: 147
# layer index: 348 	 total channel: 41 	 remaining channel: 32
# layer index: 350 	 total channel: 64 	 remaining channel: 64
# layer index: 354 	 total channel: 256 	 remaining channel: 133
# layer index: 357 	 total channel: 48 	 remaining channel: 34
# layer index: 359 	 total channel: 64 	 remaining channel: 64
# layer index: 363 	 total channel: 256 	 remaining channel: 152
# layer index: 366 	 total channel: 49 	 remaining channel: 39
# layer index: 368 	 total channel: 64 	 remaining channel: 64
# layer index: 372 	 total channel: 256 	 remaining channel: 147
# layer index: 375 	 total channel: 46 	 remaining channel: 34
# layer index: 377 	 total channel: 64 	 remaining channel: 64
# layer index: 381 	 total channel: 256 	 remaining channel: 163
# layer index: 384 	 total channel: 40 	 remaining channel: 35
# layer index: 386 	 total channel: 64 	 remaining channel: 64
# layer index: 390 	 total channel: 256 	 remaining channel: 150
# layer index: 393 	 total channel: 45 	 remaining channel: 36
# layer index: 395 	 total channel: 64 	 remaining channel: 64
# layer index: 399 	 total channel: 256 	 remaining channel: 145
# layer index: 402 	 total channel: 43 	 remaining channel: 36
# layer index: 404 	 total channel: 64 	 remaining channel: 63
# layer index: 408 	 total channel: 256 	 remaining channel: 153
# layer index: 411 	 total channel: 54 	 remaining channel: 33
# layer index: 413 	 total channel: 64 	 remaining channel: 64
# layer index: 417 	 total channel: 256 	 remaining channel: 151
# layer index: 420 	 total channel: 41 	 remaining channel: 32
# layer index: 422 	 total channel: 64 	 remaining channel: 64
# layer index: 426 	 total channel: 256 	 remaining channel: 149
# layer index: 429 	 total channel: 46 	 remaining channel: 33
# layer index: 431 	 total channel: 64 	 remaining channel: 64
# layer index: 435 	 total channel: 256 	 remaining channel: 153
# layer index: 438 	 total channel: 49 	 remaining channel: 38
# layer index: 440 	 total channel: 64 	 remaining channel: 64
# layer index: 444 	 total channel: 256 	 remaining channel: 154
# layer index: 447 	 total channel: 49 	 remaining channel: 37
# layer index: 449 	 total channel: 64 	 remaining channel: 63
# layer index: 453 	 total channel: 256 	 remaining channel: 159
# layer index: 456 	 total channel: 50 	 remaining channel: 34
# layer index: 458 	 total channel: 64 	 remaining channel: 63
# layer index: 462 	 total channel: 256 	 remaining channel: 157
# layer index: 465 	 total channel: 55 	 remaining channel: 42
# layer index: 467 	 total channel: 64 	 remaining channel: 63
# layer index: 471 	 total channel: 256 	 remaining channel: 167
# layer index: 474 	 total channel: 50 	 remaining channel: 32
# layer index: 476 	 total channel: 64 	 remaining channel: 64
# layer index: 480 	 total channel: 256 	 remaining channel: 154
# layer index: 483 	 total channel: 47 	 remaining channel: 28
# layer index: 485 	 total channel: 64 	 remaining channel: 64
# layer index: 489 	 total channel: 256 	 remaining channel: 155
# layer index: 492 	 total channel: 52 	 remaining channel: 34
# layer index: 494 	 total channel: 64 	 remaining channel: 64
# layer index: 497 	 total channel: 256 	 remaining channel: 238

# %%
# for tmp in range(len(cfg)):
#     print(cfg[tmp],len(cfg_mask[tmp]),int(torch.sum(cfg_mask[tmp])))

# %%
len(cfg_mask)
# Out:
# 163

# %%
pruned_ratio = pruned/total

print('Pre-processing Successful!')
print(pruned_ratio)
# Out:
# Pre-processing Successful!
# tensor(0.3820)

# %%
# simple test model after Pre-processing prune (simple set BN scales to zeros)
def test(model):
    model.cuda()
    kwargs = {'num_workers': 1, 'pin_memory': True} 
    test_loader = torch.utils.data.DataLoader(
        datasets.CIFAR10('./data.cifar10', train=False, transform=transforms.Compose([
            transforms.ToTensor(),
            transforms.Normalize((0.4914, 0.4822, 0.4465), (0.2023, 0.1994, 0.2010))])),
        batch_size=64, shuffle=False, **kwargs)
    model.eval()
    correct = 0
    for data, target in test_loader:
        data, target = data.cuda(), target.cuda()
        data, target = Variable(data, volatile=True), Variable(target)
        output = model(data)
        pred = output.data.max(1, keepdim=True)[1] # get the index of the max log-probability
        correct += pred.eq(target.data.view_as(pred)).cpu().sum()

    print('\nTest set: Accuracy: {}/{} ({:.1f}%)\n'.format(
        correct, len(test_loader.dataset), 100. * correct / len(test_loader.dataset)))
    model.cpu()
    return correct / float(len(test_loader.dataset))

# %%
acc = test(model)
print(acc)

# %%
# 从这里定义Net的源码 可以发现cfg决定了channel的数量
# 这里通过剪枝得到了剪完以后的cfg 根据这个来init newmodel
print("Cfg:")
print(cfg)
print(len(cfg))
print(len(cfg_mask))
# Out:
# Cfg:
# [10, 11, 12, 30, 11, 11, 32, 11, 13, 38, 12, 11, 37, 13, 12, 32, 13, 9, 34, 11, 12, 34, 11, 13, 35, 10, 9, 36, 11, 12, 32, 9, 9, 34, 12, 10, 30, 7, 15, 38, 11, 7, 33, 11, 8, 36, 11, 8, 43, 11, 9, 34, 7, 7, 31, 22, 25, 74, 17, 28, 69, 20, 32, 72, 22, 29, 74, 23, 28, 72, 17, 30, 81, 16, 29, 67, 15, 29, 71, 21, 25, 67, 16, 29, 72, 19, 24, 67, 18, 29, 76, 21, 28, 75, 20, 26, 74, 22, 27, 71, 19, 31, 80, 17, 28, 67, 20, 29, 66, 33, 63, 147, 32, 64, 133, 34, 64, 152, 39, 64, 147, 34, 64, 163, 35, 64, 150, 36, 64, 145, 36, 63, 153, 33, 64, 151, 32, 64, 149, 33, 64, 153, 38, 64, 154, 37, 63, 159, 34, 63, 157, 42, 63, 167, 32, 64, 154, 28, 64, 155, 34, 64, 238]
# 163
# 163

# %%
newmodel = models.__dict__["resnet"](dataset="cifar10",depth=164,cfg=cfg)
# newmodel = resnet(depth=164, dataset='cifar-10', cfg=cfg)
newmodel
# Out:
# resnet(
#   (conv1): Conv2d(3, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#   (layer1): Sequential(
#     (0): Bottleneck(
#       (bn1): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (select): channel_selection()
#       (conv1): Conv2d(10, 11, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn2): BatchNorm2d(11, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(11, 12, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn3): BatchNorm2d(12, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(12, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (relu): ReLU(inplace)
#       (downsample): Sequential(
#         (0): Conv2d(16, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       )
#     )
#     (1): Bottleneck(
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (select): channel_selection()
#       (conv1): Conv2d(30, 11, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn2): BatchNorm2d(11, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(11, 11, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn3): BatchNorm2d(11, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(11, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (relu): ReLU(inplace)
#     )
#     (2): Bottleneck(
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (select): channel_selection()
#       (conv1): Conv2d(32, 11, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn2): BatchNorm2d(11, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(11, 13, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn3): BatchNorm2d(13, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(13, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (relu): ReLU(inplace)
#     )
#     (3): Bottleneck(
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (select): channel_selection()
#       (conv1): Conv2d(38, 12, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn2): BatchNorm2d(12, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(12, 11, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn3): BatchNorm2d(11, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(11, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (relu): ReLU(inplace)
#     )
#     (4): Bottleneck(
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (select): channel_selection()
#       (conv1): Conv2d(37, 13, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn2): BatchNorm2d(13, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(13, 12, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn3): BatchNorm2d(12, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(12, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (relu): ReLU(inplace)
#     )
#     (5): Bottleneck(
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (select): channel_selection()
#       (conv1): Conv2d(32, 13, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn2): BatchNorm2d(13, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(13, 9, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn3): BatchNorm2d(9, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(9, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (relu): ReLU(inplace)
#     )
#     (6): Bottleneck(
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (select): channel_selection()
#       (conv1): Conv2d(34, 11, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn2): BatchNorm2d(11, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(11, 12, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn3): BatchNorm2d(12, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(12, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (relu): ReLU(inplace)
#     )
#     (7): Bottleneck(
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (select): channel_selection()
#       (conv1): Conv2d(34, 11, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn2): BatchNorm2d(11, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(11, 13, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn3): BatchNorm2d(13, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(13, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (relu): ReLU(inplace)
#     )
#     (8): Bottleneck(
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (select): channel_selection()
#       (conv1): Conv2d(35, 10, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn2): BatchNorm2d(10, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(10, 9, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn3): BatchNorm2d(9, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(9, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (relu): ReLU(inplace)
#     )
#     (9): Bottleneck(
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (select): channel_selection()
#       (conv1): Conv2d(36, 11, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn2): BatchNorm2d(11, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(11, 12, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn3): BatchNorm2d(12, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(12, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (relu): ReLU(inplace)
#     )
#     (10): Bottleneck(
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (select): channel_selection()
#       (conv1): Conv2d(32, 9, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn2): BatchNorm2d(9, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(9, 9, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn3): BatchNorm2d(9, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(9, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (relu): ReLU(inplace)
#     )
#     (11): Bottleneck(
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (select): channel_selection()
#       (conv1): Conv2d(34, 12, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn2): BatchNorm2d(12, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(12, 10, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn3): BatchNorm2d(10, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(10, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (relu): ReLU(inplace)
#     )
#     (12): Bottleneck(
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (select): channel_selection()
#       (conv1): Conv2d(30, 7, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn2): BatchNorm2d(7, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(7, 15, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn3): BatchNorm2d(15, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(15, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (relu): ReLU(inplace)
#     )
#     (13): Bottleneck(
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (select): channel_selection()
#       (conv1): Conv2d(38, 11, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn2): BatchNorm2d(11, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(11, 7, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn3): BatchNorm2d(7, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(7, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (relu): ReLU(inplace)
#     )
#     (14): Bottleneck(
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (select): channel_selection()
#       (conv1): Conv2d(33, 11, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn2): BatchNorm2d(11, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(11, 8, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn3): BatchNorm2d(8, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(8, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (relu): ReLU(inplace)
#     )
#     (15): Bottleneck(
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (select): channel_selection()
#       (conv1): Conv2d(36, 11, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn2): BatchNorm2d(11, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(11, 8, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn3): BatchNorm2d(8, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(8, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (relu): ReLU(inplace)
#     )
#     (16): Bottleneck(
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (select): channel_selection()
#       (conv1): Conv2d(43, 11, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn2): BatchNorm2d(11, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(11, 9, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn3): BatchNorm2d(9, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(9, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (relu): ReLU(inplace)
#     )
#     (17): Bottleneck(
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (select): channel_selection()
#       (conv1): Conv2d(34, 7, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn2): BatchNorm2d(7, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(7, 7, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn3): BatchNorm2d(7, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(7, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (relu): ReLU(inplace)
#     )
#   )
#   (layer2): Sequential(
#     (0): Bottleneck(
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (select): channel_selection()
#       (conv1): Conv2d(31, 22, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn2): BatchNorm2d(22, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(22, 25, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn3): BatchNorm2d(25, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(25, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (relu): ReLU(inplace)
#       (downsample): Sequential(
#         (0): Conv2d(64, 128, kernel_size=(1, 1), stride=(2, 2), bias=False)
#       )
#     )
#     (1): Bottleneck(
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (select): channel_selection()
#       (conv1): Conv2d(74, 17, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn2): BatchNorm2d(17, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(17, 28, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn3): BatchNorm2d(28, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(28, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (relu): ReLU(inplace)
#     )
#     (2): Bottleneck(
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (select): channel_selection()
#       (conv1): Conv2d(69, 20, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn2): BatchNorm2d(20, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(20, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn3): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(32, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (relu): ReLU(inplace)
#     )
#     (3): Bottleneck(
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (select): channel_selection()
#       (conv1): Conv2d(72, 22, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn2): BatchNorm2d(22, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(22, 29, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn3): BatchNorm2d(29, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(29, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (relu): ReLU(inplace)
#     )
#     (4): Bottleneck(
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (select): channel_selection()
#       (conv1): Conv2d(74, 23, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn2): BatchNorm2d(23, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(23, 28, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn3): BatchNorm2d(28, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(28, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (relu): ReLU(inplace)
#     )
#     (5): Bottleneck(
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (select): channel_selection()
#       (conv1): Conv2d(72, 17, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn2): BatchNorm2d(17, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(17, 30, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn3): BatchNorm2d(30, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(30, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (relu): ReLU(inplace)
#     )
#     (6): Bottleneck(
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (select): channel_selection()
#       (conv1): Conv2d(81, 16, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn2): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(16, 29, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn3): BatchNorm2d(29, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(29, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (relu): ReLU(inplace)
#     )
#     (7): Bottleneck(
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (select): channel_selection()
#       (conv1): Conv2d(67, 15, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn2): BatchNorm2d(15, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(15, 29, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn3): BatchNorm2d(29, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(29, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (relu): ReLU(inplace)
#     )
#     (8): Bottleneck(
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (select): channel_selection()
#       (conv1): Conv2d(71, 21, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn2): BatchNorm2d(21, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(21, 25, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn3): BatchNorm2d(25, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(25, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (relu): ReLU(inplace)
#     )
#     (9): Bottleneck(
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (select): channel_selection()
#       (conv1): Conv2d(67, 16, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn2): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(16, 29, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn3): BatchNorm2d(29, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(29, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (relu): ReLU(inplace)
#     )
#     (10): Bottleneck(
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (select): channel_selection()
#       (conv1): Conv2d(72, 19, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn2): BatchNorm2d(19, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(19, 24, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn3): BatchNorm2d(24, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(24, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (relu): ReLU(inplace)
#     )
#     (11): Bottleneck(
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (select): channel_selection()
#       (conv1): Conv2d(67, 18, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn2): BatchNorm2d(18, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(18, 29, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn3): BatchNorm2d(29, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(29, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (relu): ReLU(inplace)
#     )
#     (12): Bottleneck(
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (select): channel_selection()
#       (conv1): Conv2d(76, 21, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn2): BatchNorm2d(21, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(21, 28, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn3): BatchNorm2d(28, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(28, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (relu): ReLU(inplace)
#     )
#     (13): Bottleneck(
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (select): channel_selection()
#       (conv1): Conv2d(75, 20, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn2): BatchNorm2d(20, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(20, 26, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn3): BatchNorm2d(26, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(26, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (relu): ReLU(inplace)
#     )
#     (14): Bottleneck(
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (select): channel_selection()
#       (conv1): Conv2d(74, 22, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn2): BatchNorm2d(22, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(22, 27, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn3): BatchNorm2d(27, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(27, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (relu): ReLU(inplace)
#     )
#     (15): Bottleneck(
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (select): channel_selection()
#       (conv1): Conv2d(71, 19, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn2): BatchNorm2d(19, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(19, 31, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn3): BatchNorm2d(31, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(31, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (relu): ReLU(inplace)
#     )
#     (16): Bottleneck(
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (select): channel_selection()
#       (conv1): Conv2d(80, 17, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn2): BatchNorm2d(17, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(17, 28, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn3): BatchNorm2d(28, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(28, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (relu): ReLU(inplace)
#     )
#     (17): Bottleneck(
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (select): channel_selection()
#       (conv1): Conv2d(67, 20, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn2): BatchNorm2d(20, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(20, 29, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn3): BatchNorm2d(29, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(29, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (relu): ReLU(inplace)
#     )
#   )
#   (layer3): Sequential(
#     (0): Bottleneck(
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (select): channel_selection()
#       (conv1): Conv2d(66, 33, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn2): BatchNorm2d(33, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(33, 63, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn3): BatchNorm2d(63, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(63, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (relu): ReLU(inplace)
#       (downsample): Sequential(
#         (0): Conv2d(128, 256, kernel_size=(1, 1), stride=(2, 2), bias=False)
#       )
#     )
#     (1): Bottleneck(
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (select): channel_selection()
#       (conv1): Conv2d(147, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn2): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(32, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn3): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (relu): ReLU(inplace)
#     )
#     (2): Bottleneck(
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (select): channel_selection()
#       (conv1): Conv2d(133, 34, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn2): BatchNorm2d(34, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(34, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn3): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (relu): ReLU(inplace)
#     )
#     (3): Bottleneck(
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (select): channel_selection()
#       (conv1): Conv2d(152, 39, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn2): BatchNorm2d(39, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(39, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn3): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (relu): ReLU(inplace)
#     )
#     (4): Bottleneck(
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (select): channel_selection()
#       (conv1): Conv2d(147, 34, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn2): BatchNorm2d(34, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(34, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn3): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (relu): ReLU(inplace)
#     )
#     (5): Bottleneck(
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (select): channel_selection()
#       (conv1): Conv2d(163, 35, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn2): BatchNorm2d(35, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(35, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn3): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (relu): ReLU(inplace)
#     )
#     (6): Bottleneck(
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (select): channel_selection()
#       (conv1): Conv2d(150, 36, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn2): BatchNorm2d(36, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(36, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn3): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (relu): ReLU(inplace)
#     )
#     (7): Bottleneck(
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (select): channel_selection()
#       (conv1): Conv2d(145, 36, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn2): BatchNorm2d(36, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(36, 63, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn3): BatchNorm2d(63, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(63, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (relu): ReLU(inplace)
#     )
#     (8): Bottleneck(
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (select): channel_selection()
#       (conv1): Conv2d(153, 33, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn2): BatchNorm2d(33, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(33, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn3): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (relu): ReLU(inplace)
#     )
#     (9): Bottleneck(
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (select): channel_selection()
#       (conv1): Conv2d(151, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn2): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(32, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn3): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (relu): ReLU(inplace)
#     )
#     (10): Bottleneck(
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (select): channel_selection()
#       (conv1): Conv2d(149, 33, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn2): BatchNorm2d(33, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(33, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn3): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (relu): ReLU(inplace)
#     )
#     (11): Bottleneck(
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (select): channel_selection()
#       (conv1): Conv2d(153, 38, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn2): BatchNorm2d(38, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(38, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn3): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (relu): ReLU(inplace)
#     )
#     (12): Bottleneck(
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (select): channel_selection()
#       (conv1): Conv2d(154, 37, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn2): BatchNorm2d(37, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(37, 63, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn3): BatchNorm2d(63, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(63, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (relu): ReLU(inplace)
#     )
#     (13): Bottleneck(
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (select): channel_selection()
#       (conv1): Conv2d(159, 34, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn2): BatchNorm2d(34, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(34, 63, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn3): BatchNorm2d(63, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(63, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (relu): ReLU(inplace)
#     )
#     (14): Bottleneck(
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (select): channel_selection()
#       (conv1): Conv2d(157, 42, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn2): BatchNorm2d(42, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(42, 63, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn3): BatchNorm2d(63, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(63, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (relu): ReLU(inplace)
#     )
#     (15): Bottleneck(
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (select): channel_selection()
#       (conv1): Conv2d(167, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn2): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(32, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn3): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (relu): ReLU(inplace)
#     )
#     (16): Bottleneck(
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (select): channel_selection()
#       (conv1): Conv2d(154, 28, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn2): BatchNorm2d(28, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(28, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn3): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (relu): ReLU(inplace)
#     )
#     (17): Bottleneck(
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (select): channel_selection()
#       (conv1): Conv2d(155, 34, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn2): BatchNorm2d(34, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(34, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn3): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (relu): ReLU(inplace)
#     )
#   )
#   (bn): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (select): channel_selection()
#   (relu): ReLU(inplace)
#   (avgpool): AvgPool2d(kernel_size=8, stride=8, padding=0)
#   (fc): Linear(in_features=238, out_features=10, bias=True)
# )

# %%
# num of param in new model
num_parameters = sum([param.nelement() for param in newmodel.parameters()])

old_modules = list(model.modules())
new_modules = list(newmodel.modules())
layer_id_in_cfg = 0
start_mask = torch.ones(3)
end_mask = cfg_mask[layer_id_in_cfg]
conv_count = 0


# 把原来model里面的参数 填入new model

for layer_id in range(len(old_modules)):
    m0 = old_modules[layer_id]
    m1 = new_modules[layer_id]
#     print('start_mask: ',start_mask)
#     print('end_mask: ',end_mask)
    if isinstance(m0, nn.BatchNorm2d):
#         print("current is BN layer")
        idx1 = np.squeeze(np.argwhere(np.asarray(end_mask.cpu().numpy())))
        if idx1.size == 1:
            idx1 = np.resize(idx1,(1,))
        
        # 当后面一层是channel selection时
        if isinstance(old_modules[layer_id + 1], channel_selection):
#             print("  next layer is CS")
            # If the next layer is the channel selection layer, then the current batchnorm 2d layer won't be pruned.
            # 既然后面是 channel selection layer，就不用挑出哪些是prune的
            # 直接原模型所有参数apply到新的上
            m1.weight.data = m0.weight.data.clone()
            m1.bias.data = m0.bias.data.clone()
            m1.running_mean = m0.running_mean.clone()
            m1.running_var = m0.running_var.clone()

            # We need to set the channel selection layer.
            # 需要把cs layer的indexs参数改成这里的idx就行
            # 用cs layer 来实现prune的效果
            m2 = new_modules[layer_id + 1]
            m2.indexes.data.zero_()
            m2.indexes.data[idx1.tolist()] = 1.0

            layer_id_in_cfg += 1
            start_mask = end_mask.clone()
            if layer_id_in_cfg < len(cfg_mask):
                end_mask = cfg_mask[layer_id_in_cfg]
        else:
            # 从老模型里面挑出保留下来的channel
            # 然后把这些参数apply到新的模型
#             print("  next layer is NOT CS")
            m1.weight.data = m0.weight.data[idx1.tolist()].clone()
            m1.bias.data = m0.bias.data[idx1.tolist()].clone()
            m1.running_mean = m0.running_mean[idx1.tolist()].clone()
            m1.running_var = m0.running_var[idx1.tolist()].clone()
            layer_id_in_cfg += 1
            start_mask = end_mask.clone()
            if layer_id_in_cfg < len(cfg_mask):  # do not change in Final FC
                end_mask = cfg_mask[layer_id_in_cfg]
    elif isinstance(m0, nn.Conv2d):
#         print("current is conv layer")
        if conv_count == 0: # 第一层卷积层不prune
#             print("  current is first conv layer")
            m1.weight.data = m0.weight.data.clone()
            conv_count += 1
            continue
        if isinstance(old_modules[layer_id-1], channel_selection) or isinstance(old_modules[layer_id-1], nn.BatchNorm2d):
            # 所有残差模块里面的conv层要么跟在bn后面 要么跟在channel selection后面
            # This convers the convolutions in the residual block.
            # The convolutions are either after the channel selection layer or after the batch normalization layer.
            conv_count += 1
            # start_mask 指的是当前层的前一层的mask
            # end_mask 代表当前层
            
            
            #奇怪的补丁：
            if isinstance(old_modules[layer_id-1], channel_selection):
                old_prev_cs = old_modules[layer_id-1]
                new_prev_cs = new_modules[layer_id-1]
                old_ones = np.squeeze(np.argwhere(old_prev_cs.indexes.data))
                new_ones = np.squeeze(np.argwhere(new_prev_cs.indexes.data))
                start_mask = [0] * len(old_ones)
                for idx in range(len(old_ones)):
                    if old_ones[idx] in new_ones:
                        start_mask[idx] = 1
                    else:
                        start_mask[idx] = 0
                start_mask = torch.FloatTensor(start_mask)
                
#             print('conv_count: ',conv_count)
#             print('layer_id: ',layer_id)
            idx0 = np.squeeze(np.argwhere(np.asarray(start_mask.cpu().numpy())))
            idx1 = np.squeeze(np.argwhere(np.asarray(end_mask.cpu().numpy())))
            print('In shape: {:d}, Out shape {:d}.'.format(idx0.size, idx1.size))
#             print(idx0)
#             print(idx1)
            if idx0.size == 1:
                idx0 = np.resize(idx0, (1,))
            if idx1.size == 1:
                idx1 = np.resize(idx1, (1,))
#             print("idx0 to list: ")
#             print(idx0.tolist())
#             print(m0.weight.data.shape)
            w1 = m0.weight.data[:, idx0.tolist(), :, :].clone()
#             print('w1')
#             print(w1)
            # If the current convolution is not the last convolution in the residual block, then we can change the 
            # number of output channels. Currently we use `conv_count` to detect whether it is such convolution.
            # 这里残差模块里面一共有3个conv层，prune的时候不剪第三个conv层
            if conv_count % 3 != 1:
                w1 = w1[idx1.tolist(), :, :, :].clone()
            m1.weight.data = w1.clone()
            continue

        # We need to consider the case where there are downsampling convolutions. 
        # For these convolutions, we just copy the weights.
        # 对于下采样层也不剪枝
        m1.weight.data = m0.weight.data.clone()
    elif isinstance(m0, nn.Linear):
        
        # 奇怪的补丁
        old_prev_cs = old_modules[layer_id-3]
        new_prev_cs = new_modules[layer_id-3]
        old_ones = np.squeeze(np.argwhere(old_prev_cs.indexes.data))
        new_ones = np.squeeze(np.argwhere(new_prev_cs.indexes.data))
        start_mask = [0] * len(old_ones)
        for idx in range(len(old_ones)):
            if old_ones[idx] in new_ones:
                start_mask[idx] = 1
            else:
                start_mask[idx] = 0
        start_mask = torch.FloatTensor(start_mask)

        
        idx0 = np.squeeze(np.argwhere(np.asarray(start_mask.cpu().numpy())))
        if idx0.size == 1:
            idx0 = np.resize(idx0, (1,))
        
        m1.weight.data = m0.weight.data[:, idx0].clone()
        m1.bias.data = m0.bias.data.clone()
# Out:
# In shape: 10, Out shape 11.
# In shape: 11, Out shape 12.
# In shape: 12, Out shape 30.
# In shape: 30, Out shape 11.
# In shape: 11, Out shape 11.
# In shape: 11, Out shape 32.
# In shape: 32, Out shape 11.
# In shape: 11, Out shape 13.
# In shape: 13, Out shape 38.
# In shape: 38, Out shape 12.
# In shape: 12, Out shape 11.
# In shape: 11, Out shape 37.
# In shape: 37, Out shape 13.
# In shape: 13, Out shape 12.
# In shape: 12, Out shape 32.
# In shape: 32, Out shape 13.
# In shape: 13, Out shape 9.
# In shape: 9, Out shape 34.
# In shape: 34, Out shape 11.
# In shape: 11, Out shape 12.
# In shape: 12, Out shape 34.
# In shape: 34, Out shape 11.
# In shape: 11, Out shape 13.
# In shape: 13, Out shape 35.
# In shape: 35, Out shape 10.
# In shape: 10, Out shape 9.
# In shape: 9, Out shape 36.
# In shape: 36, Out shape 11.
# In shape: 11, Out shape 12.
# In shape: 12, Out shape 32.
# In shape: 32, Out shape 9.
# In shape: 9, Out shape 9.
# In shape: 9, Out shape 34.
# In shape: 34, Out shape 12.
# In shape: 12, Out shape 10.
# In shape: 10, Out shape 30.
# In shape: 30, Out shape 7.
# In shape: 7, Out shape 15.
# In shape: 15, Out shape 38.
# In shape: 38, Out shape 11.
# In shape: 11, Out shape 7.
# In shape: 7, Out shape 33.
# In shape: 33, Out shape 11.
# In shape: 11, Out shape 8.
# In shape: 8, Out shape 36.
# In shape: 36, Out shape 11.
# In shape: 11, Out shape 8.
# In shape: 8, Out shape 43.
# In shape: 43, Out shape 11.
# In shape: 11, Out shape 9.
# In shape: 9, Out shape 34.
# In shape: 34, Out shape 7.
# In shape: 7, Out shape 7.
# In shape: 7, Out shape 31.
# In shape: 31, Out shape 22.
# In shape: 22, Out shape 25.
# In shape: 25, Out shape 74.
# In shape: 74, Out shape 17.
# In shape: 17, Out shape 28.
# In shape: 28, Out shape 69.
# In shape: 69, Out shape 20.
# In shape: 20, Out shape 32.
# In shape: 32, Out shape 72.
# In shape: 72, Out shape 22.
# In shape: 22, Out shape 29.
# In shape: 29, Out shape 74.
# In shape: 74, Out shape 23.
# In shape: 23, Out shape 28.
# In shape: 28, Out shape 72.
# In shape: 72, Out shape 17.
# In shape: 17, Out shape 30.
# In shape: 30, Out shape 81.
# In shape: 81, Out shape 16.
# In shape: 16, Out shape 29.
# In shape: 29, Out shape 67.
# In shape: 67, Out shape 15.
# In shape: 15, Out shape 29.
# In shape: 29, Out shape 71.
# In shape: 71, Out shape 21.
# In shape: 21, Out shape 25.
# In shape: 25, Out shape 67.
# In shape: 67, Out shape 16.
# In shape: 16, Out shape 29.
# In shape: 29, Out shape 72.
# In shape: 72, Out shape 19.
# In shape: 19, Out shape 24.
# In shape: 24, Out shape 67.
# In shape: 67, Out shape 18.
# In shape: 18, Out shape 29.
# In shape: 29, Out shape 76.
# In shape: 76, Out shape 21.
# In shape: 21, Out shape 28.
# In shape: 28, Out shape 75.
# In shape: 75, Out shape 20.
# In shape: 20, Out shape 26.
# In shape: 26, Out shape 74.
# In shape: 74, Out shape 22.
# In shape: 22, Out shape 27.
# In shape: 27, Out shape 71.
# In shape: 71, Out shape 19.
# In shape: 19, Out shape 31.
# In shape: 31, Out shape 80.
# In shape: 80, Out shape 17.
# In shape: 17, Out shape 28.
# In shape: 28, Out shape 67.
# In shape: 67, Out shape 20.
# In shape: 20, Out shape 29.
# In shape: 29, Out shape 66.
# In shape: 66, Out shape 33.
# In shape: 33, Out shape 63.
# In shape: 63, Out shape 147.
# In shape: 147, Out shape 32.
# In shape: 32, Out shape 64.
# In shape: 64, Out shape 133.
# In shape: 133, Out shape 34.
# In shape: 34, Out shape 64.
# In shape: 64, Out shape 152.
# In shape: 152, Out shape 39.
# In shape: 39, Out shape 64.
# In shape: 64, Out shape 147.
# In shape: 147, Out shape 34.
# In shape: 34, Out shape 64.
# In shape: 64, Out shape 163.
# In shape: 163, Out shape 35.
# In shape: 35, Out shape 64.
# In shape: 64, Out shape 150.
# In shape: 150, Out shape 36.
# In shape: 36, Out shape 64.
# In shape: 64, Out shape 145.
# In shape: 145, Out shape 36.
# In shape: 36, Out shape 63.
# In shape: 63, Out shape 153.
# In shape: 153, Out shape 33.
# In shape: 33, Out shape 64.
# In shape: 64, Out shape 151.
# In shape: 151, Out shape 32.
# In shape: 32, Out shape 64.
# In shape: 64, Out shape 149.
# In shape: 149, Out shape 33.
# In shape: 33, Out shape 64.
# In shape: 64, Out shape 153.
# In shape: 153, Out shape 38.
# In shape: 38, Out shape 64.
# In shape: 64, Out shape 154.
# In shape: 154, Out shape 37.
# In shape: 37, Out shape 63.
# In shape: 63, Out shape 159.
# In shape: 159, Out shape 34.
# In shape: 34, Out shape 63.
# In shape: 63, Out shape 157.
# In shape: 157, Out shape 42.
# In shape: 42, Out shape 63.
# In shape: 63, Out shape 167.
# In shape: 167, Out shape 32.
# In shape: 32, Out shape 64.
# In shape: 64, Out shape 154.
# In shape: 154, Out shape 28.
# In shape: 28, Out shape 64.
# In shape: 64, Out shape 155.
# In shape: 155, Out shape 34.
# In shape: 34, Out shape 64.
# In shape: 64, Out shape 238.

# %%
# 不保存
# torch.save({'cfg': cfg, 'state_dict': newmodel.state_dict()}, os.path.join(args.save, 'pruned.pth.tar'))
print(newmodel)
# Out:
# resnet(
#   (conv1): Conv2d(3, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#   (layer1): Sequential(
#     (0): Bottleneck(
#       (bn1): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (select): channel_selection()
#       (conv1): Conv2d(10, 11, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn2): BatchNorm2d(11, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(11, 12, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn3): BatchNorm2d(12, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(12, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (relu): ReLU(inplace)
#       (downsample): Sequential(
#         (0): Conv2d(16, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       )
#     )
#     (1): Bottleneck(
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (select): channel_selection()
#       (conv1): Conv2d(30, 11, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn2): BatchNorm2d(11, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(11, 11, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn3): BatchNorm2d(11, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(11, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (relu): ReLU(inplace)
#     )
#     (2): Bottleneck(
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (select): channel_selection()
#       (conv1): Conv2d(32, 11, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn2): BatchNorm2d(11, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(11, 13, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn3): BatchNorm2d(13, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(13, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (relu): ReLU(inplace)
#     )
#     (3): Bottleneck(
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (select): channel_selection()
#       (conv1): Conv2d(38, 12, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn2): BatchNorm2d(12, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(12, 11, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn3): BatchNorm2d(11, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(11, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (relu): ReLU(inplace)
#     )
#     (4): Bottleneck(
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (select): channel_selection()
#       (conv1): Conv2d(37, 13, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn2): BatchNorm2d(13, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(13, 12, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn3): BatchNorm2d(12, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(12, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (relu): ReLU(inplace)
#     )
#     (5): Bottleneck(
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (select): channel_selection()
#       (conv1): Conv2d(32, 13, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn2): BatchNorm2d(13, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(13, 9, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn3): BatchNorm2d(9, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(9, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (relu): ReLU(inplace)
#     )
#     (6): Bottleneck(
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (select): channel_selection()
#       (conv1): Conv2d(34, 11, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn2): BatchNorm2d(11, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(11, 12, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn3): BatchNorm2d(12, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(12, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (relu): ReLU(inplace)
#     )
#     (7): Bottleneck(
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (select): channel_selection()
#       (conv1): Conv2d(34, 11, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn2): BatchNorm2d(11, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(11, 13, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn3): BatchNorm2d(13, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(13, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (relu): ReLU(inplace)
#     )
#     (8): Bottleneck(
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (select): channel_selection()
#       (conv1): Conv2d(35, 10, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn2): BatchNorm2d(10, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(10, 9, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn3): BatchNorm2d(9, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(9, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (relu): ReLU(inplace)
#     )
#     (9): Bottleneck(
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (select): channel_selection()
#       (conv1): Conv2d(36, 11, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn2): BatchNorm2d(11, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(11, 12, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn3): BatchNorm2d(12, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(12, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (relu): ReLU(inplace)
#     )
#     (10): Bottleneck(
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (select): channel_selection()
#       (conv1): Conv2d(32, 9, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn2): BatchNorm2d(9, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(9, 9, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn3): BatchNorm2d(9, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(9, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (relu): ReLU(inplace)
#     )
#     (11): Bottleneck(
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (select): channel_selection()
#       (conv1): Conv2d(34, 12, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn2): BatchNorm2d(12, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(12, 10, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn3): BatchNorm2d(10, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(10, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (relu): ReLU(inplace)
#     )
#     (12): Bottleneck(
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (select): channel_selection()
#       (conv1): Conv2d(30, 7, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn2): BatchNorm2d(7, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(7, 15, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn3): BatchNorm2d(15, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(15, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (relu): ReLU(inplace)
#     )
#     (13): Bottleneck(
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (select): channel_selection()
#       (conv1): Conv2d(38, 11, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn2): BatchNorm2d(11, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(11, 7, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn3): BatchNorm2d(7, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(7, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (relu): ReLU(inplace)
#     )
#     (14): Bottleneck(
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (select): channel_selection()
#       (conv1): Conv2d(33, 11, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn2): BatchNorm2d(11, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(11, 8, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn3): BatchNorm2d(8, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(8, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (relu): ReLU(inplace)
#     )
#     (15): Bottleneck(
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (select): channel_selection()
#       (conv1): Conv2d(36, 11, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn2): BatchNorm2d(11, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(11, 8, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn3): BatchNorm2d(8, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(8, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (relu): ReLU(inplace)
#     )
#     (16): Bottleneck(
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (select): channel_selection()
#       (conv1): Conv2d(43, 11, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn2): BatchNorm2d(11, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(11, 9, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn3): BatchNorm2d(9, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(9, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (relu): ReLU(inplace)
#     )
#     (17): Bottleneck(
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (select): channel_selection()
#       (conv1): Conv2d(34, 7, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn2): BatchNorm2d(7, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(7, 7, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn3): BatchNorm2d(7, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(7, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (relu): ReLU(inplace)
#     )
#   )
#   (layer2): Sequential(
#     (0): Bottleneck(
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (select): channel_selection()
#       (conv1): Conv2d(31, 22, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn2): BatchNorm2d(22, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(22, 25, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn3): BatchNorm2d(25, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(25, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (relu): ReLU(inplace)
#       (downsample): Sequential(
#         (0): Conv2d(64, 128, kernel_size=(1, 1), stride=(2, 2), bias=False)
#       )
#     )
#     (1): Bottleneck(
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (select): channel_selection()
#       (conv1): Conv2d(74, 17, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn2): BatchNorm2d(17, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(17, 28, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn3): BatchNorm2d(28, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(28, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (relu): ReLU(inplace)
#     )
#     (2): Bottleneck(
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (select): channel_selection()
#       (conv1): Conv2d(69, 20, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn2): BatchNorm2d(20, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(20, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn3): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(32, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (relu): ReLU(inplace)
#     )
#     (3): Bottleneck(
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (select): channel_selection()
#       (conv1): Conv2d(72, 22, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn2): BatchNorm2d(22, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(22, 29, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn3): BatchNorm2d(29, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(29, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (relu): ReLU(inplace)
#     )
#     (4): Bottleneck(
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (select): channel_selection()
#       (conv1): Conv2d(74, 23, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn2): BatchNorm2d(23, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(23, 28, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn3): BatchNorm2d(28, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(28, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (relu): ReLU(inplace)
#     )
#     (5): Bottleneck(
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (select): channel_selection()
#       (conv1): Conv2d(72, 17, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn2): BatchNorm2d(17, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(17, 30, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn3): BatchNorm2d(30, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(30, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (relu): ReLU(inplace)
#     )
#     (6): Bottleneck(
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (select): channel_selection()
#       (conv1): Conv2d(81, 16, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn2): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(16, 29, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn3): BatchNorm2d(29, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(29, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (relu): ReLU(inplace)
#     )
#     (7): Bottleneck(
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (select): channel_selection()
#       (conv1): Conv2d(67, 15, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn2): BatchNorm2d(15, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(15, 29, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn3): BatchNorm2d(29, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(29, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (relu): ReLU(inplace)
#     )
#     (8): Bottleneck(
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (select): channel_selection()
#       (conv1): Conv2d(71, 21, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn2): BatchNorm2d(21, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(21, 25, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn3): BatchNorm2d(25, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(25, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (relu): ReLU(inplace)
#     )
#     (9): Bottleneck(
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (select): channel_selection()
#       (conv1): Conv2d(67, 16, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn2): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(16, 29, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn3): BatchNorm2d(29, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(29, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (relu): ReLU(inplace)
#     )
#     (10): Bottleneck(
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (select): channel_selection()
#       (conv1): Conv2d(72, 19, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn2): BatchNorm2d(19, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(19, 24, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn3): BatchNorm2d(24, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(24, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (relu): ReLU(inplace)
#     )
#     (11): Bottleneck(
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (select): channel_selection()
#       (conv1): Conv2d(67, 18, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn2): BatchNorm2d(18, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(18, 29, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn3): BatchNorm2d(29, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(29, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (relu): ReLU(inplace)
#     )
#     (12): Bottleneck(
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (select): channel_selection()
#       (conv1): Conv2d(76, 21, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn2): BatchNorm2d(21, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(21, 28, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn3): BatchNorm2d(28, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(28, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (relu): ReLU(inplace)
#     )
#     (13): Bottleneck(
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (select): channel_selection()
#       (conv1): Conv2d(75, 20, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn2): BatchNorm2d(20, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(20, 26, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn3): BatchNorm2d(26, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(26, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (relu): ReLU(inplace)
#     )
#     (14): Bottleneck(
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (select): channel_selection()
#       (conv1): Conv2d(74, 22, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn2): BatchNorm2d(22, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(22, 27, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn3): BatchNorm2d(27, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(27, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (relu): ReLU(inplace)
#     )
#     (15): Bottleneck(
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (select): channel_selection()
#       (conv1): Conv2d(71, 19, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn2): BatchNorm2d(19, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(19, 31, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn3): BatchNorm2d(31, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(31, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (relu): ReLU(inplace)
#     )
#     (16): Bottleneck(
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (select): channel_selection()
#       (conv1): Conv2d(80, 17, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn2): BatchNorm2d(17, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(17, 28, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn3): BatchNorm2d(28, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(28, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (relu): ReLU(inplace)
#     )
#     (17): Bottleneck(
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (select): channel_selection()
#       (conv1): Conv2d(67, 20, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn2): BatchNorm2d(20, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(20, 29, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn3): BatchNorm2d(29, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(29, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (relu): ReLU(inplace)
#     )
#   )
#   (layer3): Sequential(
#     (0): Bottleneck(
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (select): channel_selection()
#       (conv1): Conv2d(66, 33, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn2): BatchNorm2d(33, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(33, 63, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn3): BatchNorm2d(63, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(63, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (relu): ReLU(inplace)
#       (downsample): Sequential(
#         (0): Conv2d(128, 256, kernel_size=(1, 1), stride=(2, 2), bias=False)
#       )
#     )
#     (1): Bottleneck(
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (select): channel_selection()
#       (conv1): Conv2d(147, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn2): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(32, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn3): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (relu): ReLU(inplace)
#     )
#     (2): Bottleneck(
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (select): channel_selection()
#       (conv1): Conv2d(133, 34, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn2): BatchNorm2d(34, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(34, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn3): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (relu): ReLU(inplace)
#     )
#     (3): Bottleneck(
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (select): channel_selection()
#       (conv1): Conv2d(152, 39, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn2): BatchNorm2d(39, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(39, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn3): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (relu): ReLU(inplace)
#     )
#     (4): Bottleneck(
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (select): channel_selection()
#       (conv1): Conv2d(147, 34, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn2): BatchNorm2d(34, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(34, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn3): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (relu): ReLU(inplace)
#     )
#     (5): Bottleneck(
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (select): channel_selection()
#       (conv1): Conv2d(163, 35, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn2): BatchNorm2d(35, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(35, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn3): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (relu): ReLU(inplace)
#     )
#     (6): Bottleneck(
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (select): channel_selection()
#       (conv1): Conv2d(150, 36, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn2): BatchNorm2d(36, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(36, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn3): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (relu): ReLU(inplace)
#     )
#     (7): Bottleneck(
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (select): channel_selection()
#       (conv1): Conv2d(145, 36, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn2): BatchNorm2d(36, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(36, 63, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn3): BatchNorm2d(63, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(63, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (relu): ReLU(inplace)
#     )
#     (8): Bottleneck(
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (select): channel_selection()
#       (conv1): Conv2d(153, 33, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn2): BatchNorm2d(33, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(33, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn3): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (relu): ReLU(inplace)
#     )
#     (9): Bottleneck(
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (select): channel_selection()
#       (conv1): Conv2d(151, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn2): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(32, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn3): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (relu): ReLU(inplace)
#     )
#     (10): Bottleneck(
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (select): channel_selection()
#       (conv1): Conv2d(149, 33, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn2): BatchNorm2d(33, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(33, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn3): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (relu): ReLU(inplace)
#     )
#     (11): Bottleneck(
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (select): channel_selection()
#       (conv1): Conv2d(153, 38, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn2): BatchNorm2d(38, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(38, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn3): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (relu): ReLU(inplace)
#     )
#     (12): Bottleneck(
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (select): channel_selection()
#       (conv1): Conv2d(154, 37, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn2): BatchNorm2d(37, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(37, 63, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn3): BatchNorm2d(63, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(63, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (relu): ReLU(inplace)
#     )
#     (13): Bottleneck(
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (select): channel_selection()
#       (conv1): Conv2d(159, 34, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn2): BatchNorm2d(34, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(34, 63, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn3): BatchNorm2d(63, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(63, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (relu): ReLU(inplace)
#     )
#     (14): Bottleneck(
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (select): channel_selection()
#       (conv1): Conv2d(157, 42, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn2): BatchNorm2d(42, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(42, 63, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn3): BatchNorm2d(63, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(63, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (relu): ReLU(inplace)
#     )
#     (15): Bottleneck(
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (select): channel_selection()
#       (conv1): Conv2d(167, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn2): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(32, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn3): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (relu): ReLU(inplace)
#     )
#     (16): Bottleneck(
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (select): channel_selection()
#       (conv1): Conv2d(154, 28, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn2): BatchNorm2d(28, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(28, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn3): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (relu): ReLU(inplace)
#     )
#     (17): Bottleneck(
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (select): channel_selection()
#       (conv1): Conv2d(155, 34, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn2): BatchNorm2d(34, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(34, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn3): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (relu): ReLU(inplace)
#     )
#   )
#   (bn): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (select): channel_selection()
#   (relu): ReLU(inplace)
#   (avgpool): AvgPool2d(kernel_size=8, stride=8, padding=0)
#   (fc): Linear(in_features=238, out_features=10, bias=True)
# )

# %%
print(count_conv_channels(model))
print(count_conv_channels(newmodel))
print('7724 / 9655 = 0.8')
# Out:
# 9655
# 7724
# 7724 / 9655 = 0.8

# %%
# Out:
# 0.8

# %%
model = newmodel
test(model)

# %%
np.squeeze(np.argwhere(np.asarray(torch.FloatTensor(start_mask).cpu().data)))

# %%
new_cs = new_modules[layer_id-1]

# %%
print('len of cs indexes: ',len(np.asarray(new_cs.indexes.data)))
print(np.asarray(new_cs.indexes.data))
print(np.squeeze(np.argwhere(np.asarray(new_cs.indexes.data))))

# %%
idx1

# %%
len(old_modules)

# %%
old_idx =[0,1,1,1,1,1,1]
new_idx =[0,0,1,1,0,0,0]

# %%
old_ones = np.squeeze(np.argwhere(old_idx))

# %%
new_ones = np.squeeze(np.argwhere(new_idx))

# %%
new_ones.shape[0]

# %%
old_ones

# %%
np.setdiff1d(old_ones,new_ones)

# %%
tmp = [1,2,3,4,5]

# %%
del tmp,[0,4]

# %%
a = [0] * 4

# %%
a[2]=1

# %%
a

# %%
1 in [10,20,30]
